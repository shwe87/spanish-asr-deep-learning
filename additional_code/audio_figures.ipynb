# %%
# %matplotlib inline
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
import librosa, librosa.display

# %%
from scipy import fftpack
import numpy as np

def get_freq_spec(x, sr):
  X = fftpack.fft(x)
  freqs = fftpack.fftfreq(len(x)) * sr
  X_mag = np.absolute(X)

  return freqs, X_mag

# %%
#19-8-29 Females
#20-1-30 Males
x8, sr8 = librosa.load('./drive/My Drive/TFM/data/speech_commands_v0.01/happy/happy-8.wav')
f8, X8 = get_freq_spec(x8, sr8)
D8 = librosa.amplitude_to_db(np.abs(librosa.stft(x8)), ref=np.max)
x19, sr19 = librosa.load('./drive/My Drive/TFM/data/speech_commands_v0.01/happy/happy-19.wav')
f19, X19 = get_freq_spec(x19, sr19)
D19 = librosa.amplitude_to_db(np.abs(librosa.stft(x19)), ref=np.max)
#x29, sr29 = librosa.load('./drive/My Drive/TFM/data/speech_commands_v0.01/happy/happy-29.wav')

#Load the male files:
x1, sr1 = librosa.load('./drive/My Drive/TFM/data/speech_commands_v0.01/happy/happy-1.wav')
f1, X1 = get_freq_spec(x1, sr1)
D1 = librosa.amplitude_to_db(np.abs(librosa.stft(x1)), ref=np.max)
x20, sr20 = librosa.load('./drive/My Drive/TFM/data/speech_commands_v0.01/happy/happy-20.wav')
f20, X20 = get_freq_spec(x20, sr20)
D20 = librosa.amplitude_to_db(np.abs(librosa.stft(x20)), ref=np.max)
#x30, sr30 = librosa.load('./drive/My Drive/TFM/data/speech_commands_v0.01/happy/happy-30.wav')
#ipd.Audio(x1, rate=sr1)

# %%
fig = plt.figure(figsize=(35, 25))
ax = fig.add_subplot(4, 3, 1)
librosa.display.waveplot(x8, sr8)
ax.set_ylabel('Happy - Female Voice 8', rotation=90, size='large')
#h1 = plt.text(-0.15, -0.5,'Happy - Female Voice 8',rotation=90,**title_font);
plt.title('Time Representation', fontsize=24,weight='bold')


fig.add_subplot(4, 3, 2)
plt.plot(f8, X8, color='green')
plt.xlim(-5000,5000)
#lt.text(5,0.5,'Frequency-Amplitude Representation',**title_font);
plt.title('Frequency-Amplitude Representation', fontsize=24,weight='bold')
plt.xlabel('Frequency in Hertz [Hz]')
plt.ylabel('Frequency Domain (Spectrum) Magnitude')



fig.add_subplot(4, 3, 3)
librosa.display.specshow(D8, x_axis = 'time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Log power spectrogram', fontsize=24,weight='bold')


ax = fig.add_subplot(4, 3, 4)
librosa.display.waveplot(x19, sr19)
#plt.title('Happy 19 - Female Voice')
#h1 = plt.text(-0.15, -0.8,'Happy-Female Voice 19',rotation=90,**title_font);
ax.set_ylabel('Happy - Female Voice 19', rotation=90, size='xx-large')

fig.add_subplot(4, 3, 5)
plt.plot(f19, X19, color='green')
plt.xlim(-5000,5000)
plt.xlabel('Frequency in Hertz [Hz]')
plt.ylabel('Frequency Domain (Spectrum) Magnitude')

fig.add_subplot(4, 3, 6)
librosa.display.specshow(D19, x_axis = 'time', y_axis='log')
plt.colorbar(format='%+2.0f dB')

ax = fig.add_subplot(4, 3, 7)
librosa.display.waveplot(x1, sr1)
#plt.title('Happy 1 - Male Voice')
#h1 = plt.text(-0.15, -0.5,'Happy - Male Voice 1',rotation=90,**title_font);
ax.set_ylabel('Happy - Male Voice 1', rotation=90, size='xx-large')

fig.add_subplot(4, 3, 8)
plt.plot(f1, X1, color='green')
plt.xlim(-5000,5000)
plt.xlabel('Frequency in Hertz [Hz]')
plt.ylabel('Frequency Domain (Spectrum) Magnitude')

fig.add_subplot(4, 3, 9)
librosa.display.specshow(D1, x_axis = 'time', y_axis='log')
plt.colorbar(format='%+2.0f dB')

ax = fig.add_subplot(4, 3, 10)
librosa.display.waveplot(x20, sr20)
#h1 = plt.text(-0.15, -0.8,'Happy - 20 - Male Voice',rotation=90,**title_font);
ax.set_ylabel('Happy - Male Voice 20', rotation=90, size='xx-large')

fig.add_subplot(4, 3, 11)
plt.plot(f20, X20, color='green')
plt.xlim(-5000,5000)
plt.xlabel('Frequency in Hertz [Hz]')
plt.ylabel('Frequency Domain (Spectrum) Magnitude')

fig.add_subplot(4, 3, 12)
librosa.display.specshow(D20, x_axis = 'time', y_axis='log')
plt.colorbar(format='%+2.0f dB')

# %%
#Load the three files
x8, sr8 = librosa.load('./drive/My Drive/TFM/data/speech_commands_v0.01/three/three-19.wav') #Female
f8, X8 = get_freq_spec(x8, sr8)
D8 = librosa.amplitude_to_db(np.abs(librosa.stft(x8)), ref=np.max)
x19, sr19 = librosa.load('./drive/My Drive/TFM/data/speech_commands_v0.01/three/three-17.wav')  # Male
f19, X19 = get_freq_spec(x19, sr19)
D19 = librosa.amplitude_to_db(np.abs(librosa.stft(x19)), ref=np.max)
#x29, sr29 = librosa.load('./drive/My Drive/TFM/data/speech_commands_v0.01/yes/yes-29.wav')    

#Load the yes files:
x1, sr1 = librosa.load('./drive/My Drive/TFM/data/speech_commands_v0.01/yes/yes-2.wav')     #Female
#x1, _ = librosa.effects.trim(x1)
f1, X1 = get_freq_spec(x1, sr1)
D1 = librosa.amplitude_to_db(np.abs(librosa.stft(x1)), ref=np.max)
x20, sr20 = librosa.load('./drive/My Drive/TFM/data/speech_commands_v0.01/yes/yes-23.wav')
f20, X20 = get_freq_spec(x20, sr20)
D20 = librosa.amplitude_to_db(np.abs(librosa.stft(x20)), ref=np.max)
#x30, sr30 = librosa.load('./drive/My Drive/TFM/data/speech_commands_v0.01/yes/yes-30.wav')
#ipd.Audio(x1, rate=sr1)

# %%
ipd.Audio(data=x8, rate=sr8)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig = plt.figure(figsize=(35, 25))
ax = fig.add_subplot(4, 3, 1)
librosa.display.waveplot(x8, sr8)
ax.set_ylabel('Three-Female Voice', rotation=90, size='xx-large')
plt.title('Time Representation', fontsize=24,weight='bold')


fig.add_subplot(4, 3, 2)
plt.plot(f8, X8, color='green')
plt.xlim(-5000,5000)
#lt.text(5,0.5,'Frequency-Amplitude Representation',**title_font);
plt.title('Frequency-Amplitude Representation', fontsize=24,weight='bold')
plt.xlabel('Frequency in Hertz [Hz]')
plt.ylabel('Frequency Domain (Spectrum) Magnitude')




fig.add_subplot(4, 3, 3)
librosa.display.specshow(D8, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Log power spectrogram', fontsize=24,weight='bold')


ax = fig.add_subplot(4, 3, 4)
librosa.display.waveplot(x19, sr19)
#plt.title('Happy 19 - Female Voice')
ax.set_ylabel('Three-Male Voice', rotation=90, size='xx-large')

fig.add_subplot(4, 3, 5)
plt.plot(f19, X19, color='green')
plt.xlim(-5000,5000)
plt.xlabel('Frequency in Hertz [Hz]')
plt.ylabel('Frequency Domain (Spectrum) Magnitude')

fig.add_subplot(4, 3, 6)
librosa.display.specshow(D19, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')

ax = fig.add_subplot(4, 3, 7)
librosa.display.waveplot(x1, sr1)
#plt.title('Happy 1 - Male Voice')
ax.set_ylabel('Yes-Female Voice', rotation=90, size='xx-large')

fig.add_subplot(4, 3, 8)
plt.plot(f1, X1, color='green')
plt.xlim(-5000,5000)
plt.xlabel('Frequency in Hertz [Hz]')
plt.ylabel('Frequency Domain (Spectrum) Magnitude')

fig.add_subplot(4, 3, 9)
librosa.display.specshow(D1, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')

ax = fig.add_subplot(4, 3, 10)
librosa.display.waveplot(x20, sr20)
ax.set_ylabel('Yes-Male Voice', rotation=90, size='xx-large')

fig.add_subplot(4, 3, 11)
plt.plot(f20, X20, color='green')
plt.xlim(-5000,5000)
plt.xlabel('Frequency in Hertz [Hz]')
plt.ylabel('Frequency Domain (Spectrum) Magnitude')

fig.add_subplot(4, 3, 12)
librosa.display.specshow(D20, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')

# %%
import numpy as np
import matplotlib.pyplot as plt
left, width = 0.1, 0.8
rect1 = [left, 0.65, width, 0.25]  # left, bottom, width, height
rect2 = [left, 0.4, width, 0.25]
rect3 = [left, 0.1, width, 0.3]

fig = plt.figure(figsize=(10, 6))

ax1 = fig.add_axes(rect1) 
ax2 = fig.add_axes(rect2, sharex=ax1)
ax3 = fig.add_axes(rect3, sharex=ax1)

x = np.linspace(0, 6.5*np.pi, 200)
y1 = np.sin(x)
y2 = np.sin(2*x)

ax1.plot(x, y1, color='b', lw=2)
ax2.plot(x, y2, color='g', lw=2)
ax3.plot(x, y1+y2, color='r', lw=2)

ax3.get_xaxis().set_ticks([])

for ax in [ax1, ax2, ax3]:
    ax.hlines(0, 0, 6.5*np.pi, color='black')
    for key in ['right', 'top', 'bottom']:
        ax.spines[key].set_visible(False)

plt.xlim(0, 6.6*np.pi)
ax3.text(2, 0.9, 'Sum signal', fontsize=14)
# Out:
# Text(2, 0.9, 'Sum signal')
