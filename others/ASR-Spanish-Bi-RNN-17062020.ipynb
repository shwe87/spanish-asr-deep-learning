# %%
! pip install soundfile
# Out:
# Requirement already satisfied: soundfile in /opt/conda/lib/python3.7/site-packages (0.10.3.post1)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.7/site-packages (from soundfile) (1.14.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.0->soundfile) (2.20)

# %%
#! apt-get install -y libsndfile1 --quiet
#!pip install torchsummary
#!pip install livelossplot --quiet
# File Settings
ROOT_FOLDER = '/kaggle/input/spanish-single-speaker-speech-dataset/'
CSV_FILE_PATH = ROOT_FOLDER + 'transcript.txt'

SAVE_RESULTS_PATH = '/kaggle/working/'
SAVE_MODELS_PATH = '/kaggle/working/'

# %%
# Systems Libraries
import os
import time

# For audio processing
import librosa
import librosa.display
import IPython as ipd

#from torchsummary import summary

# For data processing
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# For Neural networks
import torch
from torch import nn
import pickle as pkl
import torch.nn.functional as F
from pytorchtools import EarlyStopping
from torch.utils.data import Dataset, DataLoader


# For visualization
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')



# For text processing
import string

# Scripts created by me:
import utils
import models
import textprocessor
import speechdataset

from datetime import datetime



from random import choice
import random
import math

import soundfile as sf

# %% [markdown]
# ### Audio Sample
# Hear one of the audios.

# %%
ipd.display.Audio(filename='../input/spanish-single-speaker-speech-dataset/batalla_arapiles/batalla_arapiles_0010.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Plot audio
#
# Plot the audio in different formats:
#
# * Waveform
# * MFCCs (13)
# * Spectrogram.

# %%
(waveform, sample_rate) = librosa.load('../input/spanish-single-speaker-speech-dataset/batalla_arapiles/batalla_arapiles_0010.wav')
spectrogram = librosa.feature.melspectrogram(y=waveform, sr=sample_rate)
mfccs = librosa.feature.mfcc(y=waveform, sr=sample_rate, n_mfcc=13)
utils.plot_all(audio_data=waveform, spec=spectrogram, mfccs=mfccs, sr=sample_rate, file='batalla_arapiles_0010.wav')

# %% [markdown]
# ### Data Pre-processing:
#
# Before starting to analyse the data, let's do some clean up. The path which looks like 19demarzo/19marzo_XXXX.wav will be split into two other columns and thus we will have a table like this:
#
#
# | index | path    |	utterance  | label   | duration	 | dir	   | file    |
# |------ |---------|------------|---------|-----------|---------|---------|
# |0	| 19demarzo/19demarzo_0000.wav	| Durante nuestra conversación advertí que la mu...|	Durante nuestra conversación advertí que la mu...|	5.88	| 19demarzo	|19demarzo_0000.wav |
# |1|	19demarzo/19demarzo_0001.wav|	Componíanla personas de ambos sexos y de todas...|	Componíanla personas de ambos sexos y de todas...|	4.52|	19demarzo	|19demarzo_0001.wav |
# |2|	19demarzo/19demarzo_0002.wav|	espontáneamente venidas por uno de esos llamam...|	espontáneamente venidas por uno de esos llamam...|	8.31|	19demarzo |	19demarzo_0002.wav |
# |3|	19demarzo/19demarzo_0003.wav|	y resuenan de improviso en los oídos de un pue...|	y resuenan de improviso en los oídos de un pue...|	7.20|	19demarzo |	19demarzo_0003.wav |
# |4|	19demarzo/19demarzo_0004.wav|	La campana de ese arrebato glorioso no suena s...|	La campana de ese arrebato glorioso no suena s...|	7.50|	19demarzo |	19demarzo_0004.wav |
#
#
#
#
#
# ### Clearing up unnecessary data
#
# It is clear that there are accents, commas, etc. that we don't really care about. So, let's clear those up.
# We will also clearup the data where the utterance is empty with the command d.dropna.

# %% [markdown]
# ## Processing the audio data.
# For the audio, I need to get the spectrogram or mfccs and the utterance (as the label).
# The custom dataset saved as a utility script as speechdataset was created following the Custom Dataset tutorial by pytorch:
# https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
#
# **The utility script can be found named as speechdataset.**

# %%
def load_dataset(csv_file, root_dir):
  
  # Create the dataset and split into validation dataset and test dataset.
    total_dataset = speechdataset.SpanishSpeechDataSet(csv_file=csv_file, root_dir=root_dir)
    train_size = int(0.8 * len(total_dataset))
    val_test_size = len(total_dataset) - train_size
    train_dataset, val_test_dataset = torch.utils.data.random_split(total_dataset, [train_size, val_test_size])
    valid_size = int(0.9 * len(val_test_dataset))
    test_size = len(val_test_dataset) - valid_size
    val_dataset, test_dataset = torch.utils.data.random_split(val_test_dataset, [valid_size, test_size])
    print("Total Training Dataset = {}, Valid Dataset = {} and Test Dataset = {}".format(len(train_dataset),len(val_dataset), len(test_dataset) ))
    sample = train_dataset[0]
    print("*****Showing spectorgram with label:**** \n")
    print(sample[1])
    utils.plot_spec(sample[0], title="Mel spectrogram")
    return (train_dataset, val_dataset, test_dataset)

# %% [markdown]
# ### Pad the data
# As the audio files have different lengths. We need to pad the data and create batches.
#
# For example if the batch size = 3
#  spec1 = [1 2 3 4 5]
#  spec2 = [6 7 8]
#  spec3 = [9 3]
# data_processing function will create batches like:
#
# 1 batch:
# [1 2 3 4 5]
# [6 7 8 0 0]
# [9 3 0 0 0]

# %%
# The following code will be for collat_fn for the pytorch dataloader function    
def data_processing(audio_data):
    spectrograms = []
    labels = []
    input_lengths = []
    label_lengths = []
    #print("data processing")
    for (spec,label) in audio_data:
        #The spectrogram is in (128, 407) and (128, 355) for example but later on for padding the function expects (407, 128) and (355, 128). So we need to transpose the matrices.
        spectrograms.append(torch.Tensor(spec.transpose()))
        t = textprocessor.TextProcessor()
        label = torch.Tensor(t.text2int(text=label))
        labels.append(label)
        input_lengths.append(spec.shape[0]//2)
        label_lengths.append(len(label))
    #print("Start padding")
    spec_pad = torch.nn.utils.rnn.pad_sequence(spectrograms, batch_first=True).unsqueeze(1).transpose(2,3)   #(batch, channel=1, features, time )
    label_pad = torch.nn.utils.rnn.pad_sequence(labels, batch_first=True)
    #print("Finish padding")
    return spec_pad, label_pad, input_lengths, label_lengths

# %% [markdown]
# ### Create the data loaders for training, validation and testing.

# %%
def create_data_loaders(train_dataset, val_dataset, test_dataset, kwargs, batch_size):
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size,shuffle=True,drop_last=True, collate_fn=lambda x: data_processing(x), **kwargs )
    valid_loader = DataLoader(dataset=val_dataset, batch_size=batch_size,shuffle=False,drop_last=True, collate_fn=lambda x: data_processing(x), **kwargs)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size,shuffle=False,drop_last=True, collate_fn=lambda x: data_processing(x), **kwargs)
    return (train_loader, valid_loader, test_loader)

# %% [markdown]
# ### Training
#
# Ready for training and validating. Using earling stopping using the library from --> https://github.com/Bjarten/early-stopping-pytorch/
#
# We will set up the patience to 15

# %%
def train(n_epochs, train_loader, valid_loader, model, criterion, clip, device, lr, batch_size, save_model_path, save_pkl_path, show_every_n_batch=50):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=lr, 
                                            steps_per_epoch=int(len(train_loader)),
                                            epochs=n_epochs,
                                            anneal_strategy='linear')
    train_data_len = len(train_loader.dataset)
    valid_data_len = len(valid_loader.dataset)
    epoch_train_loss = 0
    epoch_val_loss = 0
    train_losses = []
    valid_losses = []
    early_stopping = EarlyStopping(patience=20, verbose=True)
    print("#######################")
    print("#  Start Training    #")
    print("#######################")
    model.train()
    for e in range(n_epochs):
        t0 = time.time()
        #Initialize hidden state
        h = model.init_hidden(batch_size, device)
        #batch loop
        running_loss = 0.0
        for batch_idx, _data in enumerate(train_loader, 1):
            specs, labels, input_lengths, label_lengths = _data
            specs, labels = specs.to(device), labels.to(device)
            # Creating new variables for the hidden state, otherwise
            # we'd backprop through the entire training history
            h = h.detach()
            # zero accumulated gradients
            model.zero_grad()
            # get the output from the model
            output, h = model(specs, h)
            output = F.log_softmax(output, dim=2)
            output = output.transpose(0,1)
            # calculate the loss and perform backprop
            loss = criterion(output, labels.float(), input_lengths, label_lengths)
            loss.backward()
            # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
            nn.utils.clip_grad_norm_(model.parameters(), clip)
            optimizer.step()
            scheduler.step()
            # loss stats
            running_loss += loss.item() * specs.size(0)        
        t_t = time.time() - t0

            
        ######################    
        # validate the model #
        ######################
        with torch.no_grad():
            model.eval() 
            tv = time.time()
            running_val_loss = 0.0
            for batch_idx_v, _data in enumerate(valid_loader, 1):
                specs, labels, input_lengths, label_lengths = _data
                specs, labels = specs.to(device), labels.to(device)
                val_h = model.init_hidden(batch_size, device)
                output, val_h = model(specs, val_h)
                output = F.log_softmax(output, dim=2)
                output = output.transpose(0,1)
                val_loss = criterion(output, labels.float(), input_lengths, label_lengths)
                running_val_loss += val_loss.item() * specs.size(0)
            print("Epoch {}: Training took {:.2f} [s]\tValidation took: {:.2f} [s]\n".format(e+1, t_t, time.time() - tv))
                
                
        epoch_train_loss = running_loss / train_data_len
        epoch_val_loss = running_val_loss / valid_data_len
        train_losses.append(epoch_train_loss)
        valid_losses.append(epoch_val_loss)
        print('Epoch: {} Losses\tTraining Loss: {:.6f}\tValidation Loss: {:.6f}'.format(
                e+1, epoch_train_loss, epoch_val_loss))
        model.train()
        
        print("-------------------------------------------------------------------------------------------")
        print('Epoch {} took total {} seconds'.format(e+1, time.time() - t0))
        print("-------------------------------------------------------------------------------------------")
        early_stopping(epoch_val_loss, model)
        if early_stopping.early_stop:
            print("***Early stopping***")
            break
    with open(save_pkl_path, 'wb') as f:       #this will save the list as "results.pkl" which you can load in later 
        pkl.dump((epoch_train_loss, epoch_val_loss), f)
    utils.save_model(save_path=save_model_path, model=model)
    utils.save_checkpoint(save_path=save_model_path, model=model, optimizer=optimizer, epoch=e, loss=train_losses)
    return (model, train_losses, valid_losses)

# %% [markdown]
# ### Test Model
#
# Calculation of WER and CER is done using the code from deepspeech. The average WER and CER is displayed at the end of the test.
# Greedydecoder is used to decode the predicted char.

# %%
def test_model(test_data, model, model_name,device, batch_size):
    model.eval()
    print("#######################")
    print("# Testing Model: {} #".format(model_name))
    print("#######################\n\n")
    test_cer, test_wer = [], []
    test_loss = 0.0
    with torch.no_grad():
        for batch_idx, _data in enumerate(test_data, 1):
            specs, labels, input_lengths, label_lengths = _data
            #print(len(specs))
            specs, labels = specs.to(device), labels.to(device)
            # initialize the hidden state
            batch_size = specs.size(0)
            h = model.init_hidden(batch_size, device)
            # get the output of the rnn
            output, _ = model(specs, h)    
            # get the probabilities
            p = F.softmax(output, dim=2)
            output = output.transpose(0,1) #(time, batch,n_class)
            loss = criterion(output, labels, input_lengths, label_lengths)
            #Input should be [batch, time, n_classes]
            output = output.transpose(1,0)
            test_loss += loss.item() / len(test_loader)
            (decoded_preds, decoded_targets) = textprocessor.GreedyDecoder(output, labels, label_lengths)
            for j in range(len(decoded_preds)):
                print("****************************************************************************")
                print("Predicted -- {}".format(decoded_preds[j]))
                print("Utterance -- {}\n\n".format(decoded_targets[j]))
                test_cer.append(textprocessor.cer(decoded_targets[j], decoded_preds[j]))
                test_wer.append(textprocessor.wer(decoded_targets[j], decoded_preds[j]))
                utils.write_to_csv('/kaggle/working/'+model_name + '.csv', decoded_preds[j], decoded_targets[j], test_loss)
    avg_cer = sum(test_cer)/len(test_cer)
    avg_wer = sum(test_wer)/len(test_wer)
    print('Test set: Average loss: {:.4f}, Average CER: {:4f} Average WER: {:.4f}\n'.format(test_loss, avg_cer, avg_wer))

# %%
use_cuda = torch.cuda.is_available()
if use_cuda:
    torch.manual_seed(7)
device = torch.device("cuda" if use_cuda else "cpu")

# %%
input_size = 128
n_classes = 29
hidden_dim = 512
n_layers = 2
clip=5 # gradient clipping

lr = 5e-4
epochs = 27
batch_size=32

criterion = nn.CTCLoss(blank=28, zero_infinity=True)

# %%
kwargs={'num_workers': 4, 'pin_memory': True} if use_cuda else {}
(train_dataset, val_dataset, test_dataset) = load_dataset(csv_file=CSV_FILE_PATH, root_dir=ROOT_FOLDER)
(train_loader, valid_loader, test_loader) = create_data_loaders(train_dataset, val_dataset, test_dataset, kwargs=kwargs, batch_size=batch_size)
# Out:
# Total Training Dataset = 8812, Valid Dataset = 1983 and Test Dataset = 221
# *****Showing spectorgram with label:****
#
# y godoy se fue y carlos abdico despues fernando septimo puso sus tropas en manos de napoleon

# %%
my_birnn_net = models.SpeechRecognitionRNN(input_size, n_classes, hidden_dim, n_layers, layer_norm=True, bidir=True)
my_birnn_net.apply(models.weight_init)
conv_bigru_net = models.ASRConvBiGRU(in_channel=1, gru_input_size=512, hidden_dim=512, n_layers=5, n_feats=128, n_classes=n_classes, drop_prob=0.2)
conv_bigru_net.apply(models.weight_init)
my_birnn_net.to(device)
conv_bigru_net.to(device)
print(my_birnn_net)
print(conv_bigru_net)
# Out:
# SpeechRecognitionRNN(
#   (gru): GRU(128, 512, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (fc1): Linear(in_features=1024, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=29, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# ASRConvBiGRU(
#   (conv1): Conv2d(1, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fully_connected): Linear(in_features=2048, out_features=512, bias=True)
#   (gru): GRU(512, 512, num_layers=5, batch_first=True, dropout=0.2, bidirectional=True)
#   (classifier): Linear(in_features=1024, out_features=29, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
(birnn_model, birnn_train_losses, birnn_val_losses) = train(n_epochs=epochs, train_loader=train_loader, valid_loader=valid_loader,
                                                     model=my_birnn_net, criterion=criterion, clip=clip,
                                                     device=device, lr=lr, batch_size=batch_size,
                                                     save_model_path=SAVE_RESULTS_PATH+"rnn",
                                                    save_pkl_path=SAVE_MODELS_PATH + "training_rnn_iteration.pkl")
# Out:
# #######################
# #  Start Training    #
# #######################
# Epoch 1: Training took 157.45 [s]	Validation took: 30.24 [s]
#
# Epoch: 1 Losses	Training Loss: 0.330736	Validation Loss: 0.294599
# -------------------------------------------------------------------------------------------
# Epoch 1 took total 187.69153237342834 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (inf --> 0.294599).  Saving model ...
# Epoch 2: Training took 141.57 [s]	Validation took: 28.04 [s]
#
# Epoch: 2 Losses	Training Loss: 0.302662	Validation Loss: 0.278109
# -------------------------------------------------------------------------------------------
# Epoch 2 took total 169.6074140071869 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.294599 --> 0.278109).  Saving model ...
# Epoch 3: Training took 136.84 [s]	Validation took: 29.59 [s]
#
# Epoch: 3 Losses	Training Loss: 0.288277	Validation Loss: 0.279655
# -------------------------------------------------------------------------------------------
# Epoch 3 took total 166.4288523197174 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 4: Training took 142.96 [s]	Validation took: 29.06 [s]
#
# Epoch: 4 Losses	Training Loss: 0.289468	Validation Loss: 0.278911
# -------------------------------------------------------------------------------------------
# Epoch 4 took total 172.01933574676514 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 5: Training took 137.70 [s]	Validation took: 27.32 [s]
#
# Epoch: 5 Losses	Training Loss: 0.287616	Validation Loss: 0.277655
# -------------------------------------------------------------------------------------------
# Epoch 5 took total 165.02382445335388 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.278109 --> 0.277655).  Saving model ...
# Epoch 6: Training took 139.73 [s]	Validation took: 28.16 [s]
#
# Epoch: 6 Losses	Training Loss: 0.285584	Validation Loss: 0.275532
# -------------------------------------------------------------------------------------------
# Epoch 6 took total 167.8900547027588 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.277655 --> 0.275532).  Saving model ...
# Epoch 7: Training took 140.21 [s]	Validation took: 28.74 [s]
#
# Epoch: 7 Losses	Training Loss: 0.284555	Validation Loss: 0.274588
# -------------------------------------------------------------------------------------------
# Epoch 7 took total 168.94976210594177 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.275532 --> 0.274588).  Saving model ...
# Epoch 8: Training took 141.14 [s]	Validation took: 29.76 [s]
#
# Epoch: 8 Losses	Training Loss: 0.284182	Validation Loss: 0.277333
# -------------------------------------------------------------------------------------------
# Epoch 8 took total 170.90418434143066 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 9: Training took 139.41 [s]	Validation took: 28.62 [s]
#
# Epoch: 9 Losses	Training Loss: 0.281906	Validation Loss: 0.275238
# -------------------------------------------------------------------------------------------
# Epoch 9 took total 168.03101539611816 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 10: Training took 134.97 [s]	Validation took: 27.45 [s]
#
# Epoch: 10 Losses	Training Loss: 0.280045	Validation Loss: 0.273363
# -------------------------------------------------------------------------------------------
# Epoch 10 took total 162.42121291160583 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.274588 --> 0.273363).  Saving model ...
# Epoch 11: Training took 136.23 [s]	Validation took: 26.87 [s]
#
# Epoch: 11 Losses	Training Loss: 0.275974	Validation Loss: 0.272497
# -------------------------------------------------------------------------------------------
# Epoch 11 took total 163.10075902938843 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.273363 --> 0.272497).  Saving model ...
# Epoch 12: Training took 133.65 [s]	Validation took: 27.63 [s]
#
# Epoch: 12 Losses	Training Loss: 0.272561	Validation Loss: 0.274574
# -------------------------------------------------------------------------------------------
# Epoch 12 took total 161.27883458137512 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 13: Training took 131.62 [s]	Validation took: 26.23 [s]
#
# Epoch: 13 Losses	Training Loss: 0.270042	Validation Loss: 0.270669
# -------------------------------------------------------------------------------------------
# Epoch 13 took total 157.85992646217346 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.272497 --> 0.270669).  Saving model ...
# Epoch 14: Training took 132.22 [s]	Validation took: 26.46 [s]
#
# Epoch: 14 Losses	Training Loss: 0.266840	Validation Loss: 0.268880
# -------------------------------------------------------------------------------------------
# Epoch 14 took total 158.6771743297577 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.270669 --> 0.268880).  Saving model ...
# Epoch 15: Training took 131.18 [s]	Validation took: 27.22 [s]
#
# Epoch: 15 Losses	Training Loss: 0.263441	Validation Loss: 0.268530
# -------------------------------------------------------------------------------------------
# Epoch 15 took total 158.4069106578827 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.268880 --> 0.268530).  Saving model ...
# Epoch 16: Training took 130.67 [s]	Validation took: 26.17 [s]
#
# Epoch: 16 Losses	Training Loss: 0.259913	Validation Loss: 0.268757
# -------------------------------------------------------------------------------------------
# Epoch 16 took total 156.84384322166443 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 17: Training took 132.88 [s]	Validation took: 26.98 [s]
#
# Epoch: 17 Losses	Training Loss: 0.255507	Validation Loss: 0.269383
# -------------------------------------------------------------------------------------------
# Epoch 17 took total 159.85897135734558 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 18: Training took 132.04 [s]	Validation took: 27.93 [s]
#
# Epoch: 18 Losses	Training Loss: 0.250632	Validation Loss: 0.270093
# -------------------------------------------------------------------------------------------
# Epoch 18 took total 159.97147965431213 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 3 out of 20
# Epoch 19: Training took 132.62 [s]	Validation took: 26.46 [s]
#
# Epoch: 19 Losses	Training Loss: 0.245113	Validation Loss: 0.272282
# -------------------------------------------------------------------------------------------
# Epoch 19 took total 159.0774631500244 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 4 out of 20
# Epoch 20: Training took 132.77 [s]	Validation took: 27.52 [s]
#
# Epoch: 20 Losses	Training Loss: 0.239109	Validation Loss: 0.273709
# -------------------------------------------------------------------------------------------
# Epoch 20 took total 160.29722547531128 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 5 out of 20
# Epoch 21: Training took 133.05 [s]	Validation took: 26.70 [s]
#
# Epoch: 21 Losses	Training Loss: 0.232458	Validation Loss: 0.275688
# -------------------------------------------------------------------------------------------
# Epoch 21 took total 159.74549913406372 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 6 out of 20
# Epoch 22: Training took 141.13 [s]	Validation took: 28.69 [s]
#
# Epoch: 22 Losses	Training Loss: 0.225965	Validation Loss: 0.277474
# -------------------------------------------------------------------------------------------
# Epoch 22 took total 169.8263897895813 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 7 out of 20
# Epoch 23: Training took 143.53 [s]	Validation took: 27.99 [s]
#
# Epoch: 23 Losses	Training Loss: 0.219826	Validation Loss: 0.282357
# -------------------------------------------------------------------------------------------
# Epoch 23 took total 171.52133440971375 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 8 out of 20
# Epoch 24: Training took 144.01 [s]	Validation took: 28.28 [s]
#
# Epoch: 24 Losses	Training Loss: 0.213231	Validation Loss: 0.283827
# -------------------------------------------------------------------------------------------
# Epoch 24 took total 172.28710055351257 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 9 out of 20
# Epoch 25: Training took 135.36 [s]	Validation took: 27.38 [s]
#
# Epoch: 25 Losses	Training Loss: 0.207370	Validation Loss: 0.287308
# -------------------------------------------------------------------------------------------
# Epoch 25 took total 162.7419741153717 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 10 out of 20
# Epoch 26: Training took 132.01 [s]	Validation took: 26.70 [s]
#
# Epoch: 26 Losses	Training Loss: 0.202279	Validation Loss: 0.289199
# -------------------------------------------------------------------------------------------
# Epoch 26 took total 158.7121639251709 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 11 out of 20
# Epoch 27: Training took 132.30 [s]	Validation took: 26.08 [s]
#
# Epoch: 27 Losses	Training Loss: 0.200656	Validation Loss: 0.290929
# -------------------------------------------------------------------------------------------
# Epoch 27 took total 158.38207721710205 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 12 out of 20

# %%
test_model(test_loader, birnn_model, "Layer-BI-RNN",device, batch_size=batch_size)
# Out:
# #######################
# # Testing Model: Layer-BI-RNN #
# #######################
#
#
# ****************************************************************************
# Predicted -- ye eneaea er a eareortooreaoo
# Utterance -- y algunos jinetes de la guardia se colocaron a derecha e izquierda de la puerta
#
#
# ****************************************************************************
# Predicted -- pe a e a aie snsneess
# Utterance -- por que no decirlo detesto las gazmonerias y melindres
#
#
# ****************************************************************************
# Predicted -- a e s ei anainis esesesiais iesai ia i ene e e eseiae
# Utterance -- aquella borrachera de entusiasmo no producia en nuestros oidos mas impresion que el vuelo de un insignificante insecto
#
#
# ****************************************************************************
# Predicted -- ase a a s o eaoaia a sis o ei is sa s a a a os as a aearosos sei esaecpesesanona e a a e e esesesesss
# Utterance -- hasta fuera de la villa fue en nuestra compania don paco el cual recordaba a su discipulo las maximas de alejandro sobre la guerra recomendandole una y otra vez que las pusiera en practica al pelear contra los franceses
#
#
# ****************************************************************************
# Predicted -- en e i omimsanmiae i ine ae iaia aeaeaei a iaera a iaae
# Utterance -- dijeronme no se que misterios manifestaronme no se que enigmaticos pensamientos que en la turbacion de aquel instante no pude entender
#
#
# ****************************************************************************
# Predicted -- a ea s o anaioisiasasesiaiais ae a e aoaoa o a a o enononoaeaedo andaeaaaaar
# Utterance -- no queriendo aparecer ni aun en sombra por la aborrecida calle de la sal busquelo alla por la alcaldia de casa y corte donde con toda seguridad pensaba encontrarle
#
#
# ****************************************************************************
# Predicted -- pe s a a o s s o s s as es sosaoaosasa ea sa e o a a e raodro
# Utterance -- todo eso es pura farsa sepamos de una vez esos secretos farsa exclamo con enojo el diplomatico ya comprendo el juego
#
#
# ****************************************************************************
# Predicted -- iea eo e ene esosaesisesiersase re oeaeoseososs
# Utterance -- me han dicho antes de la batalla que teneis resentimientos contra mi y que os disponiais a pedirme satisfaccion por no se que agravios
#
#
# ****************************************************************************
# Predicted -- ai a oa aoioro as seso iai a o a ora aioa a eae o ese e e e r oeeo
# Utterance -- las hay de diferentes especies pero en realidad jamas vi en pos de los soldados de la patria ninguna tan hermosa ni de porte tan noble y aristocratico
#
#
# ****************************************************************************
# Predicted -- ea aere seseisesoso n nonoso o s o s eo e e a eseosoi e daeroe  a
# Utterance -- cuanto puede inventarse para distraer a una criatura triste y enferma el lo invento contabame historias unas alegres otras terribles todas de su propia vida
#
#
# ****************************************************************************
# Predicted -- pe o o o s oaraeascas aes e o a misale e e ea e n nornosoaee n on o sss
# Utterance -- eres tu gabriel me dijo como estas por los suelos bonito modo de buscar a la muchacha no esta en el retiro ni
#
#
# ****************************************************************************
# Predicted -- eno o a arsoiosisiaisosaese ae a eaes snaeaetsosasasasroa asas ao il asa esaradiasaasaa
# Utterance -- pues desde mi alcobarincon se distinguia esta muy bien y vi a la inglesa que salia encaminandose a una galeria o solana situada al otro confin del pasillo y de la casa
#
#
# ****************************************************************************
# Predicted -- no e i i os aininoao i e osas o d d e de ee s er
# Utterance -- mira lo que hay alli senalo al fondo del sotano contiguo y vi un arca de hierro juan de dios prosiguio de este modo
#
#
# ****************************************************************************
# Predicted -- yen aore ro eacosas esnsnseneaesesesess
# Utterance -- es una desgracia para nosotros el tener que confesar que no podemos batirnos con los franceses
#
#
# ****************************************************************************
# Predicted -- co e i a ae eo o er e eoadoaoaoadaaa
# Utterance -- comprendi que estaba perdido pero esforceme en conservar la serenidad
#
#
# ****************************************************************************
# Predicted -- ena ea s e eisasaee as nsssetrari
# Utterance -- no hare nunca traicion a mis banderas ya he dicho que no soy espia cest dr le
#
#
# ****************************************************************************
# Predicted -- y o e es esersosos seopeso e r a a a aoioiso o eas onosasoa s s a a e eae
# Utterance -- y luego introducia un rayo de sus ojos por un resquicio para observar lo que dentro pasaba y como si lo que veia y oia la contentase
#
#
# ****************************************************************************
# Predicted -- enon es ero n easasasiosasa iea a a ease ia e ra e a a ea aoao a anan a a  a dn a daa
# Utterance -- el malo no presenta jamas a nuestros ojos cosas aborrecibles ni repugnantes sino antes bien hermosas odoriferas o gratas al paladar al olfato al oido y al tacto
#
#
# ****************************************************************************
# Predicted -- pes e s e eo iasero o o e eoedo re
# Utterance -- pues una mujer de vuestra clase no quiero ofender al senor pero es absurdo monstruoso
#
#
# ****************************************************************************
# Predicted -- nes a ois e n sea eiesroiesesa eseseoesrs
# Utterance -- no sois espanol no teneis en las venas ese fuego sublime que impulsa al hombre a luchar con las imposibilidades
#
#
# ****************************************************************************
# Predicted -- yen ea r on a eioso eaesis e a a eis eroese eiesdesososo dya e e o sososose e esaos
# Utterance -- yo temia ser visto de amaranta pero como esta y su tia habianse adelantado y estaban ya arriba me aventure a seguir al diplomatico que subio detras de todos con ines
#
#
# ****************************************************************************
# Predicted -- ynoaos a i ar s o sa o sas so s o s es a a a o sososnose arasa a a aia ia a ea i io s i a ios o a no e a e a e e a a a ao eno o a n a nde eeas
# Utterance -- ninguno absolutamente ninguno os haceis demasiado honor caballero araceli y solo con pedirme excusas por la vil calumnia solo con asociar vuestra persona a la mia estais faltando al comedimiento si faltando a la consideracion que debe inspirar en todo lo habitado una hija de la gran bretana
#
#
# ****************************************************************************
# Predicted -- e i i i a a ieasasaisia isniaiaiadaodaiaeadoaaaaa
# Utterance -- recibio al principio muy mal la advertencia mas tanto rogue y suplique que al fin consintio en escribir una carta
#
#
# ****************************************************************************
# Predicted -- y o e e e edodae eraeaerereeaeraro ohac
# Utterance -- buen susto nos hadado el picaroncillo pero que ha sido eso nino estaba usia prisionero
#
#
# ****************************************************************************
# Predicted -- e a a o e oesese e e nan a e e s o eo eoeoeoee
# Utterance -- reconocilos yo tambien uno por uno y observe que pequena parte de ellos estaban vivos aunque ferozmente heridos
#
#
# ****************************************************************************
# Predicted -- n e e aoao asesaosasasa esamo aomaosas o osea aa esaien esse a  os
# Utterance -- restituta paso del terror a la sorpresa al asombro al anonadamiento a la estupidez juan de dios exclamo juan de dios
#
#
# ****************************************************************************
# Predicted -- do o ororeodo o os edoreo
# Utterance -- dijo solemnemente bebiendo su te yo no tengo esposo yo soy soltera
#
#
# ****************************************************************************
# Predicted -- qe o o o o o o os o oio is n e e mnrnonaa
# Utterance -- pues yo ire con usted senor don celestino dije con mucha determinacion iremos juntos y vd le pedira un destino para mi
#
#
# ****************************************************************************
# Predicted -- ye a r sr e e e e a o os es eiose a e o eo o nanaen eraeuini
# Utterance -- lo seria en madrid pero no aqui las autoridades le consienten pero no le protegen hace tiempo que ha caido en desgracia le conoces bien
#
#
# ****************************************************************************
# Predicted -- po oan n na oieiois o onon a nrananares nerioaiso aesoeso s s ona ernrnoaaa
# Utterance -- pronto lo hemos de ver en espana porque pasan de cien mil los esplandianes que andan desparramados por ahi esperando que su amo y senor les mande empezar la funcion
#
#
# ****************************************************************************
# Predicted -- si eao s o o o s e en seseoses se eo eoeosososse soro ooo
# Utterance -- si les quiere a ustedes anadio el cura tratando de conciliar la repugnancia que notaba en el semblante de ines con el deseo de los
#
#
# ****************************************************************************
# Predicted -- ea a a a i eiaie an n n e a a iaiaeaaai
# Utterance -- entre los que rugian como fieras y los que se lamentaban heridos o moribundos bajo las pisadas de la multitud
#
#
# ****************************************************************************
# Predicted -- eoa i a a a e o sa ioioesoioasosons oo
# Utterance -- tomando un manojo de llaves y repiqueteando con el no sin cierta intencion zumbona
#
#
# ****************************************************************************
# Predicted -- i s esao io iaio s oe e esesesoseoeeeseree re
# Utterance -- sentiria que usted dejase a espana sin que yo pudiese manifestarle la profundisima gratitud que siento por que caballero
#
#
# ****************************************************************************
# Predicted -- eo ao e a a a o r a o ea o seoea e eosoeoepeo o a e a earnoaraa
# Utterance -- el demonio cargue contigo con el recado con el ayudante y con el general pero me he puesto el corbatin del reves dame aca esa casaca bruto
#
#
# ****************************************************************************
# Predicted -- e a e eae o aomon onod doa oaeomaonoasesaiansnsasas i  ass
# Utterance -- yo soy noble y el senor es militar con que he hablado en terminos generales senora por lo demas mi hija no quiere casarse
#
#
# ****************************************************************************
# Predicted -- pe a a r a o oesesesosooeso o o o o asa s eo o io ei oiadidoi oedoerda
# Utterance -- pero no basta que yo lo diga no basta mi palabra nos conocemos de ayer oh si a ines se le dijera lo que a usted han dicho no lo creeria
#
#
# ****************************************************************************
# Predicted -- es e e a aseses e e aes eiaieisneaiea e ea ea aen eaea e a e nae nandla
# Utterance -- es imposible que siendo tan linda no tenga los pretendientes a millares dijo miss fly mirandola sera posible que esta hermosa nina no ame a nadie
#
#
# ****************************************************************************
# Predicted -- pro aeasasas aioseionsasa o eioao i ae aea eae a a o odadaea alldd
# Utterance -- pero que el afan de no dejar atras aquellos quinientos carros llenos deriquezas les puso en el aprieto de rendirse con la esperanza de salvar el convoy
#
#
# ****************************************************************************
# Predicted -- aeae a nansasososes eneosra oncsos
# Utterance -- tanto se golpeo y machaco en la infortunada linea francesa que la vimos agrietarse romperse desmenuzarse
#
#
# ****************************************************************************
# Predicted -- yeo o oa no asisisansrsns nasas o eseso es e e er uraiaa eeua
# Utterance -- luego le conte como habiendo necesitado del auxilio de los masones para salir de salamanca nos acompanamos de ellos hasta salir a buen trecho de la ciudad
#
#
# ****************************************************************************
# Predicted -- osea a i ioa asisesasalasaaaaa
# Utterance -- mirabamos al bosque y el oscuro ramaje de las encinas no nos decia nada
#
#
# ****************************************************************************
# Predicted -- ie a i es e ao onosa e a ios e e a eranraaaa
# Utterance -- inesilla tu no me quieres tu no puedes quererme por que dices eso pregunto con candor
#
#
# ****************************************************************************
# Predicted -- pu i ero mnras es es nos a ass o o ao e e e aea e o einoni d ea deadra
# Utterance -- ojos que se quieren bien desde lejos se ven senora molichard cuando me deje su merced en el calabozo donde el oficial mando que me pusieran
#
#
# ****************************************************************************
# Predicted -- i e e o easue i a a a aicsais oa i asa a ean a a iaeana mieaeirn
# Utterance -- miss fly miss fly el viento impedia que mi voz llegase hasta ella avive el paso sin apartar los ojos de la hermosa aparicion
#
#
# ****************************************************************************
# Predicted -- ya e a e o oaosos sososo osesos os sa aeonose e r sasasososaa
# Utterance -- no se oyen las pisadas de su caballo y los gritos de entusiasmo con que le saludan los soldados no se ve el resplandor de las hogueras que encienden a su paso
#
#
# ****************************************************************************
# Predicted -- as a e enier a a o aen enar o n ae e a a eo e a e e aeae e etadoad aoe a a dnoaedaa
# Utterance -- vamos le dije tu madre te espera estas libre querida mia y se acabaron para ti el encierro y los martirios de esta casa que es un sepulcro habitado por un loco
#
#
# ****************************************************************************
# Predicted -- i ie ao a a o i i e ielieaeoai
# Utterance -- si en un principio crei ver en juan de dios un poco de artificio e hipocresia
#
#
# ****************************************************************************
# Predicted -- eoaoe e a e asa saeieisai i a a asaseaseasaeas
# Utterance -- de que con la llama de los espinos y de los brezos sin cesar alimentada por ebanos tallados y bordadas telas
#
#
# ****************************************************************************
# Predicted -- aleaoano o n n or aoeoaoaenonenene deae e  ea eeaa
# Utterance -- la desesperacion me dijo luego wellington no es la principal fuente del valor
#
#
# ****************************************************************************
# Predicted -- pe a a eo e ononsnonona isiaosasa ae enoesei seno a a a a a e ieasesss
# Utterance -- te tenia a su lado como un juguete precioso o futil pasatiempo hija mia la holgazaneria la corrupcion y la vanidad de esos grandes
#
#
# ****************************************************************************
# Predicted -- ya o a o o o esos so asa a ao a s se is o s es s sa sa enes s na oaoa  a oaa iuila
# Utterance -- y al punto olvidando la situacion nos hablamos con la confianza de aquellos tiempos en que de nuestras penas haciamos una sola ay chiquilla
#
#
# ****************************************************************************
# Predicted -- a eae e a e esesoe e e eiosrar eooraraeuea
# Utterance -- el gran capitan de esta masoneria ambulante esta postrado en el lecho desde hace tres dias y no puede moverse como quereis que huya
#
#
# ****************************************************************************
# Predicted -- e o e e ao o iaiaiaiad iaaaa
# Utterance -- desde que le conoci en el escorial aquel hombre me habia inspirado inexplicable antipatia
#
#
# ****************************************************************************
# Predicted -- esoao eoe aeoa era e e eae eoe o e ea ue o e o aloooo
# Utterance -- pero exagerando o trastornando de tal manera las ideas que las repudiaria el mismo que por primera vez las echo al mundo
#
#
# ****************************************************************************
# Predicted -- ye an a a a a aseoaoases esasesesesendeoe esesodsesesesesesa era seres
# Utterance -- y el cinto adornado con la guedeja que parecia cabellera arrancada del craneo del vencedor en las salvajes guerras septentrionales
#
#
# ****************************************************************************
# Predicted -- ca i e s ona o o o e aoeaeoe ea o oiei eoe eo y aoa inino dedeioraloo
# Utterance -- cuando volvi estaba sentada junto al lecho del enfermo a quien miraba fijamente volviendo la cabeza indicome con un signo que no debia hacer ruido
#
#
# ****************************************************************************
# Predicted -- i e ererorer otodtpera neni e oasasoasoesaoanasasss
# Utterance -- quien me habia de decir el gran capitan no pudo continuar porque la pena ahogaba su voz
#
#
# ****************************************************************************
# Predicted -- no oi isedesiyi es a o o oaododadade al
# Utterance -- no he visto jormiguita como el sr de lobo y que entusiasmado esta el pueblo espanol con su nuevo rey continuo el
#
#
# ****************************************************************************
# Predicted -- oeuer o seasosesnora
# Utterance -- yo no poseo ciencia alguna respondi exasperado
#
#
# ****************************************************************************
# Predicted -- in r ar a e esros e aso e o eso eroe eo o o e oe osssasas
# Utterance -- sino una multitud de capas que respiraban higienicamente el aire matutino por entre los agujeros de sus remiendos y apolilladuras
#
#
# ****************************************************************************
# Predicted -- eneorm dor osa
# Utterance -- exclame con la mayor sorpresa
#
#
# ****************************************************************************
# Predicted -- aqeae e e oraea sasaose ae eao o oira asas e s es eseso a e o e a orase e e esosesas e e e o o d a osearaesoraneaearodoeo
# Utterance -- apenas disparados los primeros tiros otros muchos franceses extenuados de fatiga y encontrandose ya sin fuerzas para combatir si no les caia del cielo o les brotaba de la tierra una gota de agua
#
#
# ****************************************************************************
# Predicted -- en a a a s s s s o aoln onososooss
# Utterance -- como se reian aquellos condenados lo gracioso es que no me dejaban salir de alli y a cada rato me decian so so so
#
#
# ****************************************************************************
# Predicted -- po se o o o aois a eao aeaes a ontera o a a o e do oa
# Utterance -- trescientos escopeteros que habian salido dios sabe de donde eran capitaneados por el presbitero don ramon de argote
#
#
# ****************************************************************************
# Predicted -- ena i e oao nociaco aiasera oa o acoadodoaosenad
# Utterance -- en cuanto a miss fly me apresuro a nombrarla porque oigo una misma pregunta en los labios de cuantos me escuchan
#
#
# ****************************************************************************
# Predicted -- y o e a ea a eosr oiseasoso s eos a sa sosso e es eses n
# Utterance -- y luego retrocedian haciendo con alegre algazara movimientos de miedo para esconderse despues tras una nube
#
#
# ****************************************************************************
# Predicted --  o aioasoseono a a ei eaoa erasas eoe q qeu e ereoe
# Utterance -- de uniforme lujoso y destrozado en la garganta y seno como si se lo hubiera hecho pedazos con las unas para dar desahogo al oprimido pecho
#
#
# ****************************************************************************
# Predicted -- y o a o o andadenda a i ii
# Utterance -- dijeles que si y poniendose muy contentos me mandaron que diese al punto una corridano queria yo mas para divertirme
#
#
# ****************************************************************************
# Predicted -- poaeo o ae naoe eseae ea aenesa saes esens ns a e sossos
# Utterance -- soldados gemid de rabiay furor
#
#
# ****************************************************************************
# Predicted -- ea e ar osaidesa a aienoa o i
# Utterance -- las dos desconsoladas mujeres vieron todo esto y examinaron los cuerpos uno a uno
#
#
# ****************************************************************************
# Predicted -- a ea o i e aeieioioeoa idrina
# Utterance -- tantas y tan amargas derramo que me senti no ya compasiva sino tambien enternecida
#
#
# ****************************************************************************
# Predicted -- e oe a eno se o oeso oeosoeoenodsoneo e e n i i ialaa nean a  n e
# Utterance -- estuve en la batalla de tamames y en extremadura no se encontro usted en un nuevo asedio en el de cadiz mi general
#
#
# ****************************************************************************
# Predicted -- u e aoa o o a i oa d a a o a o sa s sasosa siancsasss
# Utterance -- su difunto esposo habia sido companero de don mauro en el cargamento y arrastre de fardos y mercancias
#
#
# ****************************************************************************
# Predicted -- co a a e e o a aeo coe i eo e a a a non
# Utterance -- cuando fui al meson a decir a los arrieros que no me aguardaran oi decir lo mismito a unos que estaban alli
#
#
# ****************************************************************************
# Predicted -- na e ae qeuque e a asas ea osos s es s es se ei eses esesesessos
# Utterance -- no el del barandal del cielo que es mas bonito y habla de la virgen anadio el condesito gozoso de hallarse a punto
#
#
# ****************************************************************************
# Predicted -- e aoa a s s s esessin s o o e ueae e da eassreue a
# Utterance -- esto si que esta bueno al cabo de la vejez si nunca me lo has dicho puede que quieras sostener que me lo has dicho que no
#
#
# ****************************************************************************
# Predicted -- i i o a adiaoa eo e de ere r e eoie ninonoion o odal
# Utterance -- no se olvide que aun me duraba el despecho y la sofocacion de la manana el recuerdo de las escenas que antes he descrito completaba mi ceguera
#
#
# ****************************************************************************
# Predicted -- eos e n n ea ao aeaeaeamonemnmoe mn
# Utterance -- lo demas lo sabes tu y no necesito decirtelo esta manana creimos morir aqui
#
#
# ****************************************************************************
# Predicted -- a eai i a aiosaso osdy r ses a asasa saesassssss
# Utterance -- a la salud de maria ciperez muy guapa parece un sol y cuantos la ven la tienen por princesa
#
#
# ****************************************************************************
# Predicted -- nesar en no s e eoeoseso oraosooos
# Utterance -- mientras con angustiosa impaciencia miraba los fusiles del peloton de granaderos
#
#
# ****************************************************************************
# Predicted -- pe o a aoasaa s o  ea
# Utterance -- tenia como veinte anos llamabase andresillo marijuan
#
#
# ****************************************************************************
# Predicted -- cmi o a a ia oai ioidi oa ao a eaenea ea esaoeoeas aaaaoa
# Utterance -- cuando nos dirigiamos juntos al alojamiento del general pedile informes de la dama inglesa cuya figura y extranos modos he dado a conocer y me contesto
#
#
# ****************************************************************************
# Predicted -- eae o esoeo e seoeoeoe o dioieseoeo es e e e rode re ain
# Utterance -- empecela yo y como en ella pusiera no recuerdo que palabras pidiendo perdon enfureciose mucho y dijo
#
#
# ****************************************************************************
# Predicted -- a e a e o nr i ianan
# Utterance -- cuanto se va a alegrar la pobrecita decia para mi
#
#
# ****************************************************************************
# Predicted -- nse o a asa a eaeaso a o nesasasasassaaaaa
# Utterance -- no se lo oculte y el me decia esto acabara pronto no conquistare a los necios sino con esta farsa
#
#
# ****************************************************************************
# Predicted -- yese na e a a e esosose asoso easoeonsnesen aos araaaa
# Utterance -- y usted que piensa me dijo monsalud observandome con curiosidad entraran los aliados en salamanca
#
#
# ****************************************************************************
# Predicted -- pro ie e a a e eaoei eoe o na n e eaea aaaa
# Utterance -- cuando dios me crio dispuso que padeciese y he padecido como ningun otro mortal sobre la tierra
#
#
# ****************************************************************************
# Predicted -- aqeoa e o a ar no o o o o e o sosraosoie e o o e eeo a r s esssss
# Utterance -- tal vez no habria caido tal vez no habria sido rey fernando septimo tal vez no habrian venido los franceses tal vez
#
#
# ****************************************************************************
# Predicted -- ase ao a o ea o nososoieora oa ro o enesesearaa a  o a esas
# Utterance -- marchad fuera a cuidar de los otros enfermos dijo miss fly jovialmente y no vengais a fastidiarnos con vuestras necedades
#
#
# ****************************************************************************
# Predicted -- e io e s uo
# Utterance -- donde le entregaron los pliegos de reding
#
#
# ****************************************************************************
# Predicted -- qe e i a o na eononeriaon
# Utterance -- tu eres un chiquillo y no piensas mas que en jugar y por eso no te importa
#
#
# ****************************************************************************
# Predicted -- n a n o e ea eano e enra en eo e esa esssaas
# Utterance -- no saldran repuso hasta despues de media noche amigo jeanjean quiero que me proporciones un sable y dos pistolas
#
#
# ****************************************************************************
# Predicted -- po s e eroa a aeos s s ers oso s e seao oe o so eods se e s e s seseseoses
# Utterance -- todos los articulos del comercio estaban alli reunidos y hacinados con cierto orden los requejos vendian telas de lana y algodones a saber
#
#
# ****************************************************************************
# Predicted -- ie o ra o seo eieonoesoer ea es e e es s oioeoi eos ei e e ncoea eaoa oiadooo
# Utterance -- el pueblo victoreaba al nuevo rey el plan concebido en las antecamaras de palacio habia sido puesto en ejecucion con el exito mas lisonjero
#
#
# ****************************************************************************
# Predicted -- ye o oa osesos as o o asarases osa oso o oraosdedoaeoss
# Utterance -- y el vestido limpio ya de polvo y lodo disimulaba sus desgarrones y arrugas no se por que arte singular solo revelado a las mujeres
#
#
# ****************************************************************************
# Predicted -- i e r a o eoa e a ea eae nene e   ni aaa
# Utterance -- si me bian dejao le hago porvo con este palo prrun prrun marchen media guelta
#
#
# ****************************************************************************
# Predicted -- qesei n n a eiesnsos aesa s snosa so asosos esos a o o odoldososs
# Utterance -- a fe que si ustedes me dieran la comision de vigilar a la nina cuando salen de casa la nina no se reiria de nosotros
#
#
# ****************************************************************************
# Predicted -- pero o aeoie aeroi a oi ea a aeae e eiana a e ae earansee a a a a alera
# Utterance -- pero estos observando nuestro movimiento y reconociendo al instante su indudable inferioridad invadieron precipitadamente la carretera
#
#
# ****************************************************************************
# Predicted -- e s s e s a a aisaesa o osasasasaamsesssss
# Utterance -- voy a aburrir a mis lectores abusando de la gentil cortesia que les movio a fijar sus ojos en estas
#
#
# ****************************************************************************
# Predicted -- pro e oas e e sa osoe eosaeoso os epr e na iranoa
# Utterance -- prometo que santurrias me las ha de pagar todas juntas pero has visto como se burla de mi ese condenado
#
#
# ****************************************************************************
# Predicted -- adi saoa o asasers esos es esreosers ioe e o o ero e e r ereo e ea oeodoao ae adaarous s ua
# Utterance -- la multitud subia y bajaba abria alacenas rompia tapices volcaba sofas y sillones creyendo encontrar tras alguno de estos muebles al objeto de su ira
#
#
# ****************************************************************************
# Predicted -- ad ese aoa o oa asa o a o o s sre o coroio oass
# Utterance -- ambos libros son muy bonitos y traen un aquel de amores y besos que me daba mucho gusto cuando los leia a escondidas
#
#
# ****************************************************************************
# Predicted -- i e a e nanaosos nsesa s e e a asasansa ea amni e i niamnian i iss
# Utterance -- y diciendole que voy de parte de usted le pintare la situacion en que nos encontramos hablandole tambien de inesilla que es sin duda lo que le interesa mas
#
#
# ****************************************************************************
# Predicted -- pueie e era anosae adoaosasarara a a e e euesedr
# Utterance -- fue un infierno porque todos los demonios todas las maldades y abominaciones cayeron sobre ella
#
#
# ****************************************************************************
# Predicted -- penenana a a e e o osoeoio eiooasnosss
# Utterance -- pero he intentado disuadirle de su empeno porque no posee conocimientos facultativos
#
#
# ****************************************************************************
# Predicted -- a ea ea e eneso o e e eso eo e ea eao e eu e oeqque eorsresioi iu uesss
# Utterance -- ahora cuando ese saladisimo rey que tenemos arregle las cosas hay esperanzas de hacer algo que tiempos restituta que tiempos
#
#
# ****************************************************************************
# Predicted -- eoe a o ao o a dsa a ei s a e e e e e d e eroasesa
# Utterance -- mi adorada suegra tenia la mania de las cartas escribia a todo el mundo y de todos lograba respuesta
#
#
# ****************************************************************************
# Predicted -- e ea s a a esa asaeiaeaia asaenata esa e e aoer eaer a ea
# Utterance -- entre las dos debia desarrollarse al dia siguiente uno de los mas sangrientos dramas del siglo el verdadero prefacio de waterloo
#
#
# ****************************************************************************
# Predicted -- ie e e e oasasaoaeoe e e o esne e o os o e e e a e eaeiesie i i sisi a o o ia a e ea ea e iarioen no
# Utterance -- yo me desespero y lloro en silencio al ver cuan felices son otros frailes de mi orden los cuales disfrutan con la paz mas pura las delicias de visiones santas que son el mas regalado manjar del espiritu
#
#
# ****************************************************************************
# Predicted -- etaseono s ea orea osaenoe ae e a a a e acaeaaa
# Utterance -- el cual se encerro contigo en su gabinete y te confio el plan de su campana contra el austria
#
#
# ****************************************************************************
# Predicted -- ne oroao o a o ononos eseaieoio disi o sososo oieondeno m o o s osssossa
# Utterance -- cuando me encontre en la calle trate de reflexionar para que la razon enfriando mi sofocante ira iluminara un poco mi entendimiento sobre aquel inesperado suceso
#
#
# ****************************************************************************
# Predicted -- e o ao o a a eiaea as ae i ea ieaeiaea a a aeanm e esnse mosaea a  r uae a reli
# Utterance -- lo primero que has de hacer cuando llegues cordoba es visitar a mis primas y entregarles estas cartas mira aqui van las
#
#
# ****************************************************************************
# Predicted -- yases e a eada ea asasea e e e d d d e ea earoe o edadarpre oe e erea
# Utterance -- ya sabe usted que ha venido mucha tropa de madrid y por las calles del pueblo se ve gente de malos modos pero que objeto puede tener ese viaje
#
#
# ****************************************************************************
# Predicted -- e o a e s esesosa asasasasasoaas
# Utterance -- de este modo los franceses piensan embolsarse el poco dinero que han dejado en nuestras arcas
#
#
# ****************************************************************************
# Predicted -- s ase a o oa a m asasase s eoeao aiaiesoao a o e ora r a ra es
# Utterance -- en aquella confusion de gritos de brazos alzados de semblantes infernales de ojos desfigurados por la pasion
#
#
# ****************************************************************************
# Predicted -- aqenona e a as s o is e e a ei ie ae a a o a sosos
# Utterance -- para que todos en una palabra puedan apreciar la buena pronunciacion de usted y su cadencioso oido echenos cualquiera de esos romances que sabe vamos
#
#
# ****************************************************************************
# Predicted -- eoaoe eaerei e e ieien ieieieio ie i eieoiee
# Utterance -- en cuanto a los informes que me exigieron facil me fue conseguir la merced de una recomendacion del regente del diario
#
#
# ****************************************************************************
# Predicted -- s eresae aeoaoasasasasasa asasa aasasesaoasasonaaa
# Utterance -- si fuera a hacer caso de esta compraria tierras y mas tierras a esta no le gustan sino las tierras
#
#
# ****************************************************************************
# Predicted -- a eaoso e ni iananinia nieidon n aa
# Utterance -- agujeraba con entusiasmo su encierro porque habia vislumbrado fuera alguna cosa que tenia la fascinacion de lo nuevo
#
#
# ****************************************************************************
# Predicted -- a eao a arae en ne eneneneneoeo
# Utterance -- a pesar de esta viva crueldad que a veces manifestaba de un modo imponente
#
#
# ****************************************************************************
# Predicted -- eoera e neaea e e e e e e opre ina e ea as a a a ian uea inadonoaal a ens
# Utterance -- ya te dijimos que habiamos determinado casarte con un joven de alto linaje proyecto en el cual estriba la felicidad y grandeza y lustre de la familia a que perteneces
#
#
# ****************************************************************************
# Predicted -- e a o enoao ae a eiese aoeaosoa onesesiosene nosoen e oa e oao aconenoera a e r
# Utterance -- doy las gracias a su eminencia por haber mandado que me devolvieran el burro eminencia me llama usted repuse todavia no me han hecho cardenal
#
#
# ****************************************************************************
# Predicted -- coa ie eoaneodsdye a o e a o n iane onono d eoao oaononanonoss
# Utterance -- toca este instrumento y veras lo bueno el combate llegaba a un extremo de desesperacion y la artilleria enemiga avanzo hacia nosotros
#
#
# ****************************************************************************
# Predicted -- eo a iesea ar eara a asasaseaso eae raora uaaaaa
# Utterance -- todos anhelaban que se firmase de una vez la capitulacion para salir de tan lastimoso estado
#
#
# ****************************************************************************
# Predicted -- ene io o no onseoseso os o eroenono areo oesr eoenosore oe eorso sopes eo e eoeoi e e eere o ee
# Utterance -- veo que usted ha leido mucho mi enemigo no es tal como usted le pinta es un viejo enfermo pues entonces senora araceli dijo athenais con disgusto
#
#
# ****************************************************************************
# Predicted -- y s e ao as tia a rs etnosay eso e e e a aeost e ea allaleda
# Utterance -- y que moncey sale manana de aqui para valencia y que lefebvre que esta en pamplona ira pronto sobre la capital de aragon
#
#
# ****************************************************************************
# Predicted -- ao es a o s ien e e eue no ri eo e
# Utterance -- la condesa dijo a ines hija mia tienes inconveniente en casarte con gabriel
#
#
# ****************************************************************************
# Predicted -- a a ea o o a a ayaoa a o o a o a o oa a a o d
# Utterance -- astamos ya hasta el ganote y ahora no hay naa mas sino dejarse de pedricar y coger las armas pacabar con godoy
#
#
# ****************************************************************************
# Predicted -- co n s o es no ene esi oeis enotoese ona a d a aa
# Utterance -- con una camisa limpia que me presto el cura quede en disposicion segun el mismo me dijo de presentarme aunque fuera a napoleon bonaparte
#
#
# ****************************************************************************
# Predicted -- a eseses sos oneneoesosossese e oss
# Utterance -- una larga pieza de tela que se arrolla en el cuerpo como la faja que ponen a los ninos
#
#
# ****************************************************************************
# Predicted -- ie a e e e osoeoeoesoe
# Utterance -- miss fly se levanto senora le dije con el mayor respeto
#
#
# ****************************************************************************
# Predicted -- e r e si i ais a ea e aiei ienoiea i asoaone endyeroso s e era
# Utterance -- mas tuve el disgusto de saber que su excelencia la senora condesa estaba en camino de andalucia desesperado regrese al centro de madrid
#
#
# ****************************************************************************
# Predicted -- e o a o a eason sosasea e o ss
# Utterance -- el uno subia mientras el otro bajaba en aquel instante debi de decir algo mas sustancioso que los primitivos sis
#
#
# ****************************************************************************
# Predicted -- etono oro ososeoe oso esos e e e e o e e e esesesoedeaeoroa qquea i iasiaue qe a
# Utterance -- ese asombro indefinible que sentimos en el momento de observar la falta o perdida de un objeto que poco antes llevabamos y miss fly
#
#
# ****************************************************************************
# Predicted -- po a e a a a d ieies aemndedin e a nmne o oaos
# Utterance -- todos los arbitrios de la caridad son inutiles y el dinero busca alimentos sin encontrarlos
#
#
# ****************************************************************************
# Predicted -- e aoas soaeo s sa s sesosos sa e a lae naaa
# Utterance -- nos despedimos el bravo ciperez y yo dandonos fuertes apretones de manos y segui a buen paso mi camino
#
#
# ****************************************************************************
# Predicted -- e a a n a an eneneone ietioioonm io
# Utterance -- esta revelacion me dejo tan suspensa tan asombrada que por un instante perdi el sentido
#
#
# ****************************************************************************
# Predicted -- pe o e a a disadeso a a o e osaeesie o no o o a n nao
# Utterance -- crei entender oh cielos que me amenazaba un interrogatorio severo al cual seguirian rigurosas medidas penales contra mi
#
#
# ****************************************************************************
# Predicted -- qe e mno aoa oaha a a a o enro e o on on onanenaenna
# Utterance -- quieres verlo pues toma aun no lo habia dicho cuando rapida fuerte y destructora como un ariete romano
#
#
# ****************************************************************************
# Predicted -- pera na e e esreoeenososes
# Utterance -- fortuna vil prostituta por que te invocan los hombres
#
#
# ****************************************************************************
# Predicted -- doe de o o sasodod o o d s s e s es sosereninaa
# Utterance -- yo se el romance de la reina mora grito don diego batiendo palmas lo echo venga
#
#
# ****************************************************************************
# Predicted -- prao o eos e e se o esio eios cs siese se eoe e eoeroeies
# Utterance -- pero atended ahora que lejos de ser tarde es esta la ocasion propicia de hacerlo segun el refran que dice
#
#
# ****************************************************************************
# Predicted -- ea a a aioa oe a aoada a o a ioaoaoaiaoaoa adao o d o oa e edoeoeooddddadoo
# Utterance -- en los puntos lejanos las columnas de humo eran en mayor numero y cada una indicaba la troj o panera que caia bajo la planta de fuego del ejercito fugitivo
#
#
# ****************************************************************************
# Predicted -- pa eaea n eaesasoao esas s erese s eses eseoseoeso dose os eosaa en
# Utterance -- pero a todas estas la multitud que ocupa la taberna se levanta obedeciendo a la orden de un hombre que alli se presento de improviso salieron todos
#
#
# ****************************************************************************
# Predicted -- ie n n e ea e en na s eae eino e ei o a n a d a i adaoi oi a nas
# Utterance -- mi desesperacion no tuvo limites y ahora celebro no haber tenido en aquel momento un punal en mi mano porque de seguro le hubiera partido el corazon al leguleno trapisondista
#
#
# ****************************************************************************
# Predicted -- ye a e e eieis ese ois e e eiso sr o eaea e e esss
# Utterance -- mi tenaz proyecto se explica por el estado de desesperacion en que me puso la visita de los requejos y su proposito de cargar con la pobre ines
#
#
# ****************************************************************************
# Predicted -- yi ue e a d o o a aoadadaaao
# Utterance -- bien pudo usted haberlos traido dijo grunendo la vieja
#
#
# ****************************************************************************
# Predicted -- ye aoenraon a i eaeasasases sasasasaaaas
# Utterance -- y el crater de nuestra venganza esputaba lo mismo el puro fuego que las pestilentes lavas
#
#
# ****************************************************************************
# Predicted -- co s se e r ro eaeasosoiesosaiaesosrs eao a a aaaa
# Utterance -- como estaba vestido facil me fue levantarme en un momento y dirigirme hacia ella con paso quedo para no asustarla
#
#
# ****************************************************************************
# Predicted -- yde o a na n oaoeone enoano a o o eo e os aeoeo oeoe sa eaa
# Utterance -- muy luego convencime de lo contrario y aquel santo varon arrojado por las tempestades mundanas a la vida contemplativa y austera
#
#
# ****************************************************************************
# Predicted -- qeao s osa eoeoaoioir ose a a saeoa a e edyo e a sas a aia daoesasoe oeaonroaa
# Utterance -- aqui todos quieren saber tanto como los que mandan de modo que se oyen unos disparates lo de portugal ha resultado muy distinto de lo que se creia
#
#
# ****************************************************************************
# Predicted -- enmo e e sisis esosoia iosy e n s n rdedorr
# Utterance -- mi amo tuvo el gusto de plantear por si mismo el nuevo sistema dispuso que ines no saldria de su cuarto ni para comer
#
#
# ****************************************************************************
# Predicted -- pro seranoneae e a araladaoaeaoaedad rr
# Utterance -- que rehechos con un destacamento que habia llegado de linares trataban de ganar lo perdido
#
#
# ****************************************************************************
# Predicted -- en a a a o o onocoraorra
# Utterance -- estaba el ama a las cuatro de la tarde sentada en el cuarto de la costura
#
#
# ****************************************************************************
# Predicted -- ie i a e e erene eneido
# Utterance -- el dia dieciocho el arrabal donde yo estaba diome idea de como es el infierno
#
#
# ****************************************************************************
# Predicted -- e a ea a araaa
# Utterance -- despues que me abrace a la santa cruz para salvarme
#
#
# ****************************************************************************
# Predicted -- q no a a e a nsa o era as e e e a a a eaea esro earnsa e oa e esesaass
# Utterance -- cuyo unico apoyo material era una depresion del terreno una especie de zanja sin profundidad que parecia marcar el linde entre dos heredades
#
#
# ****************************************************************************
# Predicted -- e a e e a a a aea oa o ontene aea e e a e o o o aeaoaoadododadoaaaale
# Utterance -- despues de vacilar un momento entre la seriedad y una sonrisa se apreto el corazon con ambas manos y me dijo gabriel
#
#
# ****************************************************************************
# Predicted -- qes o e a r oarosodeoro a a n o r a e no o a oao oeoaeano nmnono nemao e e o a
# Utterance -- y que pronto se murio la pobrecita ya que paso a mejor vida aquella santa y ejemplar mujer dijo restituta no la nombremos
#
#
# ****************************************************************************
# Predicted -- yeaeas e r o aeanea e aeae eaaa dedd ae e a
# Utterance -- y como los franceses se establezcan en espana veras la que armo  padre le decia yo
#
#
# ****************************************************************************
# Predicted -- ye a ao s s a esa s esesa s s eiesois taoaisoa ao qer oe  oes s
# Utterance -- muchos oficiales se han fugado sin que en los cuarteles ni en sus casas se sepa donde estan y diras tu pues donde estan  yo lo se
#
#
# ****************************************************************************
# Predicted -- es e s aose erar erararaa
# Utterance -- es usted el senor chantre de la catedral de astorga que viene a
#
#
# ****************************************************************************
# Predicted -- no ea n iaia di aincnrneneaa
# Utterance -- y no era aquella ocasion a proposito para que me diera la llave falsificada que hacia falta
#
#
# ****************************************************************************
# Predicted -- ms a aeo e a o a ea ea e e ie n niyssye ali aroa a a nrnrnranran
# Utterance -- nunca mas vera usted a su madre bien sabia yo que no eras capaz de la infamia de abandonarme
#
#
# ****************************************************************************
# Predicted -- dedoe a r ar a aodae o e aaa
# Utterance -- verde ahora con picos despues con curvas mas tarde irradiado
#
#
# ****************************************************************************
# Predicted -- eae e o ea era a eoaeoe e e e e dedoaodea
# Utterance -- ya no tengo piernas traes tu polvora dame aca yo te cargare el fusil pero me caigo redondo
#
#
# ****************************************************************************
# Predicted -- aie eaiasieaeaiea a oao oa s isala eimi a a s a a oea e eaealaea e e e e
# Utterance -- parecianme disparates sus consejos y los obedecia aquella inmensidad de su pensamiento tan distante de la realidad me seducia
#
#
# ****************************************************************************
# Predicted -- a ea o e ne n or eio noieoeio oa amaoeaeo a aso o o a s a o sa sasoios o oraos es osas asoso eansesa a a e oaa
# Utterance -- aunque al traves del tiempo nos parezca lo contrario entonces se chillaba mucho y tambien habia quien tomara muy a pechos los asuntos de la guerra solo por el simple placer de meter ruido y tambien para hacerse notar
#
#
# ****************************************************************************
# Predicted -- asiea ea ea a a iae eioe it o o e e e eia cinedoi a a ea iaaaa
# Utterance -- llamando a mi asistente que estaba en la calle le di orden de que proporcionase a ines cuanto fuese preciso y existiera en el lugar
#
#
# ****************************************************************************
# Predicted -- ye aearo araraeapaeanan essas
# Utterance -- los franceses les llevan a la fuerza aparteme a un lado por temor a que mi curiosidad infundiese sospechas
#
#
# ****************************************************************************
# Predicted -- que a i nea eaoa ieiaieiesieiar eieois eeo
# Utterance -- tienes algun amigo que quiera ganarse unos cuantos doblones y que ademas sea valiente sereno y discreto
#
#
# ****************************************************************************
# Predicted -- tea eoe oa eo nie a e eoeosod o deoeoe sopes a aa
# Utterance -- acercose a amaranta y mostrandole un medallon que en la mano traia le dijo te gusta no es verdad que esta parecido
#
#
# ****************************************************************************
# Predicted -- u oereo ioiar a iaia aero ieieie a a a n e eaer
# Utterance -- sucedio que los pobres masones igualmente malquistos con los franceses que salian y los espanoles que entraban en babilafuente
#
#
# ****************************************************************************
# Predicted -- io o o o o er eare e ae e d dieraa
# Utterance -- no hay cuidado por eso despues de habersela dado me entro tentacion de hablar con ella
#
#
# ****************************************************************************
# Predicted -- eaes e aoiaos a aea oru ao aeae eoadese o e eoerueooro
# Utterance -- despues del avance de nuestras tropas que no ocuparon enteramente las posiciones francesas por ofrecer esto algun peligro
#
#
# ****************************************************************************
# Predicted -- a e e o e ecicso o o ed ospes o e aeno nr
# Utterance -- pero si apenas puedo creerlo exclamaba mi ama
#
#
# ****************************************************************************
# Predicted -- i soa se o os a sa o a orooosoas
# Utterance -- juan de dios exhalo un suspiro profundisimo y despues bajo los ojos
#
#
# ****************************************************************************
# Predicted -- deso s ona eara esoses a a an asa lals
# Utterance -- lo que yo sospechaba y ahora se me revela por completo tiene tanta belleza como las mentiras de las novelas y romances
#
#
# ****************************************************************************
# Predicted -- eo a a asasasasa a isaisie eaeisas aea a s ono s e s sosossis
# Utterance -- el antiguo mancebo de don mauro requejo estaba tan demacrado tan excesivamente amarillo y mustio que parecia haber vivido diez anos de penas en el trascurso de algunos dias
#
#
# ****************************************************************************
# Predicted -- aqes i ia io o a s ioso s e e eope o ueueane
# Utterance -- ahora que eres archiduquesa y archipampana no tienes verguenza de quererme pero que quieren hacer de mi
#
#
# ****************************************************************************
# Predicted -- y eo e o n imaisa emaisis eie e o s oos
# Utterance -- no tuviese completa seguridad de ser respetada miss fly es duena de sus acciones le conteste
#
#
# ****************************************************************************
# Predicted -- ay a io e i oies s iadadsa lyio o er e eneasses
# Utterance -- ay que voces que gritos mi tio se echo a llorar y dijo tambien viva espana tres veces
#
#
# ****************************************************************************
# Predicted -- y a no a sa a a a oa asa o so ere ouo a a s eso iososasdoodsodososo
# Utterance -- grito intentando incorporarse con esfuerzos dolorosos todavia puedo hacer algo esto pasara no es nada aun tengo pulso
#
#
# ****************************************************************************
# Predicted -- si eses e a m a e e oease e e e e ses e eieseseoesesoso oi eeei d un
# Utterance -- si quieres que no la ame mas que a ti damela nuncate he pedido nada con ella sere bueno sin ella sere lo que el demonio quiera
#
#
# ****************************************************************************
# Predicted -- pao e e o o aoasaosnoneidens aroarao esesos aeaea esr srasae e arao a e as a aeaessas
# Utterance -- trajeron despues botellas de vino de jerez que en un santiamen dejaron como cuerpos sin alma porque toda ella paso a fortificar las de aquellos claros varones
#
#
# ****************************************************************************
# Predicted -- que a ne eon dodoneso o a oono aoa na e a eoeosadeoe eae aea o n onanaaaa
# Utterance -- que dia senor san antonio de mi alma que dia yo me encargare del mocito dijo lobo lo unico que les pido es que me lo guarden hasta manana
#
#
# ****************************************************************************
# Predicted -- ue ano a a aas
# Utterance -- que no alzaron la cabeza para mirarnos
#
#
# ****************************************************************************
# Predicted -- ye o or de ero
# Utterance -- y helos aqui que por grados perdian la serenidad
#
#
# ****************************************************************************
# Predicted -- eno e s oao a a sasaoes a ao es a aoeaea e es s e a o e deo e e a eaeaneerea e eaaa
# Utterance -- anadiendo que si ella probara tan solo un buche de tal enjuagadero de tripas arrojaria por la boca juntamente con los higados la primer leche que mamo
#
#
# ****************************************************************************
# Predicted -- ao s ses a ara nsasesnensasesesesosonaenos anin nco mosasoa
# Utterance -- al poco rato ya no pensaba mas que en volver a mi casa donde suponia a ines en penosa angustia por mi ausencia
#
#
# ****************************************************************************
# Predicted -- eio a ro eise e e eipeye o eneraoesea esses
# Utterance -- a fe que mi marido hace buenas migas con los masones el y yo detestamos el populacho y adoramos a reyes y frailes
#
#
# Test set: Average loss: -0.3135, Average CER: 0.717957 Average WER: 1.0034

# %%
(convbigru_model, conv_bigru_train_losses, conv_bigru_valid_losses) = train(n_epochs=epochs, train_loader=train_loader, valid_loader=valid_loader,
                                                                          model=conv_bigru_net, criterion=criterion, clip=clip,
                                                                          device=device, lr=lr, batch_size=batch_size,
                                                                          save_model_path=SAVE_RESULTS_PATH+"/conv_bigru",
                                                                          save_pkl_path=SAVE_MODELS_PATH + "/training_conv_bigru_results.pkl")
# Out:
# #######################
# #  Start Training    #
# #######################
# Epoch 1: Training took 149.15 [s]	Validation took: 28.43 [s]
#
# Epoch: 1 Losses	Training Loss: 0.310154	Validation Loss: 0.288712
# -------------------------------------------------------------------------------------------
# Epoch 1 took total 177.5842320919037 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (inf --> 0.288712).  Saving model ...
# Epoch 2: Training took 148.40 [s]	Validation took: 27.77 [s]
#
# Epoch: 2 Losses	Training Loss: 0.287672	Validation Loss: 0.277235
# -------------------------------------------------------------------------------------------
# Epoch 2 took total 176.16771936416626 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.288712 --> 0.277235).  Saving model ...
# Epoch 3: Training took 149.79 [s]	Validation took: 27.79 [s]
#
# Epoch: 3 Losses	Training Loss: 0.283747	Validation Loss: 0.279905
# -------------------------------------------------------------------------------------------
# Epoch 3 took total 177.58524203300476 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 4: Training took 149.49 [s]	Validation took: 26.81 [s]
#
# Epoch: 4 Losses	Training Loss: 0.279026	Validation Loss: 0.273565
# -------------------------------------------------------------------------------------------
# Epoch 4 took total 176.30058598518372 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.277235 --> 0.273565).  Saving model ...
# Epoch 5: Training took 149.53 [s]	Validation took: 26.98 [s]
#
# Epoch: 5 Losses	Training Loss: 0.274396	Validation Loss: 0.265346
# -------------------------------------------------------------------------------------------
# Epoch 5 took total 176.51888179779053 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.273565 --> 0.265346).  Saving model ...
# Epoch 6: Training took 149.33 [s]	Validation took: 27.42 [s]
#
# Epoch: 6 Losses	Training Loss: 0.271191	Validation Loss: 0.267888
# -------------------------------------------------------------------------------------------
# Epoch 6 took total 176.74490785598755 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 7: Training took 147.86 [s]	Validation took: 26.82 [s]
#
# Epoch: 7 Losses	Training Loss: 0.261015	Validation Loss: 0.249246
# -------------------------------------------------------------------------------------------
# Epoch 7 took total 174.68061876296997 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.265346 --> 0.249246).  Saving model ...
# Epoch 8: Training took 148.60 [s]	Validation took: 27.01 [s]
#
# Epoch: 8 Losses	Training Loss: 0.252291	Validation Loss: 0.243041
# -------------------------------------------------------------------------------------------
# Epoch 8 took total 175.61837363243103 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.249246 --> 0.243041).  Saving model ...
# Epoch 9: Training took 148.48 [s]	Validation took: 26.62 [s]
#
# Epoch: 9 Losses	Training Loss: 0.246383	Validation Loss: 0.244087
# -------------------------------------------------------------------------------------------
# Epoch 9 took total 175.10137391090393 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 10: Training took 146.95 [s]	Validation took: 27.21 [s]
#
# Epoch: 10 Losses	Training Loss: 0.235253	Validation Loss: 0.237485
# -------------------------------------------------------------------------------------------
# Epoch 10 took total 174.16009092330933 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.243041 --> 0.237485).  Saving model ...
# Epoch 11: Training took 147.79 [s]	Validation took: 27.84 [s]
#
# Epoch: 11 Losses	Training Loss: 0.224351	Validation Loss: 0.225111
# -------------------------------------------------------------------------------------------
# Epoch 11 took total 175.6295096874237 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.237485 --> 0.225111).  Saving model ...
# Epoch 12: Training took 146.46 [s]	Validation took: 27.71 [s]
#
# Epoch: 12 Losses	Training Loss: 0.212028	Validation Loss: 0.217494
# -------------------------------------------------------------------------------------------
# Epoch 12 took total 174.17188549041748 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.225111 --> 0.217494).  Saving model ...
# Epoch 13: Training took 148.83 [s]	Validation took: 30.20 [s]
#
# Epoch: 13 Losses	Training Loss: 0.196742	Validation Loss: 0.219902
# -------------------------------------------------------------------------------------------
# Epoch 13 took total 179.03083562850952 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 14: Training took 157.22 [s]	Validation took: 29.21 [s]
#
# Epoch: 14 Losses	Training Loss: 0.182163	Validation Loss: 0.209883
# -------------------------------------------------------------------------------------------
# Epoch 14 took total 186.43049573898315 seconds
# -------------------------------------------------------------------------------------------
# Validation loss decreased (0.217494 --> 0.209883).  Saving model ...
# Epoch 15: Training took 149.00 [s]	Validation took: 28.44 [s]
#
# Epoch: 15 Losses	Training Loss: 0.167194	Validation Loss: 0.212694
# -------------------------------------------------------------------------------------------
# Epoch 15 took total 177.44652938842773 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 1 out of 20
# Epoch 16: Training took 150.17 [s]	Validation took: 29.35 [s]
#
# Epoch: 16 Losses	Training Loss: 0.151826	Validation Loss: 0.210002
# -------------------------------------------------------------------------------------------
# Epoch 16 took total 179.51947951316833 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 2 out of 20
# Epoch 17: Training took 150.92 [s]	Validation took: 29.40 [s]
#
# Epoch: 17 Losses	Training Loss: 0.137788	Validation Loss: 0.220332
# -------------------------------------------------------------------------------------------
# Epoch 17 took total 180.32335901260376 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 3 out of 20
# Epoch 18: Training took 152.70 [s]	Validation took: 30.44 [s]
#
# Epoch: 18 Losses	Training Loss: 0.123736	Validation Loss: 0.218948
# -------------------------------------------------------------------------------------------
# Epoch 18 took total 183.1394567489624 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 4 out of 20
# Epoch 19: Training took 152.87 [s]	Validation took: 29.39 [s]
#
# Epoch: 19 Losses	Training Loss: 0.109974	Validation Loss: 0.228668
# -------------------------------------------------------------------------------------------
# Epoch 19 took total 182.2530415058136 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 5 out of 20
# Epoch 20: Training took 154.08 [s]	Validation took: 29.60 [s]
#
# Epoch: 20 Losses	Training Loss: 0.099924	Validation Loss: 0.231395
# -------------------------------------------------------------------------------------------
# Epoch 20 took total 183.67970275878906 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 6 out of 20
# Epoch 21: Training took 155.17 [s]	Validation took: 29.04 [s]
#
# Epoch: 21 Losses	Training Loss: 0.089822	Validation Loss: 0.244403
# -------------------------------------------------------------------------------------------
# Epoch 21 took total 184.21615600585938 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 7 out of 20
# Epoch 22: Training took 155.28 [s]	Validation took: 28.14 [s]
#
# Epoch: 22 Losses	Training Loss: 0.080173	Validation Loss: 0.248439
# -------------------------------------------------------------------------------------------
# Epoch 22 took total 183.41588282585144 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 8 out of 20
# Epoch 23: Training took 154.23 [s]	Validation took: 28.04 [s]
#
# Epoch: 23 Losses	Training Loss: 0.072836	Validation Loss: 0.262708
# -------------------------------------------------------------------------------------------
# Epoch 23 took total 182.26736617088318 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 9 out of 20
# Epoch 24: Training took 154.33 [s]	Validation took: 28.39 [s]
#
# Epoch: 24 Losses	Training Loss: 0.066564	Validation Loss: 0.264555
# -------------------------------------------------------------------------------------------
# Epoch 24 took total 182.7222900390625 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 10 out of 20
# Epoch 25: Training took 153.86 [s]	Validation took: 27.42 [s]
#
# Epoch: 25 Losses	Training Loss: 0.060676	Validation Loss: 0.272960
# -------------------------------------------------------------------------------------------
# Epoch 25 took total 181.2789433002472 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 11 out of 20
# Epoch 26: Training took 154.80 [s]	Validation took: 28.51 [s]
#
# Epoch: 26 Losses	Training Loss: 0.056951	Validation Loss: 0.277736
# -------------------------------------------------------------------------------------------
# Epoch 26 took total 183.31603622436523 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 12 out of 20
# Epoch 27: Training took 152.39 [s]	Validation took: 27.65 [s]
#
# Epoch: 27 Losses	Training Loss: 0.054065	Validation Loss: 0.280467
# -------------------------------------------------------------------------------------------
# Epoch 27 took total 180.0341980457306 seconds
# -------------------------------------------------------------------------------------------
# EarlyStopping counter: 13 out of 20

# %%
test_model(test_loader, convbigru_model, "CONV-BI-RNN", device, batch_size=batch_size)
# Out:
# #######################
# # Testing Model: CONV-BI-RNN #
# #######################
#
#
# ****************************************************************************
# Predicted -- ya lgenos ens de boaba erulara n aderch ay cie de de la corta
# Utterance -- y algunos jinetes de la guardia se colocaron a derecha e izquierda de la puerta
#
#
# ****************************************************************************
# Predicted -- porque mo e herlo desteo adade madadeda sises esesinteses
# Utterance -- por que no decirlo detesto las gazmonerias y melindres
#
#
# ****************************************************************************
# Predicted -- aquelogratedar entechas no o outandos o e o no onosien en eieienenineitietenteane
# Utterance -- aquella borrachera de entusiasmo no producia en nuestros oidos mas impresion que el vuelo de un insignificante insecto
#
#
# ****************************************************************************
# Predicted -- as a perlarela bila perdes ua cja ca a a a a e e e e e ea ae a e e i e iea a ea a ea aea a e e e c a cecececeneseses
# Utterance -- hasta fuera de la villa fue en nuestra compania don paco el cual recordaba a su discipulo las maximas de alejandro sobre la guerra recomendandole una y otra vez que las pusiera en practica al pelear contra los franceses
#
#
# ****************************************************************************
# Predicted -- dijeononde enos u icio o un ce n eo e u ue u u e ue eu e u un eu n e e o o unenontnroro
# Utterance -- dijeronme no se que misterios manifestaronme no se que enigmaticos pensamientos que en la turbacion de aquel instante no pude entender
#
#
# ****************************************************************************
# Predicted -- no puebieovo pe uno e oapa a a a e a a a e ara eo a e eo eo ece o reo oreor ore o ororeorororororoeo
# Utterance -- no queriendo aparecer ni aun en sombra por la aborrecida calle de la sal busquelo alla por la alcaldia de casa y corte donde con toda seguridad pensaba encontrarle
#
#
# ****************************************************************************
# Predicted -- perodo ses pura para e omun eso s us o er re ue u e e e a e r re erer a a a e aeor eororapororo
# Utterance -- todo eso es pura farsa sepamos de una vez esos secretos farsa exclamo con enojo el diplomatico ya comprendo el juego
#
#
# ****************************************************************************
# Predicted -- me d tit e lba aeutetne e et teto snouena aisos eis a e e ea e aoa e eo e deseadas
# Utterance -- me han dicho antes de la batalla que teneis resentimientos contra mi y que os disponiais a pedirme satisfaccion por no se que agravios
#
#
# ****************************************************************************
# Predicted -- la ae e ie rente prestrir ernrorce eneoeo o e deo eoreo eonence eo eoeoceo co ieca ereirirorocaeoaeiporororcioo
# Utterance -- las hay de diferentes especies pero en realidad jamas vi en pos de los soldados de la patria ninguna tan hermosa ni de porte tan noble y aristocratico
#
#
# ****************************************************************************
# Predicted -- cano vreidentase as uera ama ce y ea a oaea aroar oao o a co s s e e e e a eocoleaer re e ereorosieariaia
# Utterance -- cuanto puede inventarse para distraer a una criatura triste y enferma el lo invento contabame historias unas alegres otras terribles todas de su propia vida
#
#
# ****************************************************************************
# Predicted -- que es pui u bab en i i o s oeo e e e e e e e e o eoeoedeo o e eo eo eo oe e sosestseso
# Utterance -- eres tu gabriel me dijo como estas por los suelos bonito modo de buscar a la muchacha no esta en el retiro ni
#
#
# ****************************************************************************
# Predicted -- es en aoda e con ciaia as ama a y a a a a e mema oaea a o a a amla ca sa a eosa a a a mec i lo lo ea a a asasasasasasa
# Utterance -- pues desde mi alcobarincon se distinguia esta muy bien y vi a la inglesa que salia encaminandose a una galeria o solana situada al otro confin del pasillo y de la casa
#
#
# ****************************************************************************
# Predicted -- miro l e e e re ne o o eieneo oeo o denososososode do o eo odosdesnutan oro
# Utterance -- mira lo que hay alli senalo al fondo del sotano contiguo y vi un arca de hierro juan de dios prosiguio de este modo
#
#
# ****************************************************************************
# Predicted -- qe ma redae arn s torpcenece cecea ron o cn n a enaca caces
# Utterance -- es una desgracia para nosotros el tener que confesar que no podemos batirnos con los franceses
#
#
# ****************************************************************************
# Predicted -- cono e i s sa perbi e es oreaea a asasiadad
# Utterance -- comprendi que estaba perdido pero esforceme en conservar la serenidad
#
#
# ****************************************************************************
# Predicted -- nahave enca tarecela misra bera yio o e e me e aililisi ioeolo
# Utterance -- no hare nunca traicion a mis banderas ya he dicho que no soy espia cest dr le
#
#
# ****************************************************************************
# Predicted -- yi uergogno d m ad do co c u n e de e d o dei e a i i e e e e a es eaenesase
# Utterance -- y luego introducia un rayo de sus ojos por un resquicio para observar lo que dentro pasaba y como si lo que veia y oia la contentase
#
#
# ****************************************************************************
# Predicted -- tel amao me enten co co a co os o ce a a a a c a a a ca cacac aca a ca a o ca a c cacaca ca con acaoacao a o o aoararatatro
# Utterance -- el malo no presenta jamas a nuestros ojos cosas aborrecibles ni repugnantes sino antes bien hermosas odoriferas o gratas al paladar al olfato al oido y al tacto
#
#
# ****************************************************************************
# Predicted -- pue e s un ce s tesu o ouo u u es s u usususuousususososo
# Utterance -- pues una mujer de vuestra clase no quiero ofender al senor pero es absurdo monstruoso
#
#
# ****************************************************************************
# Predicted -- nose sestno y no ete ns s sun s s s is os s s sens
# Utterance -- no sois espanol no teneis en las venas ese fuego sublime que impulsa al hombre a luchar con las imposibilidades
#
#
# ****************************************************************************
# Predicted -- de penias aeas ea arna a cos co a ca a a co o a a a o a a e aoe o o i oe e aoco o o o o o e o eo eo ososososoeo oseses
# Utterance -- yo temia ser visto de amaranta pero como esta y su tia habianse adelantado y estaban ya arriba me aventure a seguir al diplomatico que subio detras de todos con ines
#
#
# ****************************************************************************
# Predicted -- mon inmus asiata o mo po m so a o a mo a a e a e a a a a a mo a a a no do e aormo
# Utterance -- ninguno absolutamente ninguno os haceis demasiado honor caballero araceli y solo con pedirme excusas por la vil calumnia solo con asociar vuestra persona a la mia estais faltando al comedimiento si faltando a la consideracion que debe inspirar en todo lo habitado una hija de la gran bretana
#
#
# ****************************************************************************
# Predicted -- purpilala de licio un a e rerercia cuscu o couo o o ci o i ia ei a aeuararacararta
# Utterance -- recibio al principio muy mal la advertencia mas tanto rogue y suplique que al fin consintio en escribir una carta
#
#
# ****************************************************************************
# Predicted -- cuel cuchnos aro bel ticaro cio u i eie eieue o o oereoeoeodoro
# Utterance -- buen susto nos hadado el picaroncillo pero que ha sido eso nino estaba usia prisionero
#
#
# ****************************************************************************
# Predicted -- el consio do se oanbie o u uo lese e e e e eo e e eo o e e do e e e demeimetro
# Utterance -- reconocilos yo tambien uno por uno y observe que pequena parte de ellos estaban vivos aunque ferozmente heridos
#
#
# ****************************************************************************
# Predicted -- resesptpa os r po pro as a ada a m ma ieia a a a i ea a ai i a a i eios sens ansamoiosisosososos
# Utterance -- restituta paso del terror a la sorpresa al asombro al anonadamiento a la estupidez juan de dios exclamo juan de dios
#
#
# ****************************************************************************
# Predicted -- dijos el memen pededindesiutu dedme e ue e e es oese voelel eltera
# Utterance -- dijo solemnemente bebiendo su te yo no tengo esposo yo soy soltera
#
#
# ****************************************************************************
# Predicted -- que su le conuse sne ven el i e n u u i i i i u n n in e en n snen nano
# Utterance -- pues yo ire con usted senor don celestino dije con mucha determinacion iremos juntos y vd le pedira un destino para mi
#
#
# ****************************************************************************
# Predicted -- les aria ed dar i eroma ai ao e e e e e e e e ae eo eo e e e de dedede ededirioneninon
# Utterance -- lo seria en madrid pero no aqui las autoridades le consienten pero no le protegen hace tiempo que ha caido en desgracia le conoces bien
#
#
# ****************************************************************************
# Predicted -- coronpo do ere en ento oe qu a e a a a ea a ae a a ea a a o a e e ea eo ae a e a ea e aiara
# Utterance -- pronto lo hemos de ver en espana porque pasan de cien mil los esplandianes que andan desparramados por ahi esperando que su amo y senor les mande empezar la funcion
#
#
# ****************************************************************************
# Predicted -- sile ese e e eu e e aera a o rora iea a a eno eae a eao i e eo e e orero oeoroerera
# Utterance -- si les quiere a ustedes anadio el cura tratando de conciliar la repugnancia que notaba en el semblante de ines con el deseo de los
#
#
# ****************************************************************************
# Predicted -- men trel los ercian comoirea seyo o e ao a coso s u u ocsea lcl ieodedn u iutitor
# Utterance -- entre los que rugian como fieras y los que se lamentaban heridos o moribundos bajo las pisadas de la multitud
#
#
# ****************************************************************************
# Predicted -- cona a de nan codiao e e yeretea no ne ein n n e eno ono oauonroao
# Utterance -- tomando un manojo de llaves y repiqueteando con el no sin cierta intencion zumbona
#
#
# ****************************************************************************
# Predicted -- que ueso uese pe acasan in emini meimoria oi i ie e o o o odododoo
# Utterance -- sentiria que usted dejase a espana sin que yo pudiese manifestarle la profundisima gratitud que siento por que caballero
#
#
# ****************************************************************************
# Predicted -- pelin on on ar con ioca a a cerjcno a a a ae a aor a o a o o a ar a a r ar a aoaoroao o otoo
# Utterance -- el demonio cargue contigo con el recado con el ayudante y con el general pero me he puesto el corbatin del reves dame aca esa casaca bruto
#
#
# ****************************************************************************
# Predicted -- yesey mavyle dies nr re mico mus a loeln i a ia eol ea aioa miais is sa imsmoseocosososo
# Utterance -- yo soy noble y el senor es militar con que he hablado en terminos generales senora por lo demas mi hija no quiere casarse
#
#
# ****************************************************************************
# Predicted -- pero homo oras aciloria o asa i oa do eo do e o e e e a l o a o o o o aeleiria
# Utterance -- pero no basta que yo lo diga no basta mi palabra nos conocemos de ayer oh si a ines se le dijera lo que a usted han dicho no lo creeria
#
#
# ****************************************************************************
# Predicted -- yisilo i le e o l anin no gen l o fegpn a a a e ano a o mo a o e a a moa a aoamoiaili ioiloioloioior
# Utterance -- es imposible que siendo tan linda no tenga los pretendientes a millares dijo miss fly mirandola sera posible que esta hermosa nina no ame a nadie
#
#
# ****************************************************************************
# Predicted -- pero que la janono e erar prs asin s n e e e c cnc n ener coc n co o cencncncnc c ne ce ea corcono ononocnolo
# Utterance -- pero que el afan de no dejar atras aquellos quinientos carros llenos deriquezas les puso en el aprieto de rendirse con la esperanza de salvar el convoy
#
#
# ****************************************************************************
# Predicted -- cantos e ualtiro ainma a co e anoprotuna linda ancsa ua saseareserereseorosenesreser
# Utterance -- tanto se golpeo y machaco en la infortunada linea francesa que la vimos agrietarse romperse desmenuzarse
#
#
# ****************************************************************************
# Predicted -- yo l cn te cono ae e aea do ursoresasa cscare a acoesosc l a a ea aela ele e e a a lalararad
# Utterance -- luego le conte como habiendo necesitado del auxilio de los masones para salir de salamanca nos acompanamos de ellos hasta salir a buen trecho de la ciudad
#
#
# ****************************************************************************
# Predicted -- mra o algros precpiesos bubamases smaismsnon asadadra
# Utterance -- mirabamos al bosque y el oscuro ramaje de las encinas no nos decia nada
#
#
# ****************************************************************************
# Predicted -- yinesila uno c ir s u u ur pesprororuecueotonoroatanatono
# Utterance -- inesilla tu no me quieres tu no puedes quererme por que dices eso pregunto con candor
#
#
# ****************************************************************************
# Predicted -- co ose ecien ie e de eo lo ol ene a e es mo n n ne n a an ana a ma o oi i onena a lnan neneno u neaineno
# Utterance -- ojos que se quieren bien desde lejos se ven senora molichard cuando me deje su merced en el calabozo donde el oficial mando que me pusieran
#
#
# ****************************************************************************
# Predicted -- mi l ly i l le pe mo mo mo o a a s a e ea a oa eio o a o au os a a e ea a araninonono
# Utterance -- miss fly miss fly el viento impedia que mi voz llegase hasta ella avive el paso sin apartar los ojos de la hermosa aparicion
#
#
# ****************************************************************************
# Predicted -- no ele astirtard de sa b lro oens e a aoceo oado a aoe da ae u udesesedas e eseus es ses asut tausosrososo
# Utterance -- no se oyen las pisadas de su caballo y los gritos de entusiasmo con que le saludan los soldados no se ve el resplandor de las hogueras que encienden a su paso
#
#
# ****************************************************************************
# Predicted -- mas os iere e e ae ta r a i r r a a a era ce ce a ce c a euar cas cea r ar aoa a a a a c carernuajajadoo
# Utterance -- vamos le dije tu madre te espera estas libre querida mia y se acabaron para ti el encierro y los martirios de esta casa que es un sepulcro habitado por un loco
#
#
# ****************************************************************************
# Predicted -- sui mo priqeo beire en junde dio mpo poere eo pur iope orisaia
# Utterance -- si en un principio crei ver en juan de dios un poco de artificio e hipocresia
#
#
# ****************************************************************************
# Predicted -- de cue comrara ar lsesins e esesasnsuaroa a s asasrsosososasasas
# Utterance -- de que con la llama de los espinos y de los brezos sin cesar alimentada por ebanos tallados y bordadas telas
#
#
# ****************************************************************************
# Predicted -- la desesperacion i dodo o eno one oe ete o to o l e e eoeo o do odo
# Utterance -- la desesperacion me dijo luego wellington no es la principal fuente del valor
#
#
# ****************************************************************************
# Predicted -- que punasa lado cun o urperco o o apa po pi a a ad d d a de d de de enedededededesdes
# Utterance -- te tenia a su lado como un juguete precioso o futil pasatiempo hija mia la holgazaneria la corrupcion y la vanidad de esos grandes
#
#
# ****************************************************************************
# Predicted -- y l fumnoco a aiandasaio oco aosa e e s e e e s e s a sa a a a a as s a alalieiasa
# Utterance -- y al punto olvidando la situacion nos hablamos con la confianza de aquellos tiempos en que de nuestras penas haciamos una sola ay chiquilla
#
#
# ****************************************************************************
# Predicted -- peri a cacian e samsno erianbo lan e as co ae e e e e e i o egu u ue oeci lsosrorooaroa
# Utterance -- el gran capitan de esta masoneria ambulante esta postrado en el lecho desde hace tres dias y no puede moverse como quereis que huya
#
#
# ****************************************************************************
# Predicted -- que le qele concion e espoiad a guen nme i ima i mi i a a i i ia aidia
# Utterance -- desde que le conoci en el escorial aquel hombre me habia inspirado inexplicable antipatia
#
#
# ****************************************************************************
# Predicted -- pero sa erandos a taranrara ea ada a e e u o o ene e e e e a ueu aua a ananonanmondodo
# Utterance -- pero exagerando o trastornando de tal manera las ideas que las repudiaria el mismo que por primera vez las echo al mundo
#
#
# ****************************************************************************
# Predicted -- y el tinrbraro rn ao con ado pa pa juapara a a e e a a en a a aeisesa selsesesesese enenses
# Utterance -- y el cinto adornado con la guedeja que parecia cabellera arrancada del craneo del vencedor en las salvajes guerras septentrionales
#
#
# ****************************************************************************
# Predicted -- cuando vol d stao a a cuae po uiniueiu e e eo i n e e e e oeu e e eae a oeoroo
# Utterance -- cuando volvi estaba sentada junto al lecho del enfermo a quien miraba fijamente volviendo la cabeza indicome con un signo que no debia hacer ruido
#
#
# ****************************************************************************
# Predicted -- sien ia aia de decierer o poro o oro orero o o a oa arsoso
# Utterance -- quien me habia de decir el gran capitan no pudo continuar porque la pena ahogaba su voz
#
#
# ****************************************************************************
# Predicted -- no diso comi ictca om e re e eu une e o olo e o o e u lu loe leielelal
# Utterance -- no he visto jormiguita como el sr de lobo y que entusiasmado esta el pueblo espanol con su nuevo rey continuo el
#
#
# ****************************************************************************
# Predicted -- ye lose gtiente l uma estescoioniasa earelo
# Utterance -- yo no poseo ciencia alguna respondi exasperado
#
#
# ****************************************************************************
# Predicted -- sino ono ul ipe p ta ase e e e c o e o o o euru ude ue u u ueueoe e eaoeoeseliaiasauras
# Utterance -- sino una multitud de capas que respiraban higienicamente el aire matutino por entre los agujeros de sus remiendos y apolilladuras
#
#
# ****************************************************************************
# Predicted -- exclame con amey o sorfresa
# Utterance -- exclame con la mayor sorpresa
#
#
# ****************************************************************************
# Predicted -- aquenasist os o o s o u e a e a r a a a a a a a a a a a a a a e oeo
# Utterance -- apenas disparados los primeros tiros otros muchos franceses extenuados de fatiga y encontrandose ya sin fuerzas para combatir si no les caia del cielo o les brotaba de la tierra una gota de agua
#
#
# ****************************************************************************
# Predicted -- como s arerin iolonoa oe o e e aea a a a m a m m mraro a amosososo
# Utterance -- como se reian aquellos condenados lo gracioso es que no me dejaban salir de alli y a cada rato me decian so so so
#
#
# ****************************************************************************
# Predicted -- precin os e quecuedoebarasas aoeo uareoa a u u aue u r r ercrcr eo erca roreracacaorea
# Utterance -- trescientos escopeteros que habian salido dios sabe de donde eran capitaneados por el presbitero don ramon de argote
#
#
# ****************************************************************************
# Predicted -- entcrn ca mi il escerararara a co ena c a a a oc a a e enenesean
# Utterance -- en cuanto a miss fly me apresuro a nombrarla porque oigo una misma pregunta en los labios de cuantos me escuchan
#
#
# ****************************************************************************
# Predicted -- y o pr ro rede dia codo ma adara a o o no e edede ue e e o de de e d a adadbre
# Utterance -- y luego retrocedian haciendo con alegre algazara movimientos de miedo para esconderse despues tras una nube
#
#
# ****************************************************************************
# Predicted -- de ij n e o u eoroar o ba ao oeje o omo o eoe e e e eo o e e e o e e e e e e o o o e ereco
# Utterance -- de uniforme lujoso y destrozado en la garganta y seno como si se lo hubiera hecho pedazos con las unas para dar desahogo al oprimido pecho
#
#
# ****************************************************************************
# Predicted -- dije e pe pi don e o o o o o onmia m l l i i i i iada di l ieia ririr ienenirnoe
# Utterance -- dijeles que si y poniendose muy contentos me mandaron que diese al punto una corridano queria yo mas para divertirme
#
#
# ****************************************************************************
# Predicted -- puaencar gu a queza a labrndo aizcorabara ca cun o nanundon nonono onionionoinondtdondos
# Utterance -- soldados gemid de rabiay furor
#
#
# ****************************************************************************
# Predicted -- las seosesconcladas mjre n n o o eo o oe u u u o un o o mo
# Utterance -- las dos desconsoladas mujeres vieron todo esto y examinaron los cuerpos uno a uno
#
#
# ****************************************************************************
# Predicted -- canta si ta a ardaservanma en i i pima iearaririaia
# Utterance -- tantas y tan amargas derramo que me senti no ya compasiva sino tambien enternecida
#
#
# ****************************************************************************
# Predicted -- y sure e a alo de tamen ynen ni imimenonci i i leie e eie eieienegmoereolo
# Utterance -- estuve en la batalla de tamames y en extremadura no se encontro usted en un nuevo asedio en el de cadiz mi general
#
#
# ****************************************************************************
# Predicted -- sue icontoscacacoco cacacnoenenarena ea ae a a aose cininieancicisis
# Utterance -- su difunto esposo habia sido companero de don mauro en el cargamento y arrastre de fardos y mercancias
#
#
# ****************************************************************************
# Predicted -- conovortanende sn derara d asa bslelos gena a ararn cos o n n c e e a a a cnaioiliroio
# Utterance -- cuando fui al meson a decir a los arrieros que no me aguardaran oi decir lo mismito a unos que estaban alli
#
#
# ****************************************************************************
# Predicted -- na etetaeredonco co osu ar a e e es es e s s es s ses use ses esasedse sdasasases
# Utterance -- no el del barandal del cielo que es mas bonito y habla de la virgen anadio el condesito gozoso de hallarse a punto
#
#
# ****************************************************************************
# Predicted -- pesto i te ta m es a pur a e o o e s e eseuo o o ne eo o o o o mo oneoseomesnoo
# Utterance -- esto si que esta bueno al cabo de la vejez si nunca me lo has dicho puede que quieras sostener que me lo has dicho que no
#
#
# ****************************************************************************
# Predicted -- no e vioe ae e a a sese a a o e me e a asa a ca ei e ia eacaci ca c a ci ci iceciaiaisra
# Utterance -- no se olvide que aun me duraba el despecho y la sofocacion de la manana el recuerdo de las escenas que antes he descrito completaba mi ceguera
#
#
# ****************************************************************************
# Predicted -- per ema res a e pun uno e e e eo o e e le o o o o omeaiaiosio
# Utterance -- lo demas lo sabes tu y no necesito decirtelo esta manana creimos morir aqui
#
#
# ****************************************************************************
# Predicted -- halasade tuemaria itede n oa nenan a a e e ea er ea uene erarenesesa
# Utterance -- a la salud de maria ciperez muy guapa parece un sol y cuantos la ven la tienen por princesa
#
#
# ****************************************************************************
# Predicted -- mientrspragui s e pinie o ioes e eo o oepoeo graradesesros
# Utterance -- mientras con angustiosa impaciencia miraba los fusiles del peloton de granaderos
#
#
# ****************************************************************************
# Predicted -- penia comoveinte n ea ae eu e e e u un o on o aruan
# Utterance -- tenia como veinte anos llamabase andresillo marijuan
#
#
# ****************************************************************************
# Predicted -- cuandonesalitiaon s una ao a ecntep etere e e en e e e o eo e oenreo e e u eo rendo o er e e eneontroetsosoo
# Utterance -- cuando nos dirigiamos juntos al alojamiento del general pedile informes de la dama inglesa cuya figura y extranos modos he dado a conocer y me contesto
#
#
# ****************************************************************************
# Predicted -- en te tel coe a a e e e oa e e e eue e e e e e eoci e e me enenanoo
# Utterance -- empecela yo y como en ella pusiera no recuerdo que palabras pidiendo perdon enfureciose mucho y dijo
#
#
# ****************************************************************************
# Predicted -- cuanto se vanlede a la poresita dicia grne
# Utterance -- cuanto se va a alegrar la pobrecita decia para mi
#
#
# ****************************************************************************
# Predicted -- na se lo fulte din e a pa oc oso o ocococac oacos o a soso oaoarasasta rasao
# Utterance -- no se lo oculte y el me decia esto acabara pronto no conquistare a los necios sino con esta farsa
#
#
# ****************************************************************************
# Predicted -- y soe pe cien saymo co c caca ca a a a a a anaena a arnarararo
# Utterance -- y usted que piensa me dijo monsalud observandome con curiosidad entraran los aliados en salamanca
#
#
# ****************************************************************************
# Predicted -- conde iose ueio ic p o ueapetut o o o roa a a a la l aea a alararao
# Utterance -- cuando dios me crio dispuso que padeciese y he padecido como ningun otro mortal sobre la tierra
#
#
# ****************************************************************************
# Predicted -- cal de no i an l le o o e e e e eo e e e e e e e ese eseseses
# Utterance -- tal vez no habria caido tal vez no habria sido rey fernando septimo tal vez no habrian venido los franceses tal vez
#
#
# ****************************************************************************
# Predicted -- maear e a ue a e os os enen cnce e n e e e ea o e ra e e a ereres erseds
# Utterance -- marchad fuera a cuidar de los otros enfermos dijo miss fly jovialmente y no vengais a fastidiarnos con vuestras necedades
#
#
# ****************************************************************************
# Predicted -- pende denperaraols liegos rarerino
# Utterance -- donde le entregaron los pliegos de reding
#
#
# ****************************************************************************
# Predicted -- quele es nichi yiuo yno ces m macare oe en aoronrtroo
# Utterance -- tu eres un chiquillo y no piensas mas que en jugar y por eso no te importa
#
#
# ****************************************************************************
# Predicted -- nos algarn ercouso ase es es eos o s ei ono os o olosoloso sls s
# Utterance -- no saldran repuso hasta despues de media noche amigo jeanjean quiero que me proporciones un sable y dos pistolas
#
#
# ****************************************************************************
# Predicted -- pos s patuco o cnretea a oa e e io so a a o o u e n e a a ea ararsaseaeso
# Utterance -- todos los articulos del comercio estaban alli reunidos y hacinados con cierto orden los requejos vendian telas de lana y algodones a saber
#
#
# ****************************************************************************
# Predicted -- el pue o a erarneo eve e elnlo e e e ceo ca cace eo eu eueueuea o ecaca amaceaearajarao
# Utterance -- el pueblo victoreaba al nuevo rey el plan concebido en las antecamaras de palacio habia sido puesto en ejecucion con el exito mas lisonjero
#
#
# ****************************************************************************
# Predicted -- y l esiodo irde e or ra e o e u a e ueses se ses sesuseds e e e e es e us se seses es meuseueges
# Utterance -- y el vestido limpio ya de polvo y lodo disimulaba sus desgarrones y arrugas no se por que arte singular solo revelado a las mujeres
#
#
# ****************************************************************************
# Predicted -- sinerian die cayo y oamo a a a a o e e ae e ae e e a a alalala
# Utterance -- si me bian dejao le hago porvo con este palo prrun prrun marchen media guelta
#
#
# ****************************************************************************
# Predicted -- acesi sise de eria acomi a be ba a li imocn a ae datas ana ae na ea in einenouosos
# Utterance -- a fe que si ustedes me dieran la comision de vigilar a la nina cuando salen de casa la nina no se reiria de nosotros
#
#
# ****************************************************************************
# Predicted -- pero ecto os ds ranos o ma tn t p pe te ie e e a a a a a a a a e e a eracarecea atarera
# Utterance -- pero estos observando nuestro movimiento y reconociendo al instante su indudable inferioridad invadieron precipitadamente la carretera
#
#
# ****************************************************************************
# Predicted -- vorira ordea a sde pres punade ta ce pipo esa a c oa ca cseoseosoeal i silioses
# Utterance -- voy a aburrir a mis lectores abusando de la gentil cortesia que les movio a fijar sus ojos en estas
#
#
# ****************************************************************************
# Predicted -- por e tho e a i as me ha a a s u o e o e e de dodne eno e erarararodoo
# Utterance -- prometo que santurrias me las ha de pagar todas juntas pero has visto como se burla de mi ese condenado
#
#
# ****************************************************************************
# Predicted -- a me titu sibe a arba ba ce e a e e eo en e e e e e o eo o o re de ea deo o da a eo aeao ocoesesda
# Utterance -- la multitud subia y bajaba abria alacenas rompia tapices volcaba sofas y sillones creyendo encontrar tras alguno de estos muebles al objeto de su ira
#
#
# ****************************************************************************
# Predicted -- ambosigdos cunirgo ite a e e i o do mo eo oe o eoe o do o o d do edo o oeo odododos
# Utterance -- ambos libros son muy bonitos y traen un aquel de amores y besos que me daba mucho gusto cuando los leia a escondidas
#
#
# ****************************************************************************
# Predicted -- dininodo o bo o parta s e sesa n n sa a e a a a a a eia a a as a i as asase l esososasosasas
# Utterance -- y diciendole que voy de parte de usted le pintare la situacion en que nos encontramos hablandole tambien de inesilla que es sin duda lo que le interesa mas
#
#
# ****************************************************************************
# Predicted -- pue mincoaopoe e o oe ea ae e ae ene ieie e al eie ulrloroa
# Utterance -- fue un infierno porque todos los demonios todas las maldades y abominaciones cayeron sobre ella
#
#
# ****************************************************************************
# Predicted -- per en tenpta b ius ble leseaneno pr e ocoese e mamint osa ultiorisos
# Utterance -- pero he intentado disuadirle de su empeno porque no posee conocimientos facultativos
#
#
# ****************************************************************************
# Predicted -- ahoroa uonde al e oere etaoasresa sasereo e eneuseseosososiuesiscoisosostsoros
# Utterance -- ahora cuando ese saladisimo rey que tenemos arregle las cosas hay esperanzas de hacer algo que tiempos restituta que tiempos
#
#
# ****************************************************************************
# Predicted -- merabdadas ela cemi a a anade lsas sei o r e re uauaorororasaraststa
# Utterance -- mi adorada suegra tenia la mania de las cartas escribia a todo el mundo y de todos lograba respuesta
#
#
# ****************************************************************************
# Predicted -- en raiasrodreiceae eae aea ie o o ue e erelo o ra re le e el oe earelerererlrororodoro
# Utterance -- entre las dos debia desarrollarse al dia siguiente uno de los mas sangrientos dramas del siglo el verdadero prefacio de waterloo
#
#
# ****************************************************************************
# Predicted -- yo e u re n nie in e o oeo o eu o emo e e eo o o oe o o o e e eo e e e e e e eo e e e e d e o e ereieiesteititoo
# Utterance -- yo me desespero y lloro en silencio al ver cuan felices son otros frailes de mi orden los cuales disfrutan con la paz mas pura las delicias de visiones santas que son el mas regalado manjar del espiritu
#
#
# ****************************************************************************
# Predicted -- el cua se ensercocnpioron rba enece co crc c ca carco cararaloranalasasorsolo
# Utterance -- el cual se encerro contigo en su gabinete y te confio el plan de su campana contra el austria
#
#
# ****************************************************************************
# Predicted -- cando menton den a al e prauedeareofcroroe o o oe e cocomo eo eo o oe o o oneno o o eo e eoe e e eo eo eoreoesesesereososoo
# Utterance -- cuando me encontre en la calle trate de reflexionar para que la razon enfriando mi sofocante ira iluminara un poco mi entendimiento sobre aquel inesperado suceso
#
#
# ****************************************************************************
# Predicted -- vo preo que heihacecone de es oba je pia cama esa a ama esasasa a eia a eselasesasmelesealalsoso
# Utterance -- lo primero que has de hacer cuando llegues cordoba es visitar a mis primas y entregarles estas cartas mira aqui van las
#
#
# ****************************************************************************
# Predicted -- ya as rste ue biea pa a a a a da e e e e e e o o o oue oecececeacacae
# Utterance -- ya sabe usted que ha venido mucha tropa de madrid y por las calles del pueblo se ve gente de malos modos pero que objeto puede tener ese viaje
#
#
# ****************************************************************************
# Predicted -- lesestenmuevo es carece se i a e a lsaseo o en ea eaea e esetasaracas
# Utterance -- de este modo los franceses piensan embolsarse el poco dinero que han dejado en nuestras arcas
#
#
# ****************************************************************************
# Predicted -- yn quela concs n de dt e prese e e u a ao arae lo a oa ao aua a ocbn nca anioninon
# Utterance -- en aquella confusion de gritos de brazos alzados de semblantes infernales de ojos desfigurados por la pasion
#
#
# ****************************************************************************
# Predicted -- para qe lolos em apa ara e e a a o o e eo o s es e se a ar rasreasasasadosos
# Utterance -- para que todos en una palabra puedan apreciar la buena pronunciacion de usted y su cadencioso oido echenos cualquiera de esos romances que sabe vamos
#
#
# ****************************************************************************
# Predicted -- en puaresincnore e ecici cunu e e e e enenenen en e ecne e edeidedaelr
# Utterance -- en cuanto a los informes que me exigieron facil me fue conseguir la merced de una recomendacion del regente del diario
#
#
# ****************************************************************************
# Predicted -- qu u ra cercaso de esco uraia tue a in astiara an u a o a a as ia isasasarara
# Utterance -- si fuera a hacer caso de esta compraria tierras y mas tierras a esta no le gustan sino las tierras
#
#
# ****************************************************************************
# Predicted -- asi aqu ea atanianea ei ea ae e a eainoenenrna
# Utterance -- agujeraba con entusiasmo su encierro porque habia vislumbrado fuera alguna cosa que tenia la fascinacion de lo nuevo
#
#
# ****************************************************************************
# Predicted -- a questade etarido curel tar edese menteaba lum mo yi p enter
# Utterance -- a pesar de esta viva crueldad que a veces manifestaba de un modo imponente
#
#
# ****************************************************************************
# Predicted -- yaelisos hea aos e a nasa o ca o o a a a a a a a eca a a a a a a a a e ea a e a a a e a a es e e es seseseseses
# Utterance -- ya te dijimos que habiamos determinado casarte con un joven de alto linaje proyecto en el cual estriba la felicidad y grandeza y lustre de la familia a que perteneces
#
#
# ****************************************************************************
# Predicted -- vovorasdore an ni e e pro a nono e e le e geme ene o e a aea e a a me a a e aeara a ao
# Utterance -- doy las gracias a su eminencia por haber mandado que me devolvieran el burro eminencia me llama usted repuse todavia no me han hecho cardenal
#
#
# ****************************************************************************
# Predicted -- po pa sie e o a o o uo o r a e e e e ea a a a a e a a e ea a ararorososososos
# Utterance -- toca este instrumento y veras lo bueno el combate llegaba a un extremo de desesperacion y la artilleria enemiga avanzo hacia nosotros
#
#
# ****************************************************************************
# Predicted -- podos amelabanesntimseli a esta glel ca se e a inananaseserestado
# Utterance -- todos anhelaban que se firmase de una vez la capitulacion para salir de tan lastimoso estado
#
#
# ****************************************************************************
# Predicted -- ye que te al go mecinmi i us sn es o ou eu u eo uesens e e ueus s esesioi i i e e o eo eososueuo omo thjroroso
# Utterance -- veo que usted ha leido mucho mi enemigo no es tal como usted le pinta es un viejo enfermo pues entonces senora araceli dijo athenais con disgusto
#
#
# ****************************************************************************
# Predicted -- y queremonsel cal l la a a a a a u e a a a a a a a a a o e e a a a a a aran ananono
# Utterance -- y que moncey sale manana de aqui para valencia y que lefebvre que esta en pamplona ira pronto sobre la capital de aragon
#
#
# ****************************************************************************
# Predicted -- la gondesaijaines y e neo ue rae eare araer rabalaodoe
# Utterance -- la condesa dijo a ines hija mia tienes inconveniente en casarte con gabriel
#
#
# ****************************************************************************
# Predicted -- asaram rerea a aiananda pe a a a a a a e a a o ero a e era a adoa a rododoeoloeoo
# Utterance -- astamos ya hasta el ganote y ahora no hay naa mas sino dejarse de pedricar y coger las armas pacabar con godoy
#
#
# ****************************************************************************
# Predicted -- cun a aninain to tenrefre o ur etos o o en e a e o o o erarorarar a ro coronarararjoroteo
# Utterance -- con una camisa limpia que me presto el cura quede en disposicion segun el mismo me dijo de presentarme aunque fuera a napoleon bonaparte
#
#
# ****************************************************************************
# Predicted -- cunal ar jurpa arde ueda queserablen e uoporoa o o co oe o non aloioso
# Utterance -- una larga pieza de tela que se arrolla en el cuerpo como la faja que ponen a los ninos
#
#
# ****************************************************************************
# Predicted -- mi i y y selogvn o enmeme e ireojomos erere rerereroto
# Utterance -- miss fly se levanto senora le dije con el mayor respeto
#
#
# ****************************************************************************
# Predicted -- mos ulventoen sn o s do e a e re o e ea a e a a a e a e e oao o eo o ea a o o eoro oio ioooo
# Utterance -- mas tuve el disgusto de saber que su excelencia la senora condesa estaba en camino de andalucia desesperado regrese al centro de madrid
#
#
# ****************************************************************************
# Predicted -- pe inos dia metaraso orbrba a o mo a l o somsososos lslosisistisosos
# Utterance -- el uno subia mientras el otro bajaba en aquel instante debi de decir algo mas sustancioso que los primitivos sis
#
#
# ****************************************************************************
# Predicted -- y he saombro y mn eo eos en o e e a a a a aoa o c co e e e o o e a a aim eis i i i a alaio
# Utterance -- ese asombro indefinible que sentimos en el momento de observar la falta o perdida de un objeto que poco antes llevabamos y miss fly
#
#
# ****************************************************************************
# Predicted -- pordrn a a io de a arards cn i ieino s sesosoeosostorsors
# Utterance -- todos los arbitrios de la caridad son inutiles y el dinero busca alimentos sin encontrarlos
#
#
# ****************************************************************************
# Predicted -- mes tdo de ims de ra uite c o morme e ea a mn a a a a ama ainia
# Utterance -- nos despedimos el bravo ciperez y yo dandonos fuertes apretones de manos y segui a buen paso mi camino
#
#
# ****************************************************************************
# Predicted -- que stabe eaciende e forcan ustens co a oba i u us e e ie iesisuesu rarobo
# Utterance -- esta revelacion me dejo tan suspensa tan asombrada que por un instante perdi el sentido
#
#
# ****************************************************************************
# Predicted -- pre ententenro priel oso lna c clc c c a e o a a ca co c c ca oneneococ eocococonco aioio
# Utterance -- crei entender oh cielos que me amenazaba un interrogatorio severo al cual seguirian rigurosas medidas penales contra mi
#
#
# ****************************************************************************
# Predicted -- quie es draro oson aona h a a a a a a a a em e eoa a o oamoa ar a o aodoa arananoo
# Utterance -- quieres verlo pues toma aun no lo habia dicho cuando rapida fuerte y destructora como un ariete romano
#
#
# ****************************************************************************
# Predicted -- porftuna diji u prpre pr nao tatansnsonseteses
# Utterance -- fortuna vil prostituta por que te invocan los hombres
#
#
# ****************************************************************************
# Predicted -- viose omanede l rey amora ye o a ao a a la adodeo a
# Utterance -- yo se el romance de la reina mora grito don diego batiendo palmas lo echo venga
#
#
# ****************************************************************************
# Predicted -- pera tente a ara ero oue arare e eo e ae e e ede de edeacecarerese
# Utterance -- pero atended ahora que lejos de ser tarde es esta la ocasion propicia de hacerlo segun el refran que dice
#
#
# ****************************************************************************
# Predicted -- es osjupse a aos as unuarieueai a or rira a re e rca a ca rer e er e e r ar e o eoere e ereraro r e criorororoo
# Utterance -- en los puntos lejanos las columnas de humo eran en mayor numero y cada una indicaba la troj o panera que caia bajo la planta de fuego del ejercito fugitivo
#
#
# ****************************************************************************
# Predicted -- quera tor a quetas na u tu t oa a ao e e e e e e e e e e e e e a a ia rea a entorortoo
# Utterance -- pero a todas estas la multitud que ocupa la taberna se levanta obedeciendo a la orden de un hombre que alli se presento de improviso salieron todos
#
#
# ****************************************************************************
# Predicted -- yosos e pracosu u yo ya reronmiro ia o o o o e i o oa o o eo o eo o o o i o ci oi c o oio ao ioisitaotiosmotsraoo
# Utterance -- mi desesperacion no tuvo limites y ahora celebro no haber tenido en aquel momento un punal en mi mano porque de seguro le hubiera partido el corazon al leguleno trapisondista
#
#
# ****************************************************************************
# Predicted -- ytuena col etose scpico o e pae e qu u u u e ia i ic e o euecoeoesocoeoaonoens
# Utterance -- mi tenaz proyecto se explica por el estado de desesperacion en que me puso la visita de los requejos y su proposito de cargar con la pobre ines
#
#
# ****************************************************************************
# Predicted -- vie u vuse dado los carlilo dij e nero laarja
# Utterance -- bien pudo usted haberlos traido dijo grunendo la vieja
#
#
# ****************************************************************************
# Predicted -- y entra te que mue pabenas a es pi a da o o po u es ese s tesi tata asas
# Utterance -- y el crater de nuestra venganza esputaba lo mismo el puro fuego que las pestilentes lavas
#
#
# ****************************************************************************
# Predicted -- como es abo e pi a que er aervaenr nm emu c ca a a acacarararariao
# Utterance -- como estaba vestido facil me fue levantarme en un momento y dirigirme hacia ella con paso quedo para no asustarla
#
#
# ****************************************************************************
# Predicted -- mo vijo co con e niene de corarai eososusar oasaseseaes e aea ea elo o oe aedo a lsesoseurtadao
# Utterance -- muy luego convencime de lo contrario y aquel santo varon arrojado por las tempestades mundanas a la vida contemplativa y austera
#
#
# ****************************************************************************
# Predicted -- aqitodo qierentar e canoto conde ue a s e e ce e e a i i e e i e ei esiea
# Utterance -- aqui todos quieren saber tanto como los que mandan de modo que se oyen unos disparates lo de portugal ha resultado muy distinto de lo que se creia
#
#
# ****************************************************************************
# Predicted -- min an us u uon upue tlan uea os n mo mro sis s ste es o ea car c oco a oe araca oco aroncoero
# Utterance -- mi amo tuvo el gusto de plantear por si mismo el nuevo sistema dispuso que ines no saldria de su cuarto ni para comer
#
#
# ****************************************************************************
# Predicted -- qerarecos une a t uaba lo o e e a a o dodio
# Utterance -- que rehechos con un destacamento que habia llegado de linares trataban de ganar lo perdido
#
#
# ****************************************************************************
# Predicted -- esca ela a al a r eatre ete rara a po pr a so costia
# Utterance -- estaba el ama a las cuatro de la tarde sentada en el cuarto de la costura
#
#
# ****************************************************************************
# Predicted -- menira y crio ceho al ababa icon ies aya a y eo me m mnmn n ca caonono
# Utterance -- el dia dieciocho el arrabal donde yo estaba diome idea de como es el infierno
#
#
# ****************************************************************************
# Predicted -- despos e ma bacie eta los an tacu ta rs algardne
# Utterance -- despues que me abrace a la santa cruz para salvarme
#
#
# ****************************************************************************
# Predicted -- cur ie ds co o y m aulal er on e an n e e e e e e e e e e e e ere eneseso
# Utterance -- cuyo unico apoyo material era una depresion del terreno una especie de zanja sin profundidad que parecia marcar el linde entre dos heredades
#
#
# ****************************************************************************
# Predicted -- expep am e n enoa a ea e a a oa mo om ma a o a m i oi hio aojihoo
# Utterance -- despues de vacilar un momento entre la seriedad y una sonrisa se apreto el corazon con ambas manos y me dijo gabriel
#
#
# ****************************************************************************
# Predicted -- y que conts gro al poria a a m mo e e e m mo o mo m o o o oe meodo onesososo
# Utterance -- y que pronto se murio la pobrecita ya que paso a mejor vida aquella santa y ejemplar mujer dijo restituta no la nombremos
#
#
# ****************************************************************************
# Predicted -- y omo las fran ceses esaleztanen estano e a ca ia r e e o
# Utterance -- y como los franceses se establezcan en espana veras la que armo  padre le decia yo
#
#
# ****************************************************************************
# Predicted -- me ces ouialesan cu dado sun r la ae ae s a asas sea e es a e d dedededesdededeadadodoesese
# Utterance -- muchos oficiales se han fugado sin que en los cuarteles ni en sus casas se sepa donde estan y diras tu pues donde estan  yo lo se
#
#
# ****************************************************************************
# Predicted -- esiste desenrercante delscaderderalas poraraje dinena a
# Utterance -- es usted el senor chantre de la catedral de astorga que viene a
#
#
# ****************************************************************************
# Predicted -- y nodera quera pase na posi torparen ia a la e oa austitara ie aiela auta
# Utterance -- y no era aquella ocasion a proposito para que me diera la llave falsificada que hacia falta
#
#
# ****************************************************************************
# Predicted -- nuacams me ve a use unsa e e a a a a a a a a a a a a a a aoaororo
# Utterance -- nunca mas vera usted a su madre bien sabia yo que no eras capaz de la infamia de abandonarme
#
#
# ****************************************************************************
# Predicted -- vrere a a o con io s eto u u u absdaodoavado
# Utterance -- verde ahora con picos despues con curvas mas tarde irradiado
#
#
# ****************************************************************************
# Predicted -- yo no uemotiarnas sa ar u ro o ra a e dada rorero orodo ordodordorao rdodrdngonodo
# Utterance -- ya no tengo piernas traes tu polvora dame aca yo te cargare el fusil pero me caigo redondo
#
#
# ****************************************************************************
# Predicted -- parei a e i sa rs tus pus sen i re e a n eien e i i e i i ede i de idedesesiuruaro
# Utterance -- parecianme disparates sus consejos y los obedecia aquella inmensidad de su pensamiento tan distante de la realidad me seducia
#
#
# ****************************************************************************
# Predicted -- an que latarereceltioen ornon ca ecaocanra n n eno a o ara ne n aeae a ea eae a a e a eaea a a ae ae e a a a a aea a nenarararararoroo
# Utterance -- aunque al traves del tiempo nos parezca lo contrario entonces se chillaba mucho y tambien habia quien tomara muy a pechos los asuntos de la guerra solo por el simple placer de meter ruido y tambien para hacerse notar
#
#
# ****************************************************************************
# Predicted -- leandales estete tenae e aile en oe e ea ae e e e i e o l e e e e alabad
# Utterance -- llamando a mi asistente que estaba en la calle le di orden de que proporcionase a ines cuanto fuese preciso y existiera en el lugar
#
#
# ****************************************************************************
# Predicted -- las a rancese e la la o era en e o o o do ococececiecocosososaspsostas
# Utterance -- los franceses les llevan a la fuerza aparteme a un lado por temor a que mi curiosidad infundiese sospechas
#
#
# ****************************************************************************
# Predicted -- que es amoamo o pe ua a atonos nto bloesiti a i einene es e hispirtorto
# Utterance -- tienes algun amigo que quiera ganarse unos cuantos doblones y que ademas sea valiente sereno y discreto
#
#
# ****************************************************************************
# Predicted -- a celtose ana rantan n ou n an ae e a a a e a a e e eaedo acoerare aearoro
# Utterance -- acercose a amaranta y mostrandole un medallon que en la mano traia le dijo te gusta no es verdad que esta parecido
#
#
# ****************************************************************************
# Predicted -- su perio pero preso co te panona o ao e en ada a a a e e ae ena na ea a a rn a inenteter
# Utterance -- sucedio que los pobres masones igualmente malquistos con los franceses que salian y los espanoles que entraban en babilafuente
#
#
# ****************************************************************************
# Predicted -- na adipido do edeso espes e ade asrerar muea a a a a leroa a lacada
# Utterance -- no hay cuidado por eso despues de habersela dado me entro tentacion de hablar con ella
#
#
# ****************************************************************************
# Predicted -- desxpe que labancuere us rasara enoueuene ea a e e ra eoe rerdud e dodo d edododod dododo
# Utterance -- despues del avance de nuestras tropas que no ocuparon enteramente las posiciones francesas por ofrecer esto algun peligro
#
#
# ****************************************************************************
# Predicted -- epaer e to do do e reieroio o le e ea ama amamamamaoao
# Utterance -- pero si apenas puedo creerlo exclamaba mi ama
#
#
# ****************************************************************************
# Predicted -- con de dios esalanlo un ci coro o in i o e ye pe pe pojlorojos
# Utterance -- juan de dios exhalo un suspiro profundisimo y despues bajo los ojos
#
#
# ****************************************************************************
# Predicted -- lo pure sespecbara y enen e e e pc c eae a c c ea e e ea ena eaea cenraceseses
# Utterance -- lo que yo sospechaba y ahora se me revela por completo tiene tanta belleza como las mentiras de las novelas y romances
#
#
# ****************************************************************************
# Predicted -- el lugono cu o rdo oroboro re de pa anba aresaeoese ose u ea e ae eue ueue ea e as e ea e a a ausuos s asiuaos
# Utterance -- el antiguo mancebo de don mauro requejo estaba tan demacrado tan excesivamente amarillo y mustio que parecia haber vivido diez anos de penas en el trascurso de algunos dias
#
#
# ****************************************************************************
# Predicted -- aha qe desta tiquesa la acia pan me e e e e e e e ie ieieilildidaiaio
# Utterance -- ahora que eres archiduquesa y archipampana no tienes verguenza de quererme pero que quieren hacer de mi
#
#
# ****************************************************************************
# Predicted -- muo puy de se compie aso ulead sa restetado yn e esuneu uoe seunsionoestesesese
# Utterance -- no tuviese completa seguridad de ser respetada miss fly es duena de sus acciones le conteste
#
#
# ****************************************************************************
# Predicted -- ayi deo esesi tioi s i a e e ea eie e ae eseteseses
# Utterance -- ay que voces que gritos mi tio se echo a llorar y dijo tambien viva espana tres veces
#
#
# ****************************************************************************
# Predicted -- dijo ententa me porora as coe roroloro la a a aeasesesesae e eteteoetoracour oeuoeos louososososos
# Utterance -- grito intentando incorporarse con esfuerzos dolorosos todavia puedo hacer algo esto pasara no es nada aun tengo pulso
#
#
# ****************************************************************************
# Predicted -- sis ques eno la amema erai a e e e dedn de e e e ene e e e e e e ememreu den ouoiun onrirorara
# Utterance -- si quieres que no la ame mas que a ti damela nuncate he pedido nada con ella sere bueno sin ella sere lo que el demonio quiera
#
#
# ****************************************************************************
# Predicted -- puraceode es pus equr abde ecareun a a eara a a aea ae a aeada araenadaso
# Utterance -- trajeron despues botellas de vino de jerez que en un santiamen dejaron como cuerpos sin alma porque toda ella paso a fortificar las de aquellos claros varones
#
#
# ****************************************************************************
# Predicted -- que b senos enen nde ben a ea a jen e e a a a e eo e e e eae eaea ae ea rena a n arararao
# Utterance -- que dia senor san antonio de mi alma que dia yo me encargare del mocito dijo lobo lo unico que les pido es que me lo guarden hasta manana
#
#
# ****************************************************************************
# Predicted -- que naltara a cabesa paramigaraslos
# Utterance -- que no alzaron la cabeza para mirarnos
#
#
# ****************************************************************************
# Predicted -- y lelos aci que trdradospreian a e de didado
# Utterance -- y helos aqui que por grados perdian la serenidad
#
#
# ****************************************************************************
# Predicted -- andrabvino qeue iera ptrbala tan o leu utedea pe a a e e a a a e o o e a a a a o e am a asasao
# Utterance -- anadiendo que si ella probara tan solo un buche de tal enjuagadero de tripas arrojaria por la boca juntamente con los higados la primer leche que mamo
#
#
# ****************************************************************************
# Predicted -- al tocodato qe a qensanas e pue a ciseso enscen enen eaeaeosoconseseses
# Utterance -- al poco rato ya no pensaba mas que en volver a mi casa donde suponia a ines en penosa angustia por mi ausencia
#
#
# ****************************************************************************
# Predicted -- a ce tuemi airoa aque us a u osocu co e oeo e e a o easa e eose eaeseseses
# Utterance -- a fe que mi marido hace buenas migas con los masones el y yo detestamos el populacho y adoramos a reyes y frailes
#
#
# Test set: Average loss: -0.7502, Average CER: 0.619041 Average WER: 1.0625

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.subplot(111)
box = ax.get_position()

ax.plot(birnn_train_losses, 'b',label='Layer - BI-RNN valid losses')
ax.plot(birnn_val_losses, 'r',label='Layer - BI-RNN train losses')

ax.plot(conv_bigru_train_losses, 'm', label='CONV-BIRNN train losses')
ax.plot(conv_bigru_valid_losses, 'g', label='CONV-BIRNN valid losses')


plt.xlabel('epochs')
plt.ylabel('loss')

ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])
# Put a legend above current axis
ax.legend(loc='upper center',fontsize='small', bbox_to_anchor=(0.5, 1.09),
          fancybox=True, shadow=True, ncol=4) 
# Limits for the Y axis
plt.show()
