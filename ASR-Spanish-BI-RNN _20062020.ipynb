# %%
# File Settings
ROOT_FOLDERS = ['/kaggle/input/spanish-single-speaker-speech-dataset/', '/kaggle/input/120h-spanish-speech/asr-spanish-v1-carlfm01/']
CSV_FILE_PATH_1 = ROOT_FOLDERS[0] + 'transcript.txt'
CSV_FILE_PATH_2 = ROOT_FOLDERS[1] + 'files.csv'
CSV_FILE_PATH = [CSV_FILE_PATH_1, CSV_FILE_PATH_2]

SAVE_RESULTS_PATH = '/kaggle/working/'
SAVE_MODELS_PATH = '/kaggle/working/'

# %%
# Systems Libraries
import os
import time

# For audio processing
import librosa
import librosa.display
import IPython as ipd

#from torchsummary import summary

# For data processing
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# For Neural networks
import torch
from torch import nn
import pickle as pkl
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader


# For visualization
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')



# For text processing
import string

# Scripts created by me:
import utils
import models
import textprocessor
import speechdataset

from datetime import datetime



from random import choice
import random
import math

import soundfile as sf

# %% [markdown]
# ### Audio Sample
# Hear one of the audios.

# %%
ipd.display.Audio(filename='../input/spanish-single-speaker-speech-dataset/batalla_arapiles/batalla_arapiles_0010.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Plot audio
#
# Plot the audio in different formats:
#
# * Waveform
# * MFCCs (13)
# * Spectrogram.

# %%
(waveform, sample_rate) = librosa.load('../input/spanish-single-speaker-speech-dataset/batalla_arapiles/batalla_arapiles_0010.wav')
spectrogram = librosa.feature.melspectrogram(y=waveform, sr=sample_rate)
mfccs = librosa.feature.mfcc(y=waveform, sr=sample_rate, n_mfcc=13)
utils.plot_all(audio_data=waveform, spec=spectrogram, mfccs=mfccs, sr=sample_rate, file='batalla_arapiles_0010.wav')

# %% [markdown]
# ### Data Pre-processing:
#
# Before starting to analyse the data, let's do some clean up. The path which looks like 19demarzo/19marzo_XXXX.wav will be split into two other columns and thus we will have a table like this:
#
#
# | index | path    |	utterance  | label   | duration	 | dir	   | file    |
# |------ |---------|------------|---------|-----------|---------|---------|
# |0	| 19demarzo/19demarzo_0000.wav	| Durante nuestra conversación advertí que la mu...|	Durante nuestra conversación advertí que la mu...|	5.88	| 19demarzo	|19demarzo_0000.wav |
# |1|	19demarzo/19demarzo_0001.wav|	Componíanla personas de ambos sexos y de todas...|	Componíanla personas de ambos sexos y de todas...|	4.52|	19demarzo	|19demarzo_0001.wav |
# |2|	19demarzo/19demarzo_0002.wav|	espontáneamente venidas por uno de esos llamam...|	espontáneamente venidas por uno de esos llamam...|	8.31|	19demarzo |	19demarzo_0002.wav |
# |3|	19demarzo/19demarzo_0003.wav|	y resuenan de improviso en los oídos de un pue...|	y resuenan de improviso en los oídos de un pue...|	7.20|	19demarzo |	19demarzo_0003.wav |
# |4|	19demarzo/19demarzo_0004.wav|	La campana de ese arrebato glorioso no suena s...|	La campana de ese arrebato glorioso no suena s...|	7.50|	19demarzo |	19demarzo_0004.wav |
#
#
#
#
#
# ### Clearing up unnecessary data
#
# It is clear that there are accents, commas, etc. that we don't really care about. So, let's clear those up.
# We will also clearup the data where the utterance is empty with the command d.dropna.

# %% [markdown]
# ## Processing the audio data.
# For the audio, I need to get the spectrogram or mfccs and the utterance (as the label).
# The custom dataset saved as a utility script as speechdataset was created following the Custom Dataset tutorial by pytorch:
# https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
#
# **The utility script can be found named as speechdataset.**

# %%
def load_dataset(csv_files, root_dir):
  
  # Create the dataset and split into validation dataset and test dataset.
    total_dataset = speechdataset.SpanishSpeechDataSet(csv_files=csv_files, root_dir=root_dir)
    train_size = int(0.8 * len(total_dataset))
    val_test_size = len(total_dataset) - train_size
    train_dataset, val_test_dataset = torch.utils.data.random_split(total_dataset, [train_size, val_test_size])
    valid_size = int(0.9 * len(val_test_dataset))
    test_size = len(val_test_dataset) - valid_size
    val_dataset, test_dataset = torch.utils.data.random_split(val_test_dataset, [valid_size, test_size])
    print("Total Training Dataset = {}, Valid Dataset = {} and Test Dataset = {}".format(len(train_dataset),len(val_dataset), len(test_dataset) ))
    print("Total --> ", len(train_dataset)+len(val_dataset)+len(test_dataset))
    sample = train_dataset[0]
    print("*****Showing spectorgram with label:**** \n")
    print(sample[1])
    utils.plot_spec(sample[0], title="Mel spectrogram")
    return (train_dataset, val_dataset, test_dataset)

# %% [markdown]
# ### Pad the data
# As the audio files have different lengths. We need to pad the data and create batches.
#
# For example if the batch size = 3
#  spec1 = [1 2 3 4 5]
#  spec2 = [6 7 8]
#  spec3 = [9 3]
# data_processing function will create batches like:
#
# 1 batch:
# * [1 2 3 4 5]
# * [6 7 8 0 0]
# * [9 3 0 0 0]

# %%
# The following code will be for collat_fn for the pytorch dataloader function    
def data_processing(audio_data):
    spectrograms = []
    labels = []
    input_lengths = []
    label_lengths = []
    #print("data processing")
    for (spec,label) in audio_data:
        #The spectrogram is in (128, 407) and (128, 355) for example but later on for padding the function expects (407, 128) and (355, 128). So we need to transpose the matrices.
        spectrograms.append(torch.Tensor(spec.transpose()))
        t = textprocessor.TextProcessor()
        label = torch.Tensor(t.text2int(text=label))
        labels.append(label)
        input_lengths.append(spec.shape[0]//2)
        label_lengths.append(len(label))
    #print("Start padding")
    spec_pad = torch.nn.utils.rnn.pad_sequence(spectrograms, batch_first=True).unsqueeze(1).transpose(2,3)   #(batch, channel=1, features, time )
    label_pad = torch.nn.utils.rnn.pad_sequence(labels, batch_first=True)
    #print("Finish padding")
    return spec_pad, label_pad, input_lengths, label_lengths

# %% [markdown]
# ### Create the data loaders for training, validation and testing.

# %%
def create_data_loaders(train_dataset, val_dataset, test_dataset, kwargs, batch_size):
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size,shuffle=True,drop_last=True, collate_fn=lambda x: data_processing(x), **kwargs )
    valid_loader = DataLoader(dataset=val_dataset, batch_size=batch_size,shuffle=False,drop_last=True, collate_fn=lambda x: data_processing(x), **kwargs)
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size,shuffle=False,drop_last=True, collate_fn=lambda x: data_processing(x), **kwargs)
    return (train_loader, valid_loader, test_loader)

# %% [markdown]
# ### Training
#
# Ready for training and validating. Using earling stopping using the library from --> https://github.com/Bjarten/early-stopping-pytorch/
#
# We will set up the patience to 15

# %%
def train(n_epochs, train_loader, valid_loader, model, criterion, clip, device, lr, batch_size, save_model_path, save_pkl_path, show_every_n_batch=50):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=lr, 
                                            steps_per_epoch=int(len(train_loader)),
                                            epochs=n_epochs,
                                            anneal_strategy='linear')
    train_data_len = len(train_loader.dataset)
    valid_data_len = len(valid_loader.dataset)
    epoch_train_loss = 0
    epoch_val_loss = 0
    train_losses = []
    valid_losses = []
    print("#######################")
    print("#  Start Training    #")
    print("#######################")
    
    model.train()
    for e in range(n_epochs):
        t0 = time.time()
        #Initialize hidden state
        h = model.init_hidden(batch_size, device)
        #batch loop
        running_loss = 0.0
        for batch_idx, _data in enumerate(train_loader, 1):
            specs, labels, input_lengths, label_lengths = _data
            specs, labels = specs.to(device), labels.to(device)
            #print(batch_idx)
            # Creating new variables for the hidden state, otherwise
            # we'd backprop through the entire training history
            h = h.detach()
            # zero accumulated gradients
            model.zero_grad()
            # get the output from the model
            output, h = model(specs, h)
            output = F.log_softmax(output, dim=2)
            output = output.transpose(0,1)
            # calculate the loss and perform backprop
            loss = criterion(output, labels.float(), input_lengths, label_lengths)
            loss.backward()
            # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
            nn.utils.clip_grad_norm_(model.parameters(), clip)
            optimizer.step()
            scheduler.step()
            # loss stats
            running_loss += loss.item() * specs.size(0)
            if (batch_idx % 1000 == 0):
                output = output.transpose(1,0)
                #print("Training Batch Number: ", batch_idx)
                (decoded_preds, decoded_targets) = textprocessor.GreedyDecoder(output, labels, label_lengths)
                for j in range(len(decoded_preds)):
                    #print("****************************************************************************")
                    #print("Predicted -- {}".format(decoded_preds[j]))
                    #print("Utterance -- {}\n\n".format(decoded_targets[j]))
                    utils.write_to_csv('/kaggle/working/training_results.csv', decoded_preds[j], decoded_targets[j], running_loss, epoch=e+1)
                
        t_t = time.time() - t0

            
        ######################    
        # validate the model #
        ######################
        with torch.no_grad():
            model.eval() 
            tv = time.time()
            running_val_loss = 0.0
            for batch_idx_v, _data in enumerate(valid_loader, 1):
                specs, labels, input_lengths, label_lengths = _data
                specs, labels = specs.to(device), labels.to(device)
                val_h = model.init_hidden(batch_size, device)
                output, val_h = model(specs, val_h)
                output = F.log_softmax(output, dim=2)
                output = output.transpose(0,1)
                val_loss = criterion(output, labels.float(), input_lengths, label_lengths)
                running_val_loss += val_loss.item() * specs.size(0)
                if (batch_idx % 200 == 0):
                    output = output.transpose(1,0)
                    #print("Validation Batch Number: ", batch_idx)
                    (decoded_preds, decoded_targets) = textprocessor.GreedyDecoder(output, labels, label_lengths)
                    for j in range(len(decoded_preds)):
                        #print("****************************************************************************")
                        #print("Predicted -- {}".format(decoded_preds[j]))
                        #print("Utterance -- {}\n\n".format(decoded_targets[j]))
                        utils.write_to_csv('/kaggle/working/validation_results.csv', decoded_preds[j], decoded_targets[j], running_val_loss, epoch=e+1)
            print("Epoch {}: Training took {:.2f} [s]\tValidation took: {:.2f} [s]\n".format(e+1, t_t, time.time() - tv))
                
                
        epoch_train_loss = running_loss / train_data_len
        epoch_val_loss = running_val_loss / valid_data_len
        train_losses.append(epoch_train_loss)
        valid_losses.append(epoch_val_loss)
        print('Epoch: {} Losses\tTraining Loss: {:.6f}\tValidation Loss: {:.6f}'.format(
                e+1, epoch_train_loss, epoch_val_loss))
        model.train()
        
        print("-------------------------------------------------------------------------------------------")
        print('Epoch {} took total {} seconds'.format(e+1, time.time() - t0))
        print("-------------------------------------------------------------------------------------------")

    with open(save_pkl_path, 'wb') as f:       #this will save the list as "results.pkl" which you can load in later 
        pkl.dump((epoch_train_loss, epoch_val_loss), f)
    utils.save_model(save_path=save_model_path, model=model)
    utils.save_checkpoint(save_path=save_model_path, model=model, optimizer=optimizer, epoch=e, loss=train_losses)
    return (model, train_losses, valid_losses)

# %% [markdown]
# ### Test Model
#
# Calculation of WER and CER is done using the code from deepspeech. The average WER and CER is displayed at the end of the test.
# Greedydecoder is used to decode the predicted char.

# %%
def test_model(test_data, model, model_name,device, batch_size):
    model.eval()
    print("#######################")
    print("# Testing Model: {} #".format(model_name))
    print("#######################\n\n")
    test_cer, test_wer = [], []
    test_loss = 0.0
    with torch.no_grad():
        for batch_idx, _data in enumerate(test_data, 1):
            specs, labels, input_lengths, label_lengths = _data
            #print(len(specs))
            specs, labels = specs.to(device), labels.to(device)
            # initialize the hidden state
            batch_size = specs.size(0)
            h = model.init_hidden(batch_size, device)
            # get the output of the rnn
            output, _ = model(specs, h)    
            # get the probabilities
            p = F.softmax(output, dim=2)
            output = output.transpose(0,1) #(time, batch,n_class)
            loss = criterion(output, labels, input_lengths, label_lengths)
            #Input should be [batch, time, n_classes]
            output = output.transpose(1,0)
            test_loss += loss.item()
            (decoded_preds, decoded_targets) = textprocessor.GreedyDecoder(output, labels, label_lengths)
            for j in range(len(decoded_preds)):
                print("****************************************************************************")
                print("Predicted -- {}".format(decoded_preds[j]))
                print("Utterance -- {}\n\n".format(decoded_targets[j]))
                test_cer.append(textprocessor.cer(decoded_targets[j], decoded_preds[j]))
                test_wer.append(textprocessor.wer(decoded_targets[j], decoded_preds[j]))
                utils.write_to_csv('/kaggle/working/'+model_name + '.csv', decoded_preds[j], decoded_targets[j], test_loss)
    avg_cer = sum(test_cer)/len(test_cer)
    avg_wer = sum(test_wer)/len(test_wer)
    print('Test set: Average loss: {:.4f}, Average CER: {:4f} Average WER: {:.4f}\n'.format(test_loss, avg_cer, avg_wer))

# %%
use_cuda = torch.cuda.is_available()
if use_cuda:
    torch.manual_seed(7)
device = torch.device("cuda" if use_cuda else "cpu")

# %%
input_size = 128
n_classes = 29
hidden_dim = 512
n_layers = 1
clip=5 # gradient clipping

lr = 5e-4
epochs = 30
batch_size=32

criterion = nn.CTCLoss(blank=28, zero_infinity=True)

# %%
kwargs={'num_workers': 4, 'pin_memory': True} if use_cuda else {}
(train_dataset, val_dataset, test_dataset) = load_dataset(csv_files=CSV_FILE_PATH, root_dir=ROOT_FOLDERS)
(train_loader, valid_loader, test_loader) = create_data_loaders(train_dataset, val_dataset, test_dataset, kwargs=kwargs, batch_size=batch_size)
# Out:
# Total Training Dataset = 56747, Valid Dataset = 12768 and Test Dataset = 1419
# Total -->  70934
# *****Showing spectorgram with label:****
#
# y a los catorce habia empezado a traducir del griego a anacreonte

# %%
conv_bigru_net = models.ASRConvBiGRU(in_channel=1, gru_input_size=512, hidden_dim=hidden_dim, n_layers=n_layers, n_feats=128, n_classes=n_classes, drop_prob=0.2)
conv_bigru_net.apply(models.weight_init)
conv_bigru_net.to(device)
print(conv_bigru_net)
# Out:
# ASRConvBiGRU(
#   (conv1): Conv2d(1, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   (fully_connected): Linear(in_features=2048, out_features=512, bias=True)
#   (gru_layers): Sequential(
#     (0): BiGRU(
#       (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (BiGRU): GRU(512, 512, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#     )
#     (1): BiGRU(
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (BiGRU): GRU(1024, 512, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#     )
#     (2): BiGRU(
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (BiGRU): GRU(1024, 512, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#     )
#     (3): BiGRU(
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (BiGRU): GRU(1024, 512, batch_first=True, bidirectional=True)
#       (dropout): Dropout(p=0.2, inplace=False)
#     )
#   )
#   (classifier): Linear(in_features=1024, out_features=29, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
(convbigru_model, conv_bigru_train_losses, conv_bigru_valid_losses) = train(n_epochs=epochs, train_loader=train_loader, valid_loader=valid_loader,
                                                                          model=conv_bigru_net, criterion=criterion, clip=clip,
                                                                          device=device, lr=lr, batch_size=batch_size,
                                                                          save_model_path=SAVE_RESULTS_PATH+"/conv_bigru",
                                                                          save_pkl_path=SAVE_MODELS_PATH + "/training_conv_bigru_results.pkl")
# Out:
# #######################
# #  Start Training    #
# #######################
# Epoch 1: Training took 644.42 [s]	Validation took: 121.98 [s]
#
# Epoch: 1 Losses	Training Loss: 1.655819	Validation Loss: 1.576129
# -------------------------------------------------------------------------------------------
# Epoch 1 took total 766.3998520374298 seconds
# -------------------------------------------------------------------------------------------
# Epoch 2: Training took 607.12 [s]	Validation took: 120.00 [s]
#
# Epoch: 2 Losses	Training Loss: 1.537155	Validation Loss: 1.568903
# -------------------------------------------------------------------------------------------
# Epoch 2 took total 727.1193137168884 seconds
# -------------------------------------------------------------------------------------------
# Epoch 3: Training took 606.56 [s]	Validation took: 120.44 [s]
#
# Epoch: 3 Losses	Training Loss: 1.408143	Validation Loss: 1.361190
# -------------------------------------------------------------------------------------------
# Epoch 3 took total 727.0032057762146 seconds
# -------------------------------------------------------------------------------------------
# Epoch 4: Training took 706.95 [s]	Validation took: 144.50 [s]
#
# Epoch: 4 Losses	Training Loss: 1.330707	Validation Loss: 1.312587
# -------------------------------------------------------------------------------------------
# Epoch 4 took total 851.4487679004669 seconds
# -------------------------------------------------------------------------------------------
# Epoch 5: Training took 699.15 [s]	Validation took: 141.32 [s]
#
# Epoch: 5 Losses	Training Loss: 1.292021	Validation Loss: 1.237985
# -------------------------------------------------------------------------------------------
# Epoch 5 took total 840.4771757125854 seconds
# -------------------------------------------------------------------------------------------
# Epoch 6: Training took 697.98 [s]	Validation took: 142.84 [s]
#
# Epoch: 6 Losses	Training Loss: 1.221517	Validation Loss: 1.164271
# -------------------------------------------------------------------------------------------
# Epoch 6 took total 840.8199889659882 seconds
# -------------------------------------------------------------------------------------------
# Epoch 7: Training took 704.80 [s]	Validation took: 143.29 [s]
#
# Epoch: 7 Losses	Training Loss: 1.190045	Validation Loss: 1.117742
# -------------------------------------------------------------------------------------------
# Epoch 7 took total 848.0888137817383 seconds
# -------------------------------------------------------------------------------------------
# Epoch 8: Training took 704.47 [s]	Validation took: 141.83 [s]
#
# Epoch: 8 Losses	Training Loss: 1.134740	Validation Loss: 1.141623
# -------------------------------------------------------------------------------------------
# Epoch 8 took total 846.3024098873138 seconds
# -------------------------------------------------------------------------------------------
# Epoch 9: Training took 710.67 [s]	Validation took: 142.54 [s]
#
# Epoch: 9 Losses	Training Loss: 1.093094	Validation Loss: 1.049568
# -------------------------------------------------------------------------------------------
# Epoch 9 took total 853.2135450839996 seconds
# -------------------------------------------------------------------------------------------
# Epoch 10: Training took 712.59 [s]	Validation took: 140.50 [s]
#
# Epoch: 10 Losses	Training Loss: 1.057958	Validation Loss: 1.007137
# -------------------------------------------------------------------------------------------
# Epoch 10 took total 853.0839445590973 seconds
# -------------------------------------------------------------------------------------------
# Epoch 11: Training took 709.84 [s]	Validation took: 145.27 [s]
#
# Epoch: 11 Losses	Training Loss: 1.011052	Validation Loss: 0.968846
# -------------------------------------------------------------------------------------------
# Epoch 11 took total 855.1027972698212 seconds
# -------------------------------------------------------------------------------------------
# Epoch 12: Training took 722.35 [s]	Validation took: 144.67 [s]
#
# Epoch: 12 Losses	Training Loss: 0.974831	Validation Loss: 0.962930
# -------------------------------------------------------------------------------------------
# Epoch 12 took total 867.0166981220245 seconds
# -------------------------------------------------------------------------------------------
# Epoch 13: Training took 710.65 [s]	Validation took: 142.28 [s]
#
# Epoch: 13 Losses	Training Loss: 0.945674	Validation Loss: 0.914243
# -------------------------------------------------------------------------------------------
# Epoch 13 took total 852.9361910820007 seconds
# -------------------------------------------------------------------------------------------
# Epoch 14: Training took 713.38 [s]	Validation took: 145.66 [s]
#
# Epoch: 14 Losses	Training Loss: 0.905819	Validation Loss: 0.879877
# -------------------------------------------------------------------------------------------
# Epoch 14 took total 859.043426990509 seconds
# -------------------------------------------------------------------------------------------
# Epoch 15: Training took 706.77 [s]	Validation took: 141.49 [s]
#
# Epoch: 15 Losses	Training Loss: 0.875592	Validation Loss: 0.844507
# -------------------------------------------------------------------------------------------
# Epoch 15 took total 848.2583146095276 seconds
# -------------------------------------------------------------------------------------------
# Epoch 16: Training took 701.70 [s]	Validation took: 143.44 [s]
#
# Epoch: 16 Losses	Training Loss: 0.850295	Validation Loss: 0.846040
# -------------------------------------------------------------------------------------------
# Epoch 16 took total 845.1410949230194 seconds
# -------------------------------------------------------------------------------------------
# Epoch 17: Training took 704.95 [s]	Validation took: 140.96 [s]
#
# Epoch: 17 Losses	Training Loss: 0.820620	Validation Loss: 0.821019
# -------------------------------------------------------------------------------------------
# Epoch 17 took total 845.914323091507 seconds
# -------------------------------------------------------------------------------------------
# Epoch 18: Training took 708.08 [s]	Validation took: 145.95 [s]
#
# Epoch: 18 Losses	Training Loss: 0.791568	Validation Loss: 0.798509
# -------------------------------------------------------------------------------------------
# Epoch 18 took total 854.0327079296112 seconds
# -------------------------------------------------------------------------------------------
# Epoch 19: Training took 716.99 [s]	Validation took: 145.09 [s]
#
# Epoch: 19 Losses	Training Loss: 0.766415	Validation Loss: 0.767632
# -------------------------------------------------------------------------------------------
# Epoch 19 took total 862.0870585441589 seconds
# -------------------------------------------------------------------------------------------
# Epoch 20: Training took 712.70 [s]	Validation took: 145.27 [s]
#
# Epoch: 20 Losses	Training Loss: 0.741687	Validation Loss: 0.752704
# -------------------------------------------------------------------------------------------
# Epoch 20 took total 857.9703986644745 seconds
# -------------------------------------------------------------------------------------------
# Epoch 21: Training took 708.82 [s]	Validation took: 143.86 [s]
#
# Epoch: 21 Losses	Training Loss: 0.714313	Validation Loss: 0.786064
# -------------------------------------------------------------------------------------------
# Epoch 21 took total 852.6842901706696 seconds
# -------------------------------------------------------------------------------------------
# Epoch 22: Training took 712.63 [s]	Validation took: 144.02 [s]
#
# Epoch: 22 Losses	Training Loss: 0.691728	Validation Loss: 0.737554
# -------------------------------------------------------------------------------------------
# Epoch 22 took total 856.6490156650543 seconds
# -------------------------------------------------------------------------------------------
# Epoch 23: Training took 718.04 [s]	Validation took: 145.20 [s]
#
# Epoch: 23 Losses	Training Loss: 0.670535	Validation Loss: 0.725163
# -------------------------------------------------------------------------------------------
# Epoch 23 took total 863.238144159317 seconds
# -------------------------------------------------------------------------------------------
# Epoch 24: Training took 707.27 [s]	Validation took: 143.05 [s]
#
# Epoch: 24 Losses	Training Loss: 0.649422	Validation Loss: 0.743115
# -------------------------------------------------------------------------------------------
# Epoch 24 took total 850.3196587562561 seconds
# -------------------------------------------------------------------------------------------
# Epoch 25: Training took 706.76 [s]	Validation took: 140.83 [s]
#
# Epoch: 25 Losses	Training Loss: 0.629962	Validation Loss: 0.717484
# -------------------------------------------------------------------------------------------
# Epoch 25 took total 847.5950491428375 seconds
# -------------------------------------------------------------------------------------------
# Epoch 26: Training took 705.47 [s]	Validation took: 143.61 [s]
#
# Epoch: 26 Losses	Training Loss: 0.609567	Validation Loss: 0.687856
# -------------------------------------------------------------------------------------------
# Epoch 26 took total 849.083170413971 seconds
# -------------------------------------------------------------------------------------------
# Epoch 27: Training took 713.55 [s]	Validation took: 146.04 [s]
#
# Epoch: 27 Losses	Training Loss: 0.592966	Validation Loss: 0.697035
# -------------------------------------------------------------------------------------------
# Epoch 27 took total 859.5912439823151 seconds
# -------------------------------------------------------------------------------------------
# Epoch 28: Training took 712.21 [s]	Validation took: 146.48 [s]
#
# Epoch: 28 Losses	Training Loss: 0.578304	Validation Loss: 0.688341
# -------------------------------------------------------------------------------------------
# Epoch 28 took total 858.6835408210754 seconds
# -------------------------------------------------------------------------------------------
# Epoch 29: Training took 708.72 [s]	Validation took: 141.94 [s]
#
# Epoch: 29 Losses	Training Loss: 0.564725	Validation Loss: 0.669072
# -------------------------------------------------------------------------------------------
# Epoch 29 took total 850.6635813713074 seconds
# -------------------------------------------------------------------------------------------
# Epoch 30: Training took 710.88 [s]	Validation took: 142.76 [s]
#
# Epoch: 30 Losses	Training Loss: 0.555517	Validation Loss: 0.678318
# -------------------------------------------------------------------------------------------
# Epoch 30 took total 853.6427981853485 seconds
# -------------------------------------------------------------------------------------------

# %%
test_model(test_loader, convbigru_model, "CONV-BI-RNN", device, batch_size=batch_size)
# Out:
# #######################
# # Testing Model: CONV-BI-RNN #
# #######################
#
#
# ****************************************************************************
# Predicted -- andto suea q u nt ne o seses s
# Utterance -- alento a sus esclavos de manera que en un instante llevaron al bergantin los cofres y riquezas
#
#
# ****************************************************************************
# Predicted -- el cuedtentdesoalparse
# Utterance -- el juez empezo a palparse
#
#
# ****************************************************************************
# Predicted -- no es mucho que estatimn
# Utterance -- no es mucho que desatine
#
#
# ****************************************************************************
# Predicted -- ela aos
# Utterance -- estas palabras las oi confusamente y despues me quede solo o mejor dicho acompanado de algunos chicuelos que me empujaban de aca para alla jugando conmigo
#
#
# ****************************************************************************
# Predicted -- pues o bien abvicio que vonima gente
# Utterance -- pues no bien advirtio que venia gente
#
#
# ****************************************************************************
# Predicted -- des o s o o o es oss
# Utterance -- bendito sea el senor omnipotente y misericordioso exclame despues de esto no necesito mas que ojos y afortunadamente los tengo
#
#
# ****************************************************************************
# Predicted -- tuque pue des sentender
# Utterance -- tu que puedes entender
#
#
# ****************************************************************************
# Predicted -- juandedios comia en casa de lo reuejos
# Utterance -- juan de dios comia en casa de los requejos
#
#
# ****************************************************************************
# Predicted -- es a i r a ar rare cncesaos
# Utterance -- eso seria muy peligroso yo no puedo hacer eso sin ponerme antes de acuerdo con ella para que prepare su evasion con prudencia y sin escandalo
#
#
# ****************************************************************************
# Predicted -- esta a si termamentempe caba mo tal
# Utterance -- estaras eternamente en pecado mortal
#
#
# ****************************************************************************
# Predicted -- se ase l i e s s s i e o oionin
# Utterance -- se hace al fin esposa del sin par guerrero sigfrido
#
#
# ****************************************************************************
# Predicted -- de monera que si no se casa rergo con ella
# Utterance -- de manera que si no se casara luego con ella
#
#
# ****************************************************************************
# Predicted -- la s ura a ia ei esietes
# Utterance -- yo aseguro que podra ver a su hija en madrid siempre que lo solicite
#
#
# ****************************************************************************
# Predicted -- los peron o midraquellas enacions qescura
# Utterance -- los perros no olvidaron aquella sensacion de frescura
#
#
# ****************************************************************************
# Predicted -- sena e e u e e e e a a a o eseses
# Utterance -- se empena don miguel de unamuno en que ponga yo un prologo a este su libro en que se relata la tan lamentable historia de mi buen amigo augusto perez y su misteriosa muerte
#
#
# ****************************************************************************
# Predicted -- como quiera la ce u na toda via que la mismo
# Utterance -- comoquiera la fe iluminaba todavia aquel abismo
#
#
# ****************************************************************************
# Predicted -- matando odo lo que quiso
# Utterance -- matando todo lo que quiso
#
#
# ****************************************************************************
# Predicted -- y para tajar dispustos sistoriatanma entable
# Utterance -- y para atajar discursos de historia tan lamentable
#
#
# ****************************************************************************
# Predicted -- y los tuvos preso todo ala via
# Utterance -- y lo tuvo preso toda la vida
#
#
# ****************************************************************************
# Predicted -- re alo ues ene eta a i o ea u eiseis
# Utterance -- recayo pues brevemente la sentencia dando por valido y obligatorio el voto de que se trataba hasta que el sumo pontifice
#
#
# ****************************************************************************
# Predicted -- la muje uneno cno e an n a a eas
# Utterance -- la mujer es un pendulo continuo que oscila entre el instinto natural y la aprendida verguenza
#
#
# ****************************************************************************
# Predicted -- las alonda santa y es lbveria e uciero plado
# Utterance -- las alondras cantan y el sol brilla en un cielo claro
#
#
# ****************************************************************************
# Predicted -- asi como que n o tue de la cosa
# Utterance -- asi como quien no quiere la cosa
#
#
# ****************************************************************************
# Predicted -- callo de viva o los pies de las sillo de condan
# Utterance -- cayo derribado a los pies de la senora de roldan
#
#
# ****************************************************************************
# Predicted -- como bro prore s ulen i ant e noitstrtos
# Utterance -- como un rio que rompe los diques que durantesiglos le han contenido y se extiende por el llano con impetu destructor
#
#
# ****************************************************************************
# Predicted -- lo que yo se hi jcal fin
# Utterance -- lo que yo se dije al fin
#
#
# ****************************************************************************
# Predicted -- sal a ss
# Utterance -- la senorita ines ha sido reconocida por aquel un violento golpe arrebato el papel de mis manos
#
#
# ****************************************************************************
# Predicted -- de cos iete a stois encnta ura toda poseluida de uaas
# Utterance -- de consiguiente la historia se encuentra fuera de toda posibilidad de duda
#
#
# ****************************************************************************
# Predicted -- mo as a a s s s s s n as
# Utterance -- no me has dicho nada de aquella persona ya lo sabras todo me contesto sin oponerse a que le comiese a besos las manos ven pronto a casa
#
#
# ****************************************************************************
# Predicted -- tamo a parecio yl al noce y asi
# Utterance -- tampoco aparecio en la noche y asi
#
#
# ****************************************************************************
# Predicted -- se aco s e i ae
# Utterance -- sea como sea dijo juanita yo agradezco a ustedes mucho el favor que me hacen
#
#
# ****************************************************************************
# Predicted -- las mojaqu nere r eia unr o uscioas
# Utterance -- las monjas que habian esperado encontrarla restituida a su primera robustez y lozania
#
#
# ****************************************************************************
# Predicted -- la esconotiano pudo contara la risa
# Utterance -- la desconocida no pudo contener la risa
#
#
# ****************************************************************************
# Predicted -- el seque e a a a atdt a o es
# Utterance -- geiselher y gere habian llegado tambien con dankwart y volker
#
#
# ****************************************************************************
# Predicted -- y que e esas a asdse eso
# Utterance -- y creo que si hubiese sabido cual era el caracter y el verdadero estado de salud de su sobrino
#
#
# ****************************************************************************
# Predicted -- i nes s e sas s e e tos
# Utterance -- ines esconde a la senora en el cuarto de los libros que yo archivare a este sujeto en otro lado
#
#
# ****************************************************************************
# Predicted -- pasados lososo deresprmerlos esdeste elaftancia
# Utterance -- pasados los dos o tres primeros meses de lactancia
#
#
# ****************************************************************************
# Predicted -- masalecuados a mas hacila dedicosasa cuales
# Utterance -- mas adecuados a nuestras ideas religiosas actuales
#
#
# ****************************************************************************
# Predicted -- y que o la poria gullar
# Utterance -- y que no la podia burlar
#
#
# ****************************************************************************
# Predicted -- y haba calados mando ente apuetas mano e mpeass
# Utterance -- y habia soldados marchando frente a la puerta sonando trompetas
#
#
# ****************************************************************************
# Predicted -- eststae ses s pa e erlir
# Utterance -- el sistema que vds siguen no es el mas a proposito para hacerse querer de la nina
#
#
# ****************************************************************************
# Predicted -- enaiendopro esauado laspretes as quela ordenes
# Utterance -- anadiendo por nuestra voluntad nuevas tristezas a las que ya nos rodean
#
#
# ****************************************************************************
# Predicted -- volvio lraian la cabezaveiendose de la bula que nacia
# Utterance -- volvio el gayan la cabeza riendose de la burla que me hacia
#
#
# ****************************************************************************
# Predicted -- el senor nonde deo no a istito ormamo de pregunte
# Utterance -- el senor nomdedeu no ha asistido a tu hermano le pregunte
#
#
# ****************************************************************************
# Predicted -- y todo en no es mas abajo
# Utterance -- y dos renglones mas abajo
#
#
# ****************************************************************************
# Predicted -- repito l que dija comezca el diero
# Utterance -- repito lo que dije al comenzar el libro
#
#
# ****************************************************************************
# Predicted -- nu cas aia prucuadolaete cmaor la elea derocioneis
# Utterance -- nunca se habia preocupado la gente como ahora de acelerar la reproduccion
#
#
# ****************************************************************************
# Predicted -- aquia conpuesio ila d dea re pentiendo nlostados
# Utterance -- aqui la confusion y verdadero arrepentimiento de los pecados
#
#
# ****************************************************************************
# Predicted -- cun i s
# Utterance -- junto al cuerpo de un herido y bajo la cabeza del caballo moribundo marijuan se llego a mi con los brazos abiertos y grito
#
#
# ****************************************************************************
# Predicted -- ca acosanfu tieon poy ma s n amvintos
# Utterance -- cada cosa en su tiempo y los nabos en adviento
#
#
# ****************************************************************************
# Predicted -- ata sitacion abian edado i sentios con deseristan s
# Utterance -- a tal situacion habian llegado mis sentidos cuando el sacristan
#
#
# ****************************************************************************
# Predicted -- sacaraon ayites estaba nechos
# Utterance -- sacaron naipes estaban hechos
#
#
# ****************************************************************************
# Predicted -- y como ued s pererimi as mosera reian delnundo
# Utterance -- y como fue de los que el rey envio a somosierra a recibir al melenudo
#
#
# ****************************************************************************
# Predicted -- aente onea e e s s sosososs
# Utterance -- hagen de troneja caminaba siempre delante y muchas veces fue a ayudar a los nibelungos
#
#
# ****************************************************************************
# Predicted -- que entariam ienesaspaientosque hseho m contsto
# Utterance -- te sentarian bien esos aspavientos que has hecho me contesto
#
#
# ****************************************************************************
# Predicted -- la quiesa pe tos yos hombes de memerida
# Utterance -- la fiereza de todos los hombres de brunequilda
#
#
# ****************************************************************************
# Predicted -- se ria resa a asasas
# Utterance -- servia para extender las papeletas algunas de las cuales esperaban sobre la mesa la anhelada victima
#
#
# ****************************************************************************
# Predicted -- pero aororou e n r rer r orosoes
# Utterance -- pero no me provoques ni detengas un momento mas lo que no te pertenece reptil porque te aplasto
#
#
# ****************************************************************************
# Predicted -- pos s a a a a ase e e ss
# Utterance -- todos los articulos del comercio estaban alli reunidos y hacinados con cierto orden los requejos vendian telas de lana y algodones a saber
#
#
# ****************************************************************************
# Predicted -- do vis s a a a a a ua as
# Utterance -- de rodillas en el suelo hizo de la cama reclinatorio y apoyando el rostro sobre ella estuvo llorando todo el dia
#
#
# ****************************************************************************
# Predicted -- ave d ca sido oanconcnci de ries s
# Utterance -- a veces me parecia que los minutos corrian con inconcebible rapidez
#
#
# ****************************************************************************
# Predicted -- tan ua esto s c cis a a a ano s
# Utterance -- tan mudada estoy respondio ella con melancolica sonrisa y besandole la mano
#
#
# ****************************************************************************
# Predicted -- y las qesta mece conociene si
# Utterance -- y los que esta merced conocieren en si
#
#
# ****************************************************************************
# Predicted -- y tanto dije ue i itinenss
# Utterance -- y tanto dije yo que he compuesto coplas y tenido pendencias
#
#
# ****************************************************************************
# Predicted -- mede muie con ustede seiguida
# Utterance -- me reunire con usted enseguida
#
#
# ****************************************************************************
# Predicted -- paic s atas
# Utterance -- parecia que la misma tierra sacudiendose bajo las herraduras de nuestros caballos nos echaba hacia adelante
#
#
# ****************************************************************************
# Predicted -- espun a sa otososor
# Utterance -- despues una de las muchachas lanzo un grito espantoso y desgarrador
#
#
# ****************************************************************************
# Predicted -- mindicie as sacionabies
# Utterance -- ni milicias nacionales
#
#
# ****************************************************************************
# Predicted -- que a reridi a onsus stenora onecareo e a eno e a
# Utterance -- creo haber respondido a las consultas con que usted me honra por encargo de la senora de maltrana
#
#
# ****************************************************************************
# Predicted -- cona ico qea aiasa t as
# Utterance -- con cara de mico muequera arrugadilla y sardonica se adelanto apresurado al divisar a la pareja
#
#
# ****************************************************************************
# Predicted -- ouyito os ormeneres dn esaresian tinmierancia
# Utterance -- omito los pormenores de nuestra residencia en francia
#
#
# ****************************************************************************
# Predicted -- y a muete a a e os
# Utterance -- y la muerte seguia mirando al emperador con sus ojos huecos y frios
#
#
# ****************************************************************************
# Predicted -- dondes conderias de soro en el pajar
# Utterance -- donde esconderia su tesoro en el pajar
#
#
# ****************************************************************************
# Predicted -- y en spisos lsmontes qu ue s case ano rae
# Utterance -- y en espinosa de los monteros lo que hubo fue que todos los franceses echaron a correr
#
#
# ****************************************************************************
# Predicted -- no o no es que io uiealurade sus cpalabras
# Utterance -- no no es que yo quiera dudar de sus palabras
#
#
# ****************************************************************************
# Predicted -- pues a o amamaiaias
# Utterance -- pues cartas tengo aqui del principe de lichenstein del archiduque carlos eugenio del conde de schoenbrunn
#
#
# ****************************************************************************
# Predicted -- las aficiones de los ciuds ye istes se ani
# Utterance -- las aflicciones de los atribulados y tristes se han
#
#
# ****************************************************************************
# Predicted -- era la degrina y ispeta
# Utterance -- era a la vez llena y esbelta
#
#
# ****************************************************************************
# Predicted -- el iderisas dequ aun esperabasa mas suyla
# Utterance -- el infeliz sastre que aun esperaba salvar su vida
#
#
# ****************************************************************************
# Predicted -- ai oro s
# Utterance -- aquellos mancebos que salian al redondel con liston amarillo o morado aquellos barbudos reyes de jaen o antequera que caballero
#
#
# ****************************************************************************
# Predicted -- no pesospria e e e e i iaicicioas
# Utterance -- no temas por tu miserable vida porque no me ensanare en ese infeliz cuerpo a quien dios ha dado el merecido infierno con anticipacion
#
#
# ****************************************************************************
# Predicted -- ala ar orio nto o a ae e non s
# Utterance -- al hallarme solo reuni todos absolutamente todos los rayos de mi razon
#
#
# ****************************************************************************
# Predicted -- aia intntaresa spade de lasaotrida desracioss
# Utterance -- habia de intentar rescatar a su padre de las autoridades facciosas
#
#
# ****************************************************************************
# Predicted -- mi a ra quea usepai a sona de un resoarente
# Utterance -- ni era probable que anduviese por alli la sombra de una persona decente
#
#
# ****************************************************************************
# Predicted -- ponoto encoransa qe qunopeoitnejecio de aroes
# Utterance -- prontos a incorporarnos al pequeno pero brillante ejercito de san roque
#
#
# ****************************************************************************
# Predicted -- no ha ume dequil escapre solo comela
# Utterance -- no habra un medio de que yo escape solo con ella
#
#
# ****************************************************************************
# Predicted -- y a sate canotr el nada
# Utterance -- ya se acercan otra vez nada
#
#
# ****************************************************************************
# Predicted -- eue la cual e acetado apasa el rztu
# Utterance -- en la cual era aceptado hasta el verdugo
#
#
# ****************************************************************************
# Predicted -- indicados confusavente por pos pidicos
# Utterance -- indicados confusamente por los periodicos
#
#
# ****************************************************************************
# Predicted -- y enabiendo nosapartado cosa de iem pasos
# Utterance -- y en habiendonos apartado cosa de cien pasos
#
#
# ****************************************************************************
# Predicted -- aquino aorasom a a e s
# Utterance -- a los que siguieron atronadoras bombas las mujeres arrojaron flores al carruaje
#
#
# ****************************************************************************
# Predicted -- papa todo ello con en iqueno tra ue serio
# Utterance -- tapado todo ello con el mezquino traje exterior
#
#
# ****************************************************************************
# Predicted -- no pa a as e a n oness
# Utterance -- no podian apartarse los franceses de su cuartel general como no fuera en grandes destacamentos
#
#
# ****************************************************************************
# Predicted -- asi a qiemaba elanchalo y ahora todo se ba umpien
# Utterance -- asi lo afirmaba el anciano y ahora todo se va cumpliendo
#
#
# ****************************************************************************
# Predicted -- aoa a a a a a a a a a a a o o s
# Utterance -- corrio algun tiempo mas y entonces observamos que las tropas que ocupaban lo alto del cerro lo abandonaban lentamente resguardadas por el frente que seguia haciendo fuego
#
#
# ****************************************************************************
# Predicted -- sbuegva su mece antes de las res
# Utterance -- vuelva su merced antes de las tres
#
#
# ****************************************************************************
# Predicted -- y an maes a a o o i iaas
# Utterance -- y cuando los mas valientes argivos penetramos en el caballo que fabrico epeo y a mi se me confio todo asi el abrir como el cerrar la solida emboscada
#
#
# ****************************************************************************
# Predicted -- como yio se lo que ie sempre
# Utterance -- como yo se lo pedire siempre
#
#
# ****************************************************************************
# Predicted -- no di eiso etra o e s sedeisisniseieiees
# Utterance -- no direis que os he estorbado el paso contesto el ahora que no soy sino soldado del temple y he renunciado a mis derechos de senor independiente
#
#
# ****************************************************************************
# Predicted -- eselente caballero na deide odo de indel mundo
# Utterance -- excelente caballero me ha de venir todo el bien del mundo
#
#
# ****************************************************************************
# Predicted -- sino bre lo des de eredo del budo un atocho
# Utterance -- sino redondeles de terreno del vuelo de un plato chico
#
#
# ****************************************************************************
# Predicted -- por el dicenciado ogo o los yios de iesilia
# Utterance -- por el licenciado lobo por los tios de inesilla
#
#
# ****************************************************************************
# Predicted -- en pie aque aia esaea e e a cna e ece s
# Utterance -- en el principio del ataque la bateria puesta detras de laveterinaria rechazo con tanta energia el empuje de los franceses
#
#
# ****************************************************************************
# Predicted -- pasa y teo eu pres e o ieiteieioris
# Utterance -- pasado mi temor que fue presto quede con un sosiego y gozo y deleite interior
#
#
# ****************************************************************************
# Predicted -- hase la que aran cados de suvesta si se igcioso
# Utterance -- hacia la que arrancados de su extasis religioso
#
#
# ****************************************************************************
# Predicted -- no sel abia exte mio diebre
# Utterance -- no se le habia extendido billete
#
#
# ****************************************************************************
# Predicted -- me que pasto la dia aquedos pae ustes
# Utterance -- me querras todavia a que buscar luces
#
#
# ****************************************************************************
# Predicted -- cati eso pi la tiera y m dijo que
# Utterance -- cati echo pie a tierra y me dijo que
#
#
# ****************************************************************************
# Predicted -- duos podvado es ciamadon mon espadas
# Utterance -- los pobladores se armaron con espadas
#
#
# ****************************************************************************
# Predicted -- cuando precibio esta in espera descust
# Utterance -- cuando recibio esta inesperada respuesta
#
#
# ****************************************************************************
# Predicted -- para amncrar nos con ell dedia
# Utterance -- para honrarnos con ello de dia
#
#
# ****************************************************************************
# Predicted -- y que comparas omo da eseios nstaosopopcionais
# Utterance -- y quien comparta las comodidades que dios y nuestro trabajo nos han proporcionado ay
#
#
# ****************************************************************************
# Predicted -- esta comesacion es nu loanto da la noche
# Utterance -- estas conversaciones no duraban toda la noche
#
#
# ****************************************************************************
# Predicted -- no poma la ca triste
# Utterance -- no pongas la cara triste
#
#
# ****************************************************************************
# Predicted -- tusa es ine r esisn
# Utterance -- tu sabes y sientes mejor que yo exclame tu me senalas el camino que debo seguir
#
#
# ****************************************************************************
# Predicted -- y por la paranza de la cenaja
# Utterance -- y por la tardanza de la cena
#
#
# ****************************************************************************
# Predicted -- porque no lus acas ien e madar
# Utterance -- porque no los acabasen de matar
#
#
# ****************************************************************************
# Predicted -- con quelasa a a a e isass
# Utterance -- con aquella majestad inimitable y poderosa y haciendo brillar de una manera que pudiera decirse magica sus hermosas botas
#
#
# ****************************************************************************
# Predicted -- pode ueriuiy in eiansesa isis
# Utterance -- por el que reunio al imperio frances los estados pontificios
#
#
# ****************************************************************************
# Predicted -- yojero que sese n e didsisoss
# Utterance -- yo creo que esta especie de ateismo que se burla de los sentimientos
#
#
# ****************************************************************************
# Predicted -- ya quel entusas mofri ausar espepitos obveaje
# Utterance -- de aquel entusiasmo febril causaba estrepitoso oleaje
#
#
# ****************************************************************************
# Predicted -- y que tatentem ogha iouicido comuitoes y palmas
# Utterance -- y que traten de embobar a leovigildo con vitores y palmadas
#
#
# ****************************************************************************
# Predicted -- el cuerto esta miria us
# Utterance -- el cuarto esta a media luz
#
#
# ****************************************************************************
# Predicted -- asi lo prero respodio susobrina
# Utterance -- asi lo creo respondio su sobrino
#
#
# ****************************************************************************
# Predicted -- se u a a a a a a s s s s sis
# Utterance -- sueno que mi casa hoy tan triste esta de fiesta que tu papa ha venido a pasar con nosotros algunos dias que celebramos su cumpleanos y que todos reimos venturosos y satisfechos
#
#
# ****************************************************************************
# Predicted -- aunque no conitencion a viesa
# Utterance -- aunque no con intencion aviesa
#
#
# ****************************************************************************
# Predicted -- quesi guda aque udise de muntiformaen quen
# Utterance -- eres sin duda aquel odiseo de multiforme ingenio
#
#
# ****************************************************************************
# Predicted -- y a cuos a sosososososs
# Utterance -- y era que cuando su ayo o la condesa no le hacian el gusto en alguna cosa poniase los punos en los ojos
#
#
# ****************************************************************************
# Predicted -- le a a aiasasasas
# Utterance -- eso dicen pero te aseguro chinitas que eso me tiene sin cuidado pues a mi no hasta aqui llego la cosa hasta aqui aguantamos y de aqui no ha de pasar
#
#
# ****************************************************************************
# Predicted -- y tane a ass
# Utterance -- y tanto me atendio y agasajo en madrid que he vivido siempre profundamente agradecido a sus bondades
#
#
# ****************************************************************************
# Predicted -- pues mi aru yo senme que venia
# Utterance -- pues mira tu yo sone que venia
#
#
# ****************************************************************************
# Predicted -- asi e n unan puid iuamominto de anilida o eijo s
# Utterance -- asi dona aurora no podia disfrutar momento de tranquilidad con aquel hijo
#
#
# ****************************************************************************
# Predicted -- mascando su rabuta ente cougidos degranos de tierbae i
# Utterance -- mascando su dura pulpa entre crujidos de granos de tierra
#
#
# ****************************************************************************
# Predicted -- prque siempesio compaio e r o arss
# Utterance -- porque siempre he sido compasivo y el me respondio en una palabra celos
#
#
# ****************************************************************************
# Predicted -- enpadenadon puromelo iadoconpesad s orela
# Utterance -- encuadernado en cuero negro y cerrado con pesados broches de plata
#
#
# ****************************************************************************
# Predicted -- andes estaba en lasaba conistidas
# Utterance -- andres estaba en la sala con mis tias
#
#
# ****************************************************************************
# Predicted -- creimo syo y e soldo cudo den no curamos
# Utterance -- creimoslo y el soldado juro de no jurar mas
#
#
# ****************************************************************************
# Predicted -- yipesntsepicac conete n a e e c oco edsosasa
# Utterance -- mis pensamientos se purificaban con vuestra memoria en todas partes veia vuestra imagen como un reflejo de la de dios
#
#
# ****************************************************************************
# Predicted -- sali losol a lacapa y ad e s leis
# Utterance -- sabelo sola la capa y guardamonos de dias de aire
#
#
# ****************************************************************************
# Predicted -- epoldio conoce cuntabandaimoveza esoa su alma
# Utterance -- he podido conocer cuanta bondad y nobleza atesora su alma
#
#
# ****************************************************************************
# Predicted -- desaliezco y pare que me a cabo
# Utterance -- desfallezco y parece que me acabo
#
#
# ****************************************************************************
# Predicted -- una entretodas era partipurameco ante
# Utterance -- una entre todas era particularmente chocante
#
#
# ****************************************************************************
# Predicted -- tantnen e e e ess
# Utterance -- francamente y sin ruborizarme digo que tenia mas ganas de comer que de batirme y que
#
#
# ****************************************************************************
# Predicted -- que cababa maniedeayientnterosere de laspiais y ena
# Utterance -- que causaban panico y desaliento entre los heroes de las piramides y de jena
#
#
# ****************************************************************************
# Predicted -- y asi qe hacicabacio la puerta
# Utterance -- y asi que la chica batio la puerta
#
#
# ****************************************************************************
# Predicted -- a a a asas  is
# Utterance -- por lo visto madrid entero se levanta contra ellos al decir esto una detonacion terrible hizo estremecer la casa
#
#
# ****************************************************************************
# Predicted -- y sasisi a a as
# Utterance -- y la sigo y o se pierde entre la multitud o avanza tanto en su camino que no puedo alcanzarla
#
#
# ****************************************************************************
# Predicted -- ali todo oblaba de lo pasado
# Utterance -- alli todo hablaba de lo pasado
#
#
# ****************************************************************************
# Predicted -- d e a n oas
# Utterance -- ya viene por las baronesas ya viene por los cartujos una voz conocida me hizo volver la cara
#
#
# ****************************************************************************
# Predicted -- didionepesintraisqe esepa a manta o reca o nisnes
# Utterance -- medir con el pensamiento la distancia que me separaba de la montana y correr hacia alla todo paso en el mismo instante
#
#
# ****************************************************************************
# Predicted -- sus ojosenenidos consroba an guyas derecientes aremas
# Utterance -- sus ojos encendidos conservaban huellas de recientes lagrimas
#
#
# ****************************************************************************
# Predicted -- dior nos se a todo salu
# Utterance -- dios nos de a todos salud
#
#
# ****************************************************************************
# Predicted -- dis pta i i i s sasisi is sosoroes
# Utterance -- digame su paternidad saca o no las botellicas y luego sin desconcertarse ante la ironia de su superior
#
#
# ****************************************************************************
# Predicted -- oa coreso une aeseseasesas
# Utterance -- otras con perezoso cuneo al traves de las eternas estepas amarillas
#
#
# ****************************************************************************
# Predicted -- pare time con la rolacio queme dieron
# Utterance -- partime con la relacion que me dieron
#
#
# ****************************************************************************
# Predicted -- senade que habia po de que meitaba
# Utterance -- senal de que oia o de que meditaba
#
#
# ****************************************************************************
# Predicted -- pon a a a a i i s
# Utterance -- por ultimo tras largo consejo celebrado por losgenerales se dijo que iban a ser distribuidas las divisiones para tomar la ofensiva inmediatamente
#
#
# ****************************************************************************
# Predicted -- si sabia ellapentado e antonelo
# Utterance -- si estaria ella prendada de antonuelo
#
#
# ****************************************************************************
# Predicted -- y como pinaselvoiero que de iampiar acia venta e arias
# Utterance -- y como opinase el boyero que debian picar hacia la venta de arrida
#
#
# ****************************************************************************
# Predicted -- recordndo a cuncaso de supacincia en estavia
# Utterance -- recordando algun caso de su residencia en esta villa
#
#
# ****************************************************************************
# Predicted -- a pesand que este caa ruinas
# Utterance -- a pesar de que este caia en ruinas
#
#
# ****************************************************************************
# Predicted -- que abaraba de deromas orlo
# Utterance -- que ahora va a venir lo mas gordo
#
#
# ****************************************************************************
# Predicted -- ai no s
# Utterance -- amigas tenia pocas dona ines porque casi todas las hidalguillas y labradoras de la poblacion estaban muy por bajo de ella en entendimiento
#
#
# ****************************************************************************
# Predicted -- hoya rai esaeo os co n e id as as ojas
# Utterance -- oir el rey este mensaje y recordar su encuentro con el mendigo de las alforjas
#
#
# ****************************************************************************
# Predicted -- as s s
# Utterance -- hasta que todo quedo en silencio cerca ya de la madrugada oi ruido de monedas era dona restituta contando su dinero
#
#
# ****************************************************************************
# Predicted -- las gentes conserva en sombre puesto
# Utterance -- las gentes conservaban el sombrero puesto
#
#
# ****************************************************************************
# Predicted -- entonce es o torta l cucirda duaia
# Utterance -- entonces no lo tocaraanadio con firmeza liduvina
#
#
# ****************************************************************************
# Predicted -- ni e la conmenada y a antista
# Utterance -- ni de la condenada diamantista
#
#
# ****************************************************************************
# Predicted -- no y unsonos u aeaseseseiaas
# Utterance -- no hay aqui ni en los contornos sacerdote alguno y mi buen padre ha de ser sepultado sin las oraciones de la iglesia
#
#
# ****************************************************************************
# Predicted -- qua u a a a e o os
# Utterance -- que algunos historiadores hacen datar desde aquella hora la general antipatia de que los franceses fueron objeto
#
#
# ****************************************************************************
# Predicted -- vibvan dos buenos pateotras
# Utterance -- vivan los buenos patriotas
#
#
# ****************************************************************************
# Predicted -- que se corlia aes e ss
# Utterance -- que se olvidaban de ir a pescar y se les veia sonreir del gusto
#
#
# ****************************************************************************
# Predicted -- y que parcia de s capues i los ojos
# Utterance -- y que perfil el de su cara pues y los ojos
#
#
# ****************************************************************************
# Predicted -- por locuar ueresiosenaga a estr u so l ofijo
# Utterance -- por lo cual he decidido senalar a usted un sueldo fijo
#
#
# ****************************************************************************
# Predicted -- no estanciero yo co el vitad
# Utterance -- no es tan fiero el leon como le pintan
#
#
# ****************************************************************************
# Predicted -- terado y asa y c cn e laiaasn
# Utterance -- cerrado y abrochado y lo estudiaba y profundizaba con el celo de la polilla
#
#
# ****************************************************************************
# Predicted -- y pensar el la fua
# Utterance -- y pensar en la fuga
#
#
# ****************************************************************************
# Predicted -- y ellan cuedo del piendad
# Utterance -- y el gran juego de piedad
#
#
# ****************************************************************************
# Predicted -- el discuso de lacala ta decina
# Utterance -- el discurso de la charlatana vecina
#
#
# ****************************************************************************
# Predicted -- mas cunar que sentacio con to a laidad
# Utterance -- mas fue una representacion con toda claridad
#
#
# ****************************************************************************
# Predicted -- porsuete que da la tiera a adia destaciero
# Utterance -- por suerte queda la tierra anadia el estanciero
#
#
# ****************************************************************************
# Predicted -- que tamintantameta suid d rs eos esicmpioss
# Utterance -- que tan instantaneamente han surgido de los negros bosques circunvecinos
#
#
# ****************************************************************************
# Predicted -- dandante der que ma podeaces ineliosas
# Utterance -- dando a entender que nada podria hacerse sin ellos
#
#
# ****************************************************************************
# Predicted -- ya ai y o i or e eeas
# Utterance -- ya sabia yo dijo reventando de satisfaccion el siciliano y dandose un tono tremendo entre aquella gente
#
#
# ****************************************************************************
# Predicted -- pro ha aea eaos o oaials
# Utterance -- pero ahi hacia la derecha se remataba a los rusos y austriacos del modo mas admirable
#
#
# ****************************************************************************
# Predicted -- estabalan anta carar
# Utterance -- estaba yo en santa clara
#
#
# ****************************************************************************
# Predicted -- y cuma e a an a a a irisidodos
# Utterance -- y como antes los coatis salvajes venian noche a noche a visitar al coaticito civilizado
#
#
# ****************************************************************************
# Predicted -- y tun isi suisestast eie o ras a e essa
# Utterance -- y que me dicen usias de este asalto terrible que dieron los ratones a la galleta de los franceses
#
#
# ****************************************************************************
# Predicted -- ese n a os aso
# Utterance -- asi es que salimos a todo escape temiendo que los mamelucos invadieran aquella casa
#
#
# ****************************************************************************
# Predicted -- nos hombpetariamos as isonzas
# Utterance -- nos concretariamos a seis onzas
#
#
# ****************************************************************************
# Predicted -- nostotos que adns quena an esea con o lalasi
# Utterance -- nosotros nos quedaremos aqui pelando la pava en este balcon con lo cual
#
#
# ****************************************************************************
# Predicted -- los eter ecia a i a crararcrsrsososs
# Utterance -- los vencedores de egipto italia y alemania vencidos aquel dia por una fuerza inferior de pastores y carboneros
#
#
# ****************************************************************************
# Predicted -- y no dendicion del cuas se hbiean despedido
# Utterance -- y no de bendicion del cual se habian desprendido
#
#
# ****************************************************************************
# Predicted -- y luego de ellas esta pefrencias
# Utterance -- y luego de leidas estas referencias
#
#
# ****************************************************************************
# Predicted -- aque coco e i sas adadaas
# Utterance -- aquel corazon inerme y pacifico que habia sobrevivido casualmente a la guillotina
#
#
# ****************************************************************************
# Predicted -- los uosmujes n ea a sas
# Utterance -- los grupos de mujeres que en horas determinadas salian de aquel palacio hacian aun mas verosimil esta semejanza
#
#
# ****************************************************************************
# Predicted -- los acordalis de nochs e caraceo si
# Utterance -- os acordais de la noche de carracedo si
#
#
# ****************************************************************************
# Predicted -- pues y no ve onada
# Utterance -- pues yo no veo nada
#
#
# ****************************************************************************
# Predicted -- no lejos el puesto e valan
# Utterance -- no lejos del puesto de galan
#
#
# ****************************************************************************
# Predicted -- destrada de su cas el jala arasi todos os puertas
# Utterance -- desterraba de su casa y familia a casi todos los poetas
#
#
# ****************************************************************************
# Predicted -- y deco que sabreshacarle partido
# Utterance -- y te juro que sabre sacarle partido
#
#
# ****************************************************************************
# Predicted -- dondes endo uia uel car pesiontarguas
# Utterance -- donde serenandome pudiera poner en claro cuestion tan ardua
#
#
# ****************************************************************************
# Predicted -- te prenmintielevancuntido to mus os que quieras
# Utterance -- te permitire llevar contigo todos los que quieras
#
#
# ****************************************************************************
# Predicted -- ree ompvencar e hora quenos lea escudo
# Utterance -- creyeron vencerle ahora que no llevaba escudo
#
#
# ****************************************************************************
# Predicted -- el mumo e lspasos degunuoioso queserecida en uniomo
# Utterance -- el rumor de los pasos de algun curioso que se retiraba el ultimo
#
#
# ****************************************************************************
# Predicted -- la fue sader mi a acuio en aporio de lsarador n
# Utterance -- la fuerza de benifaza acudio en apoyo del serrador
#
#
# ****************************************************************************
# Predicted -- solados omanos lo ginos coblanza e rara elllo
# Utterance -- soldados romanos longinos con lanza y lazarillo
#
#
# ****************************************************************************
# Predicted -- mati anas simotosiquia a boritan puta des cababras
# Utterance -- mariquita no se inmuto siquiera al oir tan brutales palabras
#
#
# ****************************************************************************
# Predicted -- la quen aelante m orazon cuere un ijierno
# Utterance -- de aqui en adelante mi corazon fue un infierno
#
#
# ****************************************************************************
# Predicted -- le conpuso los ara josorel cuerfo
# Utterance -- le compuso los harapos sobre el cuerpo
#
#
# ****************************************************************************
# Predicted -- pero quienos con su vavos
# Utterance -- pero quien os consolara a vos
#
#
# ****************************************************************************
# Predicted -- no habien mi casudosos
# Utterance -- no hay en mi casos dudosos
#
#
# ****************************************************************************
# Predicted -- pero no mis i na ioa a aitaes e andos
# Utterance -- pero no mi sobrina me mira como para incitarme a seguir hablando
#
#
# ****************************************************************************
# Predicted -- dera a ass
# Utterance -- vete callando que ya se me sube la mostaza a la nariz no me da gana de callar
#
#
# ****************************************************************************
# Predicted -- auque o a com us s pa e sid otor o on sria s
# Utterance -- aunque no iba con mucho gusto para ello en saliendo el doctor le tome la soguilla
#
#
# ****************************************************************************
# Predicted -- pero la fuerza de la vistipvina
# Utterance -- pero la fuerza de la disciplina
#
#
# ****************************************************************************
# Predicted -- y custisia quelanto de ura l on teia
# Utterance -- injusticia que tanto deploraba y aun temia
#
#
# ****************************************************************************
# Predicted -- y cogiendo de cunsfoesa de brazo
# Utterance -- y cogiendole con fuerza del brazo
#
#
# ****************************************************************************
# Predicted -- de cueia antalve un susinadio
# Utterance -- le creian tal vez un funcionario
#
#
# ****************************************************************************
# Predicted -- crad e noco respondial aceto de pabr
# Utterance -- carmen no correspondio al afecto de pablo
#
#
# ****************************************************************************
# Predicted -- y se roboao a dede e aoao
# Utterance -- y se revolcaba pataleando mostrando sus flacas y tostadas desnudeces de animal de trabajo
#
#
# ****************************************************************************
# Predicted -- destiendo aluza u quepor eta d o ra eiasas
# Utterance -- despidiendo una luz azul que proyectaba de dos rayas verticales
#
#
# ****************************************************************************
# Predicted -- en eldiena l sea tde co casis
# Utterance -- el meridional se acerco a asis
#
#
# ****************************************************************************
# Predicted -- sin i i s s snsns as
# Utterance -- cinco hombres sentados alrededor de la ancha mesa vi sobre esta libros botellas y papeles en desorden
#
#
# ****************************************************************************
# Predicted -- pues yo romodo el vistitos e laba
# Utterance -- pues de otro modo el distrito se largaba
#
#
# ****************************************************************************
# Predicted -- entonce e n l lsojoss
# Utterance -- entonces me entere de que tenia un miedo cerval a los polacos
#
#
# ****************************************************************************
# Predicted -- yo sy s enea i n e i iaas
# Utterance -- yo soy la senora camila hermana del senor aurelio de cuyas manos recibi anoche una carta
#
#
# ****************************************************************************
# Predicted -- es a a a a i i a c c cocro croioio as
# Utterance -- esto es ahora porque estamos sin tropa pero sabe vd lo que se va a formar en andalucia un ejercito y en valencia otro ejercito
#
#
# ****************************************************************************
# Predicted -- en pops s e e e e e e neneneneneriar
# Utterance -- en cuanto a los informes que me exigieron facil me fue conseguir la merced de una recomendacion del regente del diario
#
#
# ****************************************************************************
# Predicted -- y cuando les conteste pues se a que me a uest aqui
# Utterance -- y cuando les conteste pues ya que me han puesto aqui
#
#
# ****************************************************************************
# Predicted -- el rerendo fayle tedita y ogalzado
# Utterance -- el reverendo fraile trinitario calzado
#
#
# ****************************************************************************
# Predicted -- los cualesena e las uto de s cucisios
# Utterance -- los cuales eran el asunto de los cuchicheos
#
#
# ****************************************************************************
# Predicted -- y hecha la cupals los lagas de roin esprinido que me hieres
# Utterance -- yo echaba la culpa a las dos leguas de rocin esprimido que me dieron
#
#
# ****************************************************************************
# Predicted -- sota s cacaeto ecane estosa y voviana patid
# Utterance -- soltaban su cargamento de carne destrozada y volvian a partir
#
#
# ****************************************************************************
# Predicted -- de do a a a s soso ojos
# ...
#
#
# ****************************************************************************
# Predicted -- la vesti pers u e a do s
# Utterance -- la bestia presa de estupor quedo un instante atonita y temblando
#
#
# ****************************************************************************
# Predicted -- isiueatoio araes seseseas
# Utterance -- ni siquiera torcio la cabeza para hacerles un saludo o enviarles una sonrisa de despedida
#
#
# ****************************************************************************
# Predicted -- si yo oe s o se e ese
# Utterance -- si dijo el joven es una cosa extrana lo que me sucede
#
#
# ****************************************************************************
# Predicted -- no umpapel como ls que otro senmprenian
# Utterance -- no un papel como los que otros desempenan
#
#
# ****************************************************************************
# Predicted -- acuedo me o ara de as denturas que e enin sedo s
# Utterance -- acuerdome yo ahora de las desventuras que desde nino me han seguido
#
#
# ****************************************************************************
# Predicted -- la ecase de reusos acia comian nasprpeasurezas s
# Utterance -- la escasez de recursos y la excesiva confianza en las propias fuerzas
#
#
# ****************************************************************************
# Predicted -- coresentiniendo de la orpesas y de ls semoscadas
# Utterance -- con el sentimiento de las sorpresas y de las emboscadas
#
#
# ****************************************************************************
# Predicted -- y piendo a ios proroamente que mo yo n m pa sonoro
# Utterance -- y pidiendo a dios fervorosamente que me ilumine para resolverlo
#
#
# ****************************************************************************
# Predicted -- abe a n s
# Utterance -- sabed que no solo tengo dudas sino tambien celos os habre desagradado en lo que ultimamente he hecho no os lo ocultare porque jamas he mentido
#
#
# ****************************************************************************
# Predicted -- qhe enstalo in eso il casidad
# Utterance -- ya instalado en la historica ciudad
#
#
# ****************************************************************************
# Predicted -- que no fu n a a senis sitosiss
# Utterance -- que no fue ignorancia me pudiera hacer gran dano diome aquella noche un paraxismo que me duro estar sin ningun sentido cuatro dias
#
#
# ****************************************************************************
# Predicted -- un trestire ie ro mi fesas
# Utterance -- un cestillo lleno de fresas
#
#
# ****************************************************************************
# Predicted -- y esto me o ecia i pusando na sair
# Utterance -- y esto me lo decia impulsandome a salir
#
#
# ****************************************************************************
# Predicted -- yueue e a a re era a ar asesesasaas
# Utterance -- y que le digo a su merced en contestacion al recado que tuve el honor de traer que esta muy bien contesto ines apretando su cara contra la reja
#
#
# ****************************************************************************
# Predicted -- te uieral mamnia prepuse se asi lo quies
# Utterance -- te oire alma mia repuse si asi lo quieres
#
#
# ****************************************************************************
# Predicted -- solyia acero las piecesa alya los didos de oro
# Utterance -- solian hacerlo las princesas alla en los siglos de oro
#
#
# ****************************************************************************
# Predicted -- pana n ss
# Utterance -- para nada necesitamos dinero yo tengo esperanza y tu yo tambien respondi pensando en dios
#
#
# ****************************************************************************
# Predicted -- con los comos brela podiasqia cara esante las maos
# Utterance -- con los codos sobre las rodillas y la cabeza entre las manos
#
#
# ****************************************************************************
# Predicted -- no qu e ta sos
# Utterance -- yo me quiero meter fraile estas palabras esta resolucion del muchachuelo
#
#
# ****************************************************************************
# Predicted -- entonces asoasososos
# Utterance -- entonces pues esto charlar sutilizar jugar con las palabras y los vocablos
#
#
# ****************************************************************************
# Predicted -- no ea csi desimoarorest contes a a a s sisa d as
# Utterance -- no era posible sin embargo protestar contra este y tenia necesidad de afectar servil sumision a la voluntad de mi ama
#
#
# ****************************************************************************
# Predicted -- com ran confiansan ve nio a este pais
# Utterance -- con gran confianza han venido a este pais
#
#
# ****************************************************************************
# Predicted -- di a ss
# Utterance -- digame usted en que libro ha leido eso tan bonito que acaba de decirme quiero leerlo tambien y despues probare si tales hazanas son posibles
#
#
# ****************************************************************************
# Predicted -- aunque m liba itar y hacerlocuras
# Utterance -- aunque me oigais gritar y hacer locuras
#
#
# ****************************************************************************
# Predicted -- que mi siempres a de di con el plpe da a otina
# Utterance -- que ni siempre se ha de ir con el rigor de la doctrina
#
#
# ****************************************************************************
# Predicted -- matamos ls pisiners e parto de nmcomento
# Utterance -- matamos a los prisioneros en el patio de un convento
#
#
# ****************************************************************************
# Predicted -- pamucsa ta sarrio y mo dijo nada
# Utterance -- la muchacha se rio y no dijo nada
#
#
# ****************************************************************************
# Predicted -- en r conde esarenda ajad endas
# Utterance -- senor conde exclamo la zaina riendo a carcajada tendida
#
#
# ****************************************************************************
# Predicted -- el aci preste loria tod unmu e como e rosa
# Utterance -- el arcipreste lo veia todo muy de color de rosa
#
#
# ****************************************************************************
# Predicted -- s n a a a a arsas
# Utterance -- y no se oye otra cosa sino que con los tapujos de las caras ya no hay talamo nupcial seguro ni casa honrada ni padre que pueda responder del honor de sus hijas
#
#
# ****************************************************************************
# Predicted -- vi o aie e otomo so seni aiaas
# Utterance -- vio como salian del monton humano piernas contorsionadas por los estremecimientos de la agonia
#
#
# ****************************************************************************
# Predicted -- a prita e lo iboa al suelo
# Utterance -- aplican el oido al suelo
#
#
# ****************************************************************************
# Predicted -- asi a por disc parse adodo on mios esia s
# Utterance -- hacia por disculparse practicandolo con la mayor sangre fria
#
#
# ****************************************************************************
# Predicted -- por la piesa quelos lacueos de ieron
# Utterance -- por la priesa que los vaqueros le dieron
#
#
# ****************************************************************************
# Predicted -- y como ombres sonso brerios
# Utterance -- y como los hombres son soberbios
#
#
# ****************************************************************************
# Predicted -- en estsinopcsea o cncetes
# Utterance -- en nuestros tiempos cada vez que el pueblo ruso o polaco ha intentado reivindicar sus derechos
#
#
# ****************************************************************************
# Predicted -- y me qeta etertas pinpes majete no le continente
# Utterance -- inmediatamente detras aparecia un personaje de noble continente
#
#
# ****************************************************************************
# Predicted -- mas valecaya que rocion de in erdid como ubacionaes
# Utterance -- mas vale callar que dar ocasion de incredulidad o murmuracion
#
#
# ****************************************************************************
# Predicted -- la poi o n a a a a a m omomos
# Utterance -- y como si discutieran planes y expusieran proyectos de gran trascendencia para los dos
#
#
# ****************************************************************************
# Predicted -- me conzaronlacuria lul i ormeio
# Utterance -- me forzaron a acudir al ultimo remedio
#
#
# ****************************************************************************
# Predicted -- que in porto todo eso apresiones
# Utterance -- que importa todo eso aprensiones
#
#
# ****************************************************************************
# Predicted -- y el dico qu traea a cintatuld
# Utterance -- y el dijo que traeria la cinta azul
#
#
# ****************************************************************************
# Predicted -- coa da apa e e e ececaiaos
# Utterance -- cuando la tropa francesa de linea retrocedio por tercera vez extenuada de hambre de sed y de cansancio
#
#
# ****************************************************************************
# Predicted -- desue io a a sns na asas
# Utterance -- despues de larguisima jornada durante la tarde y gran parte de una hermosisima noche de junio espana ordeno que descansasemos en santibanez de valvaneda
#
#
# ****************************************************************************
# Predicted -- que arbajando se contande tramina poluntad
# Utterance -- que arrojandose con tan determinada voluntad
#
#
# ****************************************************************************
# Predicted -- peroados paenteribunanterde enenigo
# Utterance -- preparados para impedir un avance del enemigo
#
#
# ****************************************************************************
# Predicted -- pero vidos uo e u u u iasas
# Utterance -- pero amigos puedo asegurar que es una mujer distinguidisima y muy hermosa
#
#
# ****************************************************************************
# Predicted -- qecomoyo tenia l untemo ia unando de su parte
# Utterance -- que como yo tenia algun temor de algun dano de su parte
#
#
# ****************************************************************************
# Predicted -- atendstort aca a a ai i iaiasasas
# Utterance -- atiende sobre todo a la educacion mira que por falta de ella se pierden muchos matrimonios
#
#
# ****************************************************************************
# Predicted -- que e e ine na ae ier o r o a l asess
# Utterance -- que desde alli en adelante vivirian alegremente del producto de su valor y a costa del pais
#
#
# ****************************************************************************
# Predicted -- denosab a cond ans ai s esani qy e cis mpariamiaas
# Utterance -- veremos si ahora cuando en bayona se sepa que yo sigo en espana y que no pienso en partir a america
#
#
# ****************************************************************************
# Predicted -- cal n etertretreres
# Utterance -- tales momentos no caben dentro de la apreciacion de los sentidos yo me vi rodeado de gente
#
#
# ****************************************************************************
# Predicted -- y nu a a a a a aoasas
# Utterance -- y en el pomo una cabeza con la empresa del armero toledano sebastian hernandez en la hoja algo ronosa
#
#
# ****************************************************************************
# Predicted -- sintre ayo precindoesta potadeza
# Utterance -- siempre ha ido creciendo esta fortaleza
#
#
# ****************************************************************************
# Predicted -- el iente ieneqeca a s ue sesesto
# Utterance -- el bien que tiene quien se ejercita en oracion hay muchos santos y buenos que lo han escrito
#
#
# ****************************************************************************
# Predicted -- denalari e stndsdsososas
# Utterance -- don alvaro prosiguio dirigiendose a el dios juzgara en su dia entre los dos
#
#
# ****************************************************************************
# Predicted -- loque o despusnino osto a a asa a ntn a sross
# Utterance -- lo que hizo despues metido en su aposento cuya puerta no se cerraba y cuya ventana tenia los cristales rotos
#
#
# ****************************************************************************
# Predicted -- ro r rar arar r ios
# Utterance -- usted se embarco con la expedicion de blake no pudimos vernos porque usted se oculto despues del duelo en que dio la muerte a lord gray
#
#
# ****************************************************************************
# Predicted -- esta pastaba para creritalie de gande de e geno
# Utterance -- esta bastaba para acreditarle de grande en genio
#
#
# ****************************************************************************
# Predicted -- noto una cama de mara buylo
# Utterance -- noto una calma de mal aguero
#
#
# ****************************************************************************
# Predicted -- asiso esa e tanderon te a mujeres uari caies
# Utterance -- asi sobresalen grandemente las mujeres en fabricar lienzos
#
#
# ****************************************************************************
# Predicted -- este nos de o que e asia en las ides dla pimiad
# Utterance -- este no es de los que se encastillan en las ideas de la primera edad
#
#
# ****************************************************************************
# Predicted -- acns uraton e ai asasasas
# Utterance -- acechando su retorno en el estrecho que separa a itaca de la escabrosa samos
#
#
# ****************************************************************************
# Predicted -- pero sintio ciaun motenia su iente oro
# Utterance -- pero sintio que aun no tenia suficiente oro
#
#
# ****************************************************************************
# Predicted -- entonces mien la comos ananad qe qen no cupo
# Utterance -- entonces y en la famosa mananade que me ocupo
#
#
# ****************************************************************************
# Predicted -- al a aoao s
# Utterance -- al cuartel canalla grito el jefe con ira yo os arreglare dentro de un rato
#
#
# ****************************************************************************
# Predicted -- reteponto r uso y un que quers es e aquieisi
# Utterance -- vete pronto repuso y cuenta lo que quieras pero si sales de aqui
#
#
# ****************************************************************************
# Predicted -- oy senoses oi uen anias
# Utterance -- hoy senores hoy manifesto milagro lugubremente al llegar a mi oficina
#
#
# ****************************************************************************
# Predicted -- una podo de ronce tu erdado
# Utterance -- un apolo de bronce dorado
#
#
# ****************************************************************************
# Predicted -- en una eso anferca el puente
# Utterance -- en un meson cerca del puente
#
#
# ****************************************************************************
# Predicted -- canto ia i e o e aea a etoes
# Utterance -- tanto mi navichuelo como yo teniamos que pagar demasiado caro aquel atrevimiento
#
#
# ****************************************************************************
# Predicted -- al dervmentrar pr uncho el nobre del cati
# Utterance -- al verme entrar pronuncio el nombre de cati
#
#
# ****************************************************************************
# Predicted -- un toa sos s sns sess
# Utterance -- una intencion moral a cuyo desarrollo estaban sujetos todos los movimientos pasionales de los personajes
#
#
# ****************************************************************************
# Predicted -- no podia alar por suo mocion
# Utterance -- no podia hablar por su emocion
#
#
# ****************************************************************************
# Predicted -- se mo a oi
# Utterance -- sereno callado cejijunto y llevando el brazo envuelto y colgado del cuello
#
#
# ****************************************************************************
# Predicted -- en elase simento el poleto denton e de a mas casas
# Utterance -- en ella se cimento el proyecto de entronque de ambas casas
#
#
# Test set: Average loss: -391.9795, Average CER: 0.463513 Average WER: 0.8375

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.subplot(111)
box = ax.get_position()



ax.plot(conv_bigru_train_losses, 'm', label='CONV-BIRNN train losses')
ax.plot(conv_bigru_valid_losses, 'g', label='CONV-BIRNN valid losses')


plt.xlabel('epochs')
plt.ylabel('loss')

ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])
# Put a legend above current axis
ax.legend(loc='upper center',fontsize='small', bbox_to_anchor=(0.5, 1.09),
          fancybox=True, shadow=True, ncol=2) 
# Limits for the Y axis
plt.show()
